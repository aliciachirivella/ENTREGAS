# %%
# pip install pymongo

# %% [markdown]
# 1. Mostrar todos los documentos de la colección restaurantes
# 2. Mostrar los campos restaurant_id, nombre, distrito y cocina, pero excluya el campo _id para todos los documentos de la colección restaurantes
# 3. Mostrar los primeros 5 restaurantes que se encuentran en el distrito Bronx
# 4. Devolver los restaurantes que lograron una puntuación superior a 80 pero inferior a 100
# 5. Devolver los restaurantes que se ubican en un valor de latitud inferior a -95.754168
# 6. Devolver los restaurantes que no preparan cocina americana y lograron una puntuación superior a 70 y se ubicaron en una longitud inferior a -65.754168. Nota: Realice esta consulta sin usar el operador $and
# 7. Devolver los restaurantes que no preparan cocina americana y lograron un punto de calificación 'A' que no pertenece al distrito de Brooklyn. El documento debe mostrarse según la cocina en orden descendente.
# 8. Devolver los restaurantes que pertenecen al distrito Bronx y preparan platos americanos o chinos
# 9. Devolver ID del restaurante, nombre, distrito y la cocina para aquellos restaurantes que pertenecen al distrito de Staten Island o Queens o Bronx o Brooklyn
# 10. Devolver ID del restaurante, nombre, distrito y la cocina de aquellos restaurantes que lograron una puntuación que no supere los 10
# 11. Devolver ID del restaurante, el nombre y las calificaciones del restaurante para aquellos restaurantes que obtuvieron una calificación de "A" y obtuvieron un puntaje de 11 en una fecha ISO "2014-08-11T00: 00: 00Z" entre muchas fechas de encuesta
# 12. Devolver ID del restaurante, nombre, dirección y ubicación geográfica del restaurante de aquellos donde el segundo elemento de la matriz coord contiene un valor que es más de 42 y hasta 52
#
# 15. Actualiza nombre del restaurante 'Wild Asia' por 'Wild Wild West'
# 16. Busca los restaurantes con latitud menor que -95.754168
# 17. Busca los restaurantes cuyo nombre empiece por 'C'

# %%
import pymongo
import json

# %%
# url = 'mongodb+srv://admin:admin@cluster0.xmr3d6s.mongodb.net/?retryWrites=true&w=majority'

# %%
url = "mongodb+srv://admin:admin@cluster0.jpwo6w9.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
#with open('restaurants.json','r') as r:
#   data = json.load(r)


# url = f'{connection_type}+{user}+':'+{password}+{adress}+{resto}'
#myclient = pymongo.MongoClient(url)

#mydb = myclient["Cluster0"] # INSTANCIAR BASE DE DATOS
#restaurantes = mydb['restaurantes']
#restaurantes.insert_many(data)
# Out:
# InsertManyResult([ObjectId('67349abb0ce65641937bb2d5'), ObjectId('67349abb0ce65641937bb2d6'), ObjectId('67349abb0ce65641937bb2d7'), ObjectId('67349abb0ce65641937bb2d8'), ObjectId('67349abb0ce65641937bb2d9'), ObjectId('67349abb0ce65641937bb2da'), ObjectId('67349abb0ce65641937bb2db'), ObjectId('67349abb0ce65641937bb2dc'), ObjectId('67349abb0ce65641937bb2dd'), ObjectId('67349abb0ce65641937bb2de'), ObjectId('67349abb0ce65641937bb2df'), ObjectId('67349abb0ce65641937bb2e0'), ObjectId('67349abb0ce65641937bb2e1'), ObjectId('67349abb0ce65641937bb2e2'), ObjectId('67349abb0ce65641937bb2e3'), ObjectId('67349abb0ce65641937bb2e4'), ObjectId('67349abb0ce65641937bb2e5'), ObjectId('67349abb0ce65641937bb2e6'), ObjectId('67349abb0ce65641937bb2e7'), ObjectId('67349abb0ce65641937bb2e8'), ObjectId('67349abb0ce65641937bb2e9'), ObjectId('67349abb0ce65641937bb2ea'), ObjectId('67349abb0ce65641937bb2eb'), ObjectId('67349abb0ce65641937bb2ec'), ObjectId('67349abb0ce65641937bb2ed'), ObjectId('67349abb0ce65641937bb2ee'), ObjectId('67349abb0ce65641937bb2ef'), ObjectId('67349abb0ce65641937bb2f0'), ObjectId('67349abb0ce65641937bb2f1'), ObjectId('67349abb0ce65641937bb2f2'), ObjectId('67349abb0ce65641937bb2f3'), ObjectId('67349abb0ce65641937bb2f4'), ObjectId('67349abb0ce65641937bb2f5'), ObjectId('67349abb0ce65641937bb2f6'), ObjectId('67349abb0ce65641937bb2f7'), ObjectId('67349abb0ce65641937bb2f8'), ObjectId('67349abb0ce65641937bb2f9'), ObjectId('67349abb0ce65641937bb2fa'), ObjectId('67349abb0ce65641937bb2fb'), ObjectId('67349abb0ce65641937bb2fc'), ObjectId('67349abb0ce65641937bb2fd'), ObjectId('67349abb0ce65641937bb2fe'), ObjectId('67349abb0ce65641937bb2ff'), ObjectId('67349abb0ce65641937bb300'), ObjectId('67349abb0ce65641937bb301'), ObjectId('67349abb0ce65641937bb302'), ObjectId('67349abb0ce65641937bb303'), ObjectId('67349abb0ce65641937bb304'), ObjectId('67349abb0ce65641937bb305'), ObjectId('67349abb0ce65641937bb306'), ObjectId('67349abb0ce65641937bb307'), ObjectId('67349abb0ce65641937bb308'), ObjectId('67349abb0ce65641937bb309'), ObjectId('67349abb0ce65641937bb30a'), ObjectId('67349abb0ce65641937bb30b'), ObjectId('67349abb0ce65641937bb30c'), ObjectId('67349abb0ce65641937bb30d'), ObjectId('67349abb0ce65641937bb30e'), ObjectId('67349abb0ce65641937bb30f'), ObjectId('67349abb0ce65641937bb310'), ObjectId('67349abb0ce65641937bb311'), ObjectId('67349abb0ce65641937bb312'), ObjectId('67349abb0ce65641937bb313'), ObjectId('67349abb0ce65641937bb314'), ObjectId('67349abb0ce65641937bb315'), ObjectId('67349abb0ce65641937bb316'), ObjectId('67349abb0ce65641937bb317'), ObjectId('67349abb0ce65641937bb318'), ObjectId('67349abb0ce65641937bb319'), ObjectId('67349abb0ce65641937bb31a'), ObjectId('67349abb0ce65641937bb31b'), ObjectId('67349abb0ce65641937bb31c'), ObjectId('67349abb0ce65641937bb31d'), ObjectId('67349abb0ce65641937bb31e'), ObjectId('67349abb0ce65641937bb31f'), ObjectId('67349abb0ce65641937bb320'), ObjectId('67349abb0ce65641937bb321'), ObjectId('67349abb0ce65641937bb322'), ObjectId('67349abb0ce65641937bb323'), ObjectId('67349abb0ce65641937bb324'), ObjectId('67349abb0ce65641937bb325'), ObjectId('67349abb0ce65641937bb326'), ObjectId('67349abb0ce65641937bb327'), ObjectId('67349abb0ce65641937bb328'), ObjectId('67349abb0ce65641937bb329'), ObjectId('67349abb0ce65641937bb32a'), ObjectId('67349abb0ce65641937bb32b'), ObjectId('67349abb0ce65641937bb32c'), ObjectId('67349abb0ce65641937bb32d'), ObjectId('67349abb0ce65641937bb32e'), ObjectId('67349abb0ce65641937bb32f'), ObjectId('67349abb0ce65641937bb330'), ObjectId('67349abb0ce65641937bb331'), ObjectId('67349abb0ce65641937bb332'), ObjectId('67349abb0ce65641937bb333'), ObjectId('67349abb0ce65641937bb334'), ObjectId('67349abb0ce65641937bb335'), ObjectId('67349abb0ce65641937bb336'), ObjectId('67349abb0ce65641937bb337'), ObjectId('67349abb0ce65641937bb338'), ObjectId('67349abb0ce65641937bb339'), ObjectId('67349abb0ce65641937bb33a'), ObjectId('67349abb0ce65641937bb33b'), ObjectId('67349abb0ce65641937bb33c'), ObjectId('67349abb0ce65641937b ...

# %%
url = "mongodb+srv://admin:admin@cluster0.jpwo6w9.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
myclient = pymongo.MongoClient(url)
mydb = myclient["Cluster0"] # INSTANCIAR BASE DE DATOS
restaurantes = mydb['restaurantes']

# %%
# Mostrar todos los documentos de la colección restaurantes
list(restaurantes.find())
# Out:
# [{'_id': ObjectId('673453bb5d3531401d7c0afa'),
#   'address': {'building': '1007',
#    'coord': [-73.856077, 40.848447],
#    'street': 'Morris Park Ave',
#    'zipcode': '10462'},
#   'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1378857600000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1358985600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1322006400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1299715200000}, 'grade': 'B', 'score': 14}],
#   'name': 'Morris Park Bake Shop',
#   'restaurant_id': '30075445'},
#  {'_id': ObjectId('673453bb5d3531401d7c0afb'),
#   'address': {'building': '469',
#    'coord': [-73.961704, 40.662942],
#    'street': 'Flatbush Avenue',
#    'zipcode': '11225'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1419897600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1404172800000}, 'grade': 'B', 'score': 23},
#    {'date': {'$date': 1367280000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1336435200000}, 'grade': 'A', 'score': 12}],
#   'name': "Wendy'S",
#   'restaurant_id': '30112340'},
#  {'_id': ObjectId('673453bb5d3531401d7c0afc'),
#   'address': {'building': '351',
#    'coord': [-73.98513559999999, 40.7676919],
#    'street': 'West   57 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'grades': [{'date': {'$date': 1409961600000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1374451200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1343692800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1325116800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Dj Reynolds Pub And Restaurant',
#   'restaurant_id': '30191841'},
#  {'_id': ObjectId('673453bb5d3531401d7c0afd'),
#   'address': {'building': '2780',
#    'coord': [-73.98241999999999, 40.579505],
#    'street': 'Stillwell Avenue',
#    'zipcode': '11224'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1402358400000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1370390400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1334275200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1318377600000}, 'grade': 'A', 'score': 12}],
#   'name': 'Riviera Caterer',
#   'restaurant_id': '40356018'},
#  {'_id': ObjectId('673453bb5d3531401d7c0afe'),
#   'address': {'building': '97-22',
#    'coord': [-73.8601152, 40.7311739],
#    'street': '63 Road',
#    'zipcode': '11374'},
#   'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1416787200000}, 'grade': 'Z', 'score': 20},
#    {'date': {'$date': 1358380800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1343865600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1323907200000}, 'grade': 'B', 'score': 25}],
#   'name': 'Tov Kosher Kitchen',
#   'restaurant_id': '40356068'},
#  {'_id': ObjectId('673453bb5d3531401d7c0aff'),
#   'address': {'building': '8825',
#    'coord': [-73.8803827, 40.7643124],
#    'street': 'Astoria Boulevard',
#    'zipcode': '11369'},
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1416009600000}, 'grade': 'Z', 'score': 38},
#    {'date': {'$date': 1398988800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1362182400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1328832000000}, 'grade': 'A', 'score': 13}],
#   'name': 'Brunos On The Boulevard',
#   'restaurant_id': '40356151'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b00'),
#   'address': {'building': '2206',
#    'coord': [-74.1377286, 40.6119572],
#    'street': 'Victory Boulevard',
#    'zipcode': '10314'},
#   'borough': 'Staten Island',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1412553600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1400544000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1365033600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1327363200000}, 'grade': 'A', 'score': 9}],
#   'name': 'Kosher Island',
#   'restaurant_id': '40356442'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b01'),
#   'address': {'building': '7114',
#    'coord': [-73.9068506, 40.6199034],
#    'street': 'Avenue U',
#    'zipcode': '11234'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1401321600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1389657600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1375488000000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1342569600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1331251200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1318550400000}, 'grade': 'A', 'score': 9}],
#   'name': "Wilken'S Fine Food",
#   'restaurant_id': '40356483'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b02'),
#   'address': {'building': '6409',
#    'coord': [-74.00528899999999, 40.628886],
#    'street': '11 Avenue',
#    'zipcode': '11219'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1405641600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1375142400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1360713600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1345075200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1313539200000}, 'grade': 'A', 'score': 11}],
#   'name': 'Regina Caterers',
#   'restaurant_id': '40356649'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b03'),
#   'address': {'building': '1839',
#    'coord': [-73.9482609, 40.6408271],
#    'street': 'Nostrand Avenue',
#    'zipcode': '11226'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'date': {'$date': 1405296000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1373414400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1341964800000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1329955200000}, 'grade': 'A', 'score': 8}],
#   'name': 'Taste The Tropics Ice Cream',
#   'restaurant_id': '40356731'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b04'),
#   'address': {'building': '2300',
#    'coord': [-73.8786113, 40.8502883],
#    'street': 'Southern Boulevard',
#    'zipcode': '10460'},
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1401235200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1371600000000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1339718400000}, 'grade': 'A', 'score': 3}],
#   'name': 'Wild Asia',
#   'restaurant_id': '40357217'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b05'),
#   'address': {'building': '7715',
#    'coord': [-73.9973325, 40.61174889999999],
#    'street': '18 Avenue',
#    'zipcode': '11214'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1397606400000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1366675200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1335225600000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1323993600000}, 'grade': 'A', 'score': 2}],
#   'name': 'C & C Catering Service',
#   'restaurant_id': '40357437'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b06'),
#   'address': {'building': '1269',
#    'coord': [-73.871194, 40.6730975],
#    'street': 'Sutter Avenue',
#    'zipcode': '11208'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1410825600000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1377648000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1364860800000}, 'grade': 'C', 'score': 56},
#    {'date': {'$date': 1344988800000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1332892800000}, 'grade': 'B', 'score': 27}],
#   'name': 'May May Kitchen',
#   'restaurant_id': '40358429'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b07'),
#   'address': {'building': '1',
#    'coord': [-73.96926909999999, 40.7685235],
#    'street': 'East   66 Street',
#    'zipcode': '10065'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1399420800000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1367539200000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1335744000000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1324944000000}, 'grade': 'A', 'score': 0}],
#   'name': '1 East 66Th Street Kitchen',
#   'restaurant_id': '40359480'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b08'),
#   'address': {'building': '705',
#    'coord': [-73.9653967, 40.6064339],
#    'street': 'Kings Highway',
#    'zipcode': '11223'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1415577600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1381363200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1349308800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1337558400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1325203200000}, 'grade': 'B', 'score': 19}],
#   'name': 'Seuda Foods',
#   'restaurant_id': '40360045'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b09'),
#   'address': {'building': '203',
#    'coord': [-73.97822040000001, 40.6435254],
#    'street': 'Church Avenue',
#    'zipcode': '11218'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'date': {'$date': 1391990400000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1357084800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1326067200000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1320624000000}, 'grade': 'P', 'score': 12},
#    {'date': {'$date': 1311206400000}, 'grade': 'A', 'score': 13}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40360076'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b0a'),
#   'address': {'building': '265-15',
#    'coord': [-73.7032601, 40.7386417],
#    'street': 'Hillside Avenue',
#    'zipcode': '11004'},
#   'borough': 'Queens',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'date': {'$date': 1414454400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1379462400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1348099200000}, 'grade': 'A', 'score': 13}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40361322'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b0b'),
#   'address': {'building': '6909',
#    'coord': [-74.0259567, 40.6353674],
#    'street': '3 Avenue',
#    'zipcode': '11209'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1408579200000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1393977600000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1357776000000}, 'grade': 'A', 'score': 10}],
#   'name': 'Nordic Delicacies',
#   'restaurant_id': '40361390'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b0c'),
#   'address': {'building': '522',
#    'coord': [-73.95171, 40.767461],
#    'street': 'East   74 Street',
#    'zipcode': '10021'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1409616000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1387411200000}, 'grade': 'B', 'score': 16},
#    {'date': {'$date': 1369699200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1354838400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1332979200000}, 'grade': 'A', 'score': 11}],
#   'name': 'Glorious Food',
#   'restaurant_id': '40361521'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b0d'),
#   'address': {'building': '284',
#    'coord': [-73.9829239, 40.6580753],
#    'street': 'Prospect Park West',
#    'zipcode': '11215'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1416355200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1384387200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1354665600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1337212800000}, 'grade': 'A', 'score': 11}],
#   'name': 'The Movable Feast',
#   'restaurant_id': '40361606'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b0e'),
#   'address': {'building': '129-08',
#    'coord': [-73.839297, 40.78147],
#    'street': '20 Avenue',
#    'zipcode': '11356'},
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1408147200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1377561600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1348099200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1317254400000}, 'grade': 'A', 'score': 10}],
#   'name': "Sal'S Deli",
#   'restaurant_id': '40361618'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b0f'),
#   'address': {'building': '759',
#    'coord': [-73.9925306, 40.7309346],
#    'street': 'Broadway',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1390262400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1357257600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1339027200000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1326758400000}, 'grade': 'A', 'score': 8}],
#   'name': "Bully'S Deli",
#   'restaurant_id': '40361708'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b10'),
#   'address': {'building': '3406',
#    'coord': [-73.94024739999999, 40.7623288],
#    'street': '10 Street',
#    'zipcode': '11106'},
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1395187200000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1363132800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1332806400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1301961600000}, 'grade': 'A', 'score': 7}],
#   'name': "Steve Chu'S Deli & Grocery",
#   'restaurant_id': '40361998'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b11'),
#   'address': {'building': '502',
#    'coord': [-73.976112, 40.786714],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10024'},
#   'borough': 'Manhattan',
#   'cuisine': 'Chicken',
#   'grades': [{'date': {'$date': 1410739200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1393891200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1374105600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1357689600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1334016000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1321315200000}, 'grade': 'A', 'score': 7}],
#   'name': "Harriet'S Kitchen",
#   'restaurant_id': '40362098'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b12'),
#   'address': {'building': '730',
#    'coord': [-73.96805719999999, 40.7925587],
#    'street': 'Columbus Avenue',
#    'zipcode': '10025'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1410480000000}, 'grade': 'B', 'score': 26},
#    {'date': {'$date': 1377648000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1364169600000}, 'grade': 'B', 'score': 20},
#    {'date': {'$date': 1329177600000}, 'grade': 'A', 'score': 12}],
#   'name': 'P & S Deli Grocery',
#   'restaurant_id': '40362264'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b13'),
#   'address': {'building': '18',
#    'coord': [-73.996984, 40.72589],
#    'street': 'West Houston Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1396483200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1365120000000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1332288000000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1303862400000}, 'grade': 'A', 'score': 5}],
#   'name': 'Angelika Film Center',
#   'restaurant_id': '40362274'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b14'),
#   'address': {'building': '531',
#    'coord': [-73.9634876, 40.6940001],
#    'street': 'Myrtle Avenue',
#    'zipcode': '11205'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1395100800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1363564800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1349827200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1316649600000}, 'grade': 'A', 'score': 2}],
#   'name': 'White Castle',
#   'restaurant_id': '40362344'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b15'),
#   'address': {'building': '103-05',
#    'coord': [-73.8642349, 40.75356],
#    'street': '37 Avenue',
#    'zipcode': '11368'},
#   'borough': 'Queens',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1398038400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1384214400000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1370304000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1352851200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1349913600000}, 'grade': 'P', 'score': 0},
#    {'date': {'$date': 1337817600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1323302400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1311120000000}, 'grade': 'A', 'score': 11}],
#   'name': 'Ho Mei Restaurant',
#   'restaurant_id': '40362432'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b16'),
#   'address': {'building': '60',
#    'coord': [-74.0085357, 40.70620539999999],
#    'street': 'Wall Street',
#    'zipcode': '10005'},
#   'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'date': {'$date': 1411689600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1379462400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1348185600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1336521600000}, 'grade': 'A', 'score': 11}],
#   'name': 'The Country Cafe',
#   'restaurant_id': '40362715'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b17'),
#   'address': {'building': '195',
#    'coord': [-73.9246028, 40.6522396],
#    'street': 'East   56 Street',
#    'zipcode': '11203'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'grades': [{'date': {'$date': 1399939200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1367971200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1348272000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1307318400000}, 'grade': 'A', 'score': 12}],
#   'name': "Shashemene Int'L Restaura",
#   'restaurant_id': '40362869'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b18'),
#   'address': {'building': '107',
#    'coord': [-74.00920839999999, 40.7132925],
#    'street': 'Church Street',
#    'zipcode': '10007'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1405641600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1393372800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1377475200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1359676800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1326758400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1318896000000}, 'grade': 'A', 'score': 11}],
#   'name': 'Downtown Deli',
#   'restaurant_id': '40363021'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b19'),
#   'address': {'building': '1006',
#    'coord': [-73.84856870000002, 40.8903781],
#    'street': 'East 233 Street',
#    'zipcode': '10466'},
#   'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'date': {'$date': 1398297600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1378339200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1361404800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1341273600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1310342400000}, 'grade': 'A', 'score': 5}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363093'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b1a'),
#   'address': {'building': '56',
#    'coord': [-73.991495, 40.692273],
#    'street': 'Court Street',
#    'zipcode': '11201'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Donuts',
#   'grades': [{'date': {'$date': 1419897600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1389744000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1357603200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1326931200000}, 'grade': 'A', 'score': 10}],
#   'name': "Dunkin' Donuts",
#   'restaurant_id': '40363098'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b1b'),
#   'address': {'building': '7615',
#    'coord': [-74.0228449, 40.6281815],
#    'street': '5 Avenue',
#    'zipcode': '11209'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1417651200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1382572800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1366243200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1333584000000}, 'grade': 'A', 'score': 13}],
#   'name': 'Mejlander & Mulgannon',
#   'restaurant_id': '40363117'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b1c'),
#   'address': {'building': '120',
#    'coord': [-73.9998042, 40.7251256],
#    'street': 'Prince Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'Bakery',
#   'grades': [{'date': {'$date': 1413504000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1379462400000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1367280000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1334880000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1324252800000}, 'grade': 'A', 'score': 3}],
#   'name': "Olive'S",
#   'restaurant_id': '40363151'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b1d'),
#   'address': {'building': '1236',
#    'coord': [-73.8893654, 40.81376179999999],
#    'street': '238 Spofford Ave',
#    'zipcode': '10474'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1388361600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1357603200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1339459200000}, 'grade': 'B', 'score': 15}],
#   'name': 'Happy Garden',
#   'restaurant_id': '40363289'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b1e'),
#   'address': {'building': '625',
#    'coord': [-73.990494, 40.7569545],
#    'street': '8 Avenue',
#    'zipcode': '10018'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1402272000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1389312000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1354838400000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1323734400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1315526400000}, 'grade': 'A', 'score': 13}],
#   'name': 'Cafe Metro',
#   'restaurant_id': '40363298'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b1f'),
#   'address': {'building': '1069',
#    'coord': [-73.902463, 40.694924],
#    'street': 'Wyckoff Avenue',
#    'zipcode': '11385'},
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1399507200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1386806400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1371772800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1356307200000}, 'grade': 'B', 'score': 25},
#    {'date': {'$date': 1318982400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1308096000000}, 'grade': 'A', 'score': 10}],
#   'name': "Tony'S Deli",
#   'restaurant_id': '40363333'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b20'),
#   'address': {'building': '405',
#    'coord': [-73.97534999999999, 40.7516269],
#    'street': 'Lexington Avenue',
#    'zipcode': '10174'},
#   'borough': 'Manhattan',
#   'cuisine': 'Sandwiches/Salads/Mixed Buffet',
#   'grades': [{'date': {'$date': 1392940800000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1379030400000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1346112000000}, 'grade': 'A', 'score': 0},
#    {'date': {'$date': 1315872000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1304380800000}, 'grade': 'A', 'score': 5}],
#   'name': 'Lexler Deli',
#   'restaurant_id': '40363426'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b21'),
#   'address': {'building': '2491',
#    'coord': [-74.1459332, 40.6103714],
#    'street': 'Victory Boulevard',
#    'zipcode': '10314'},
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1420761600000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1386201600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1371600000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1357603200000}, 'grade': 'A', 'score': 11}],
#   'name': 'Bagels N Buns',
#   'restaurant_id': '40363427'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b22'),
#   'address': {'building': '7905',
#    'coord': [-73.8740217, 40.7135015],
#    'street': 'Metropolitan Avenue',
#    'zipcode': '11379'},
#   'borough': 'Queens',
#   'cuisine': 'Bagels/Pretzels',
#   'grades': [{'date': {'$date': 1410912000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1389830400000}, 'grade': 'B', 'score': 23},
#    {'date': {'$date': 1375833600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1361404800000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1340150400000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1327968000000}, 'grade': 'B', 'score': 18}],
#   'name': 'Hot Bagels',
#   'restaurant_id': '40363565'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b23'),
#   'address': {'building': '87-69',
#    'coord': [-73.8309503, 40.7001121],
#    'street': 'Lefferts Boulevard',
#    'zipcode': '11418'},
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1393286400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1376438400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1344297600000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1332720000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1320364800000}, 'grade': 'A', 'score': 0},
#    {'date': {'$date': 1309305600000}, 'grade': 'A', 'score': 4}],
#   'name': 'Snack Time Grill',
#   'restaurant_id': '40363590'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b24'),
#   'address': {'building': '1418',
#    'coord': [-73.95685019999999, 40.7753401],
#    'street': 'Third Avenue',
#    'zipcode': '10028'},
#   'borough': 'Manhattan',
#   'cuisine': 'Continental',
#   'grades': [{'date': {'$date': 1401667200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1388102400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1363564800000}, 'grade': 'B', 'score': 26},
#    {'date': {'$date': 1328054400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1309910400000}, 'grade': 'B', 'score': 25}],
#   'name': "Lorenzo & Maria'S",
#   'restaurant_id': '40363630'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b25'),
#   'address': {'building': '464',
#    'coord': [-73.9791458, 40.744328],
#    'street': '3 Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1407196800000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1394064000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1373328000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1359504000000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1325721600000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1316995200000}, 'grade': 'A', 'score': 0}],
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40363644'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b26'),
#   'address': {'building': '437',
#    'coord': [-73.975393, 40.757365],
#    'street': 'Madison Avenue',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1401753600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1370563200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1340928000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1328486400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1308787200000}, 'grade': 'A', 'score': 13}],
#   'name': 'Berkely',
#   'restaurant_id': '40363685'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b27'),
#   'address': {'building': '1031',
#    'coord': [-73.9075537, 40.6438684],
#    'street': 'East   92 Street',
#    'zipcode': '11236'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1391558400000}, 'grade': 'A', 'score': 0},
#    {'date': {'$date': 1359417600000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1323302400000}, 'grade': 'A', 'score': 10}],
#   'name': "Sonny'S Heros",
#   'restaurant_id': '40363744'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b28'),
#   'address': {'building': '1111',
#    'coord': [-74.0796436, 40.59878339999999],
#    'street': 'Hylan Boulevard',
#    'zipcode': '10305'},
#   'borough': 'Staten Island',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'date': {'$date': 1398297600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1361836800000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1328140800000}, 'grade': 'A', 'score': 2}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363834'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b29'),
#   'address': {'building': '976',
#    'coord': [-73.92701509999999, 40.6620192],
#    'street': 'Rutland Road',
#    'zipcode': '11212'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1398211200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1364256000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1331596800000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1321401600000}, 'grade': 'A', 'score': 13}],
#   'name': 'Golden Pavillion',
#   'restaurant_id': '40363920'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b2a'),
#   'address': {'building': '148',
#    'coord': [-73.9806854, 40.7778589],
#    'street': 'West   72 Street',
#    'zipcode': '10023'},
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1417996800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1399248000000}, 'grade': 'B', 'score': 18},
#    {'date': {'$date': 1365120000000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1333065600000}, 'grade': 'A', 'score': 9}],
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40363945'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b2b'),
#   'address': {'building': '364',
#    'coord': [-73.96084119999999, 40.8014307],
#    'street': 'West  110 Street',
#    'zipcode': '10025'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1409788800000}, 'grade': 'B', 'score': 20},
#    {'date': {'$date': 1393372800000}, 'grade': 'B', 'score': 23},
#    {'date': {'$date': 1364169600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1329782400000}, 'grade': 'A', 'score': 8}],
#   'name': 'Spoon Bread Catering',
#   'restaurant_id': '40364179'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b2c'),
#   'address': {'building': '1423',
#    'coord': [-73.9615132, 40.6253268],
#    'street': 'Avenue J',
#    'zipcode': '11230'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1418947200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1386201600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1354752000000}, 'grade': 'A', 'score': 9}],
#   'name': 'Kosher Bagel Hole',
#   'restaurant_id': '40364220'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b2d'),
#   'address': {'building': '0',
#    'coord': [-84.2040813, 9.9986585],
#    'street': 'Guardia Airport Parking',
#    'zipcode': '11371'},
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1400198400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1368144000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1337040000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1320192000000}, 'grade': 'C', 'score': 32}],
#   'name': 'Terminal Cafe/Yankee Clipper',
#   'restaurant_id': '40364262'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b2e'),
#   'address': {'building': '73',
#    'coord': [-74.1178949, 40.5734906],
#    'street': 'New Dorp Plaza',
#    'zipcode': '10306'},
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1416268800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1383782400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1366761600000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1332201600000}, 'grade': 'A', 'score': 5}],
#   'name': 'Plaza Bagels & Deli',
#   'restaurant_id': '40364286'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b2f'),
#   'address': {'building': '277',
#    'coord': [-73.8941893, 40.8634684],
#    'street': 'East Kingsbridge Road',
#    'zipcode': '10458'},
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1380153600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1363651200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1346198400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1313539200000}, 'grade': 'A', 'score': 13}],
#   'name': 'Happy Garden',
#   'restaurant_id': '40364296'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b30'),
#   'address': {'building': '203',
#    'coord': [-74.15235919999999, 40.5563756],
#    'street': 'Giffords Lane',
#    'zipcode': '10308'},
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1420416000000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1410393600000}, 'grade': 'C', 'score': 39},
#    {'date': {'$date': 1395273600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1358985600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1337731200000}, 'grade': 'A', 'score': 10}],
#   'name': 'B & M Hot Bagel & Grocery',
#   'restaurant_id': '40364299'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b31'),
#   'address': {'building': '94',
#    'coord': [-74.0061936, 40.7092038],
#    'street': 'Fulton Street',
#    'zipcode': '10038'},
#   'borough': 'Manhattan',
#   'cuisine': 'Chicken',
#   'grades': [{'date': {'$date': 1420502400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1405382400000}, 'grade': 'C', 'score': 48},
#    {'date': {'$date': 1367452800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1348444800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1334793600000}, 'grade': 'A', 'score': 7}],
#   'name': 'Texas Rotisserie',
#   'restaurant_id': '40364304'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b32'),
#   'address': {'building': '10004',
#    'coord': [-74.03400479999999, 40.6127077],
#    'street': '4 Avenue',
#    'zipcode': '11209'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1393286400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1372291200000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1354492800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1320796800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Philadelhia Grille Express',
#   'restaurant_id': '40364305'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b33'),
#   'address': {'building': '178',
#    'coord': [-73.96252129999999, 40.7098035],
#    'street': 'Broadway',
#    'zipcode': '11211'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'grades': [{'date': {'$date': 1394236800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1380326400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1364256000000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1347235200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1313366400000}, 'grade': 'A', 'score': 13}],
#   'name': 'Peter Luger Steakhouse',
#   'restaurant_id': '40364335'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b34'),
#   'address': {'building': '1',
#    'coord': [-73.97166039999999, 40.764832],
#    'street': 'East   60 Street',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1413417600000}, 'grade': 'B', 'score': 24},
#    {'date': {'$date': 1398988800000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1364860800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1350604800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1335484800000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1322524800000}, 'grade': 'A', 'score': 11}],
#   'name': 'Metropolitan Club',
#   'restaurant_id': '40364347'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b35'),
#   'address': {'building': '837',
#    'coord': [-73.9712, 40.751703],
#    'street': '2 Avenue',
#    'zipcode': '10017'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1405987200000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1380153600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1361836800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1335744000000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1317772800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Palm Restaurant',
#   'restaurant_id': '40364355'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b36'),
#   'address': {'building': '21',
#    'coord': [-73.9774394, 40.7604522],
#    'street': 'West   52 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1400025600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1376352000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1333497600000}, 'grade': 'A', 'score': 12}],
#   'name': '21 Club',
#   'restaurant_id': '40364362'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b37'),
#   'address': {'building': '658',
#    'coord': [-73.81363999999999, 40.82941100000001],
#    'street': 'Clarence Ave',
#    'zipcode': '10465'},
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1403308800000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1341964800000}, 'grade': 'A', 'score': 10}],
#   'name': 'Manhem Club',
#   'restaurant_id': '40364363'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b38'),
#   'address': {'building': '1028',
#    'coord': [-73.966032, 40.762832],
#    'street': '3 Avenue',
#    'zipcode': '10065'},
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1410825600000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1393200000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1367539200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1345420800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1329091200000}, 'grade': 'A', 'score': 9}],
#   'name': 'Isle Of Capri Resturant',
#   'restaurant_id': '40364373'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b39'),
#   'address': {'building': '45',
#    'coord': [-73.9891878, 40.7375638],
#    'street': 'East   18 Street',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1412726400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1381363200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1366761600000}, 'grade': 'C', 'score': 36},
#    {'date': {'$date': 1326067200000}, 'grade': 'A', 'score': 9}],
#   'name': 'Old Town Bar & Restaurant',
#   'restaurant_id': '40364389'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b3a'),
#   'address': {'building': '261',
#    'coord': [-73.94839189999999, 40.7224876],
#    'street': 'Driggs Avenue',
#    'zipcode': '11222'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Polish',
#   'grades': [{'date': {'$date': 1401494400000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1368144000000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1329436800000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1318550400000}, 'grade': 'C', 'score': 54}],
#   'name': 'Polish National Home',
#   'restaurant_id': '40364404'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b3b'),
#   'address': {'building': '62',
#    'coord': [-74.00310999999999, 40.7348888],
#    'street': 'Charles Street',
#    'zipcode': '10014'},
#   'borough': 'Manhattan',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'grades': [{'date': {'$date': 1398988800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1369008000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1337817600000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1326844800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1317600000000}, 'grade': 'A', 'score': 10}],
#   'name': 'Seville Restaurant',
#   'restaurant_id': '40364439'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b3c'),
#   'address': {'building': '100',
#    'coord': [-74.0010484, 40.71599000000001],
#    'street': 'Centre Street',
#    'zipcode': '10013'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1362700800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1331251200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1301529600000}, 'grade': 'A', 'score': 12}],
#   'name': 'Criminal Court Bldg Cafeteria',
#   'restaurant_id': '40364443'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b3d'),
#   'address': {'building': '657',
#    'coord': [-73.9056678, 40.7066898],
#    'street': 'Fairview Avenue',
#    'zipcode': '11385'},
#   'borough': 'Queens',
#   'cuisine': 'German',
#   'grades': [{'date': {'$date': 1394841600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1363046400000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1342828800000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1322179200000}, 'grade': 'B', 'score': 24},
#    {'date': {'$date': 1308700800000}, 'grade': 'B', 'score': 20}],
#   'name': 'Gottscheer Hall',
#   'restaurant_id': '40364449'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b3e'),
#   'address': {'building': '180',
#    'coord': [-73.9788694, 40.7665961],
#    'street': 'Central Park South',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1418601600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1407369600000}, 'grade': 'C', 'score': 40},
#    {'date': {'$date': 1375056000000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1355356800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1343606400000}, 'grade': 'C', 'score': 4},
#    {'date': {'$date': 1329350400000}, 'grade': 'A', 'score': 2}],
#   'name': 'Nyac Main Dining Room',
#   'restaurant_id': '40364467'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b3f'),
#   'address': {'building': '108',
#    'coord': [-73.98146, 40.7250067],
#    'street': 'Avenue B',
#    'zipcode': '10009'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1405296000000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1388448000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1350864000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1336348800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1318550400000}, 'grade': 'A', 'score': 12}],
#   'name': '7B Bar',
#   'restaurant_id': '40364518'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b40'),
#   'address': {'building': '96-40',
#    'coord': [-73.86137149999999, 40.7293762],
#    'street': 'Queens Boulevard',
#    'zipcode': '11374'},
#   'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1394668800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1380499200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1366934400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1347321600000}, 'grade': 'B', 'score': 24},
#    {'date': {'$date': 1316390400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1300320000000}, 'grade': 'A', 'score': 12}],
#   'name': 'Ben-Best Deli & Restaurant',
#   'restaurant_id': '40364529'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b41'),
#   'address': {'building': '215',
#    'coord': [-73.9805679, 40.7659436],
#    'street': 'West 57 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1411603200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1392336000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1376006400000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1361491200000}, 'grade': 'B', 'score': 20},
#    {'date': {'$date': 1329350400000}, 'grade': 'A', 'score': 8}],
#   'name': 'Cafe Atelier (Art Students League)',
#   'restaurant_id': '40364531'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b42'),
#   'address': {'building': '845',
#    'coord': [-73.965531, 40.765431],
#    'street': 'Lexington Avenue',
#    'zipcode': '10065'},
#   'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'date': {'$date': 1395792000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1363824000000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1350518400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1336348800000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1305590400000}, 'grade': 'A', 'score': 5}],
#   'name': "Donohue'S Steak House",
#   'restaurant_id': '40364572'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b43'),
#   'address': {'building': '311',
#    'coord': [-73.98621899999999, 40.763406],
#    'street': 'West   51 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'date': {'$date': 1415577600000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1396483200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1374019200000}, 'grade': 'C', 'score': 36},
#    {'date': {'$date': 1360108800000}, 'grade': 'B', 'score': 22},
#    {'date': {'$date': 1342396800000}, 'grade': 'C', 'score': 36},
#    {'date': {'$date': 1331164800000}, 'grade': 'C', 'score': 7}],
#   'name': 'Tout Va Bien',
#   'restaurant_id': '40364576'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b44'),
#   'address': {'building': '386',
#    'coord': [-73.9818918, 40.6901211],
#    'street': 'Flatbush Avenue Extension',
#    'zipcode': '11201'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1415923200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1394409600000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1357776000000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1346716800000}, 'grade': 'A', 'score': 7}],
#   'name': "Junior'S",
#   'restaurant_id': '40364581'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b45'),
#   'address': {'building': '37',
#    'coord': [-74.138263, 40.546681],
#    'street': 'Mansion Ave',
#    'zipcode': '10308'},
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1398124800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1380067200000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1339200000000}, 'grade': 'A', 'score': 8}],
#   'name': 'Great Kills Yacht Club',
#   'restaurant_id': '40364610'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b46'),
#   'address': {'building': '251',
#    'coord': [-73.9775552, 40.7432016],
#    'street': 'East   31 Street',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1398124800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1371600000000}, 'grade': 'C', 'score': 32},
#    {'date': {'$date': 1337644800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Marchis Restaurant',
#   'restaurant_id': '40364668'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b47'),
#   'address': {'building': '2602',
#    'coord': [-73.95443709999999, 40.5877993],
#    'street': 'East   15 Street',
#    'zipcode': '11235'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1400025600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1367020800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1353628800000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1331683200000}, 'grade': 'B', 'score': 17},
#    {'date': {'$date': 1310601600000}, 'grade': 'B', 'score': 21}],
#   'name': 'Towne Cafe',
#   'restaurant_id': '40364681'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b48'),
#   'address': {'building': '.1-A',
#    'coord': [-48.9424, -16.3550032],
#    'street': 'East 77 St',
#    'zipcode': '10021'},
#   'borough': 'Manhattan',
#   'cuisine': 'Continental',
#   'grades': [{'date': {'$date': 1416787200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1381363200000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1364947200000}, 'grade': 'B', 'score': 18},
#    {'date': {'$date': 1349136000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1335312000000}, 'grade': 'A', 'score': 8}],
#   'name': 'Dining Room',
#   'restaurant_id': '40364691'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b49'),
#   'address': {'building': '56',
#    'coord': [-74.004758, 40.741207],
#    'street': '9 Avenue',
#    'zipcode': '10011'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1402358400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1370822400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1348617600000}, 'grade': 'B', 'score': 24},
#    {'date': {'$date': 1337817600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1321228800000}, 'grade': 'A', 'score': 2}],
#   'name': 'Old Homestead',
#   'restaurant_id': '40364715'},
#  {'_id': ObjectId('673453bb5d3531401d7c0b4a'),
#   'address': {'building': '156-71',
#    'coord': [-73.840437, 40.6627235],
# ...
#    {'date': {'$date': 1347408000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1316044800000}, 'grade': 'A', 'score': 11}],
#   'name': 'Elmhurst Famous Pizza',
#   'restaurant_id': '40395597'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ec9'),
#   'address': {'building': '300',
#    'coord': [-73.8787725, 40.8728659],
#    'street': 'East 204 Street',
#    'zipcode': '10467'},
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1391212800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1358208000000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1326931200000}, 'grade': 'A', 'score': 11}],
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395653'},
#  {'_id': ObjectId('673453bb5d3531401d7c0eca'),
#   'address': {'building': '113335',
#    'coord': [-73.96712, 40.798503],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10025'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1399852800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1368144000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1336608000000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1325203200000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1312848000000}, 'grade': 'A', 'score': 13}],
#   'name': 'Camilles',
#   'restaurant_id': '40395691'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ecb'),
#   'address': {'building': '200',
#    'coord': [-73.9875796, 40.7709609],
#    'street': 'West   60 Street',
#    'zipcode': '10023'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1406505600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1374796800000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1343779200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1333065600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1320796800000}, 'grade': 'A', 'score': 13}],
#   'name': 'Olympic Flame Diner',
#   'restaurant_id': '40395723'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ecc'),
#   'address': {'building': '357',
#    'coord': [-73.96642899999999, 40.754211],
#    'street': 'East 50 Street',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': {'$date': 1398297600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1382400000000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1364947200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1343001600000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1318464000000}, 'grade': 'B', 'score': 15}],
#   'name': 'Indigo Indian Cuisine',
#   'restaurant_id': '40395748'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ecd'),
#   'address': {'building': '150',
#    'coord': [-73.9908184, 40.686652],
#    'street': 'Smith Street',
#    'zipcode': '11201'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'date': {'$date': 1395792000000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1381968000000}, 'grade': 'A', 'score': 0},
#    {'date': {'$date': 1367366400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1353456000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1350604800000}, 'grade': 'P', 'score': 0},
#    {'date': {'$date': 1319500800000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1306108800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Caruso Pizzeria & Restaurant',
#   'restaurant_id': '40395774'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ece'),
#   'address': {'building': '455',
#    'coord': [-73.98475669999999, 40.6626618],
#    'street': '7 Avenue',
#    'zipcode': '11215'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Indonesian',
#   'grades': [{'date': {'$date': 1400716800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1367452800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1349222400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1315440000000}, 'grade': 'C', 'score': 29}],
#   'name': 'Java Restaurant',
#   'restaurant_id': '40395826'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ecf'),
#   'address': {'building': '34-37',
#    'coord': [-73.7735119, 40.7693963],
#    'street': 'Bell Boulevard',
#    'zipcode': '11361'},
#   'borough': 'Queens',
#   'cuisine': 'Mexican',
#   'grades': [{'date': {'$date': 1414108800000}, 'grade': 'C', 'score': 52},
#    {'date': {'$date': 1393977600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1373068800000}, 'grade': 'B', 'score': 22},
#    {'date': {'$date': 1354924800000}, 'grade': 'B', 'score': 23},
#    {'date': {'$date': 1349222400000}, 'grade': 'P', 'score': 3},
#    {'date': {'$date': 1335916800000}, 'grade': 'A', 'score': 12}],
#   'name': 'Tequilla Sunrise',
#   'restaurant_id': '40395858'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ed0'),
#   'address': {'building': '411',
#    'coord': [-73.98352299999999, 40.743549],
#    'street': 'Park Avenue South',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'date': {'$date': 1421107200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1408060800000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1377734400000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1364515200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1330560000000}, 'grade': 'A', 'score': 2}],
#   'name': 'Les Halles',
#   'restaurant_id': '40395860'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ed1'),
#   'address': {'building': '2807',
#    'coord': [-73.94473839999999, 40.6158108],
#    'street': 'Nostrand Avenue',
#    'zipcode': '11229'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1410912000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1395705600000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1358899200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1326758400000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1317859200000}, 'grade': 'A', 'score': 10}],
#   'name': 'Pizza Nosh',
#   'restaurant_id': '40395865'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ed2'),
#   'address': {'building': '3533',
#    'coord': [-73.9509786, 40.8264242],
#    'street': 'Broadway',
#    'zipcode': '10031'},
#   'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'date': {'$date': 1412035200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1395014400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1375660800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1361836800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1346889600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1333411200000}, 'grade': 'B', 'score': 22}],
#   'name': 'Caridad Restaurant',
#   'restaurant_id': '40395872'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ed3'),
#   'address': {'building': '98-08',
#    'coord': [-73.84043869999999, 40.6797863],
#    'street': 'Rockaway Boulevard',
#    'zipcode': '11417'},
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1396483200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1367971200000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1335139200000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1305504000000}, 'grade': 'A', 'score': 13}],
#   'name': 'White Castle',
#   'restaurant_id': '40395882'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ed4'),
#   'address': {'building': '1454',
#    'coord': [-73.9563642, 40.7712012],
#    'street': '2 Avenue',
#    'zipcode': '10021'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1418774400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1398729600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1364774400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1350864000000}, 'grade': 'A', 'score': 12}],
#   'name': 'The Stumble Inn',
#   'restaurant_id': '40395892'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ed5'),
#   'address': {'building': '7559',
#    'coord': [-73.8754225, 40.713315],
#    'street': 'Metropolitan Avenue',
#    'zipcode': '11379'},
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'date': {'$date': 1419292800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1405555200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1389225600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1367280000000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1347667200000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1333324800000}, 'grade': 'B', 'score': 20}],
#   'name': 'Rosa #2 Pizzeria',
#   'restaurant_id': '40395906'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ed6'),
#   'address': {'building': '250-01',
#    'coord': [-73.737484, 40.7683787],
#    'street': 'Northern Boulevard',
#    'zipcode': '11362'},
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1403136000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1390867200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1375315200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1343001600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1313020800000}, 'grade': 'A', 'score': 0}],
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395910'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ed7'),
#   'address': {'building': '504',
#    'coord': [-73.9194763, 40.807466],
#    'street': 'East  138 Street',
#    'zipcode': '10454'},
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1417132800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1403222400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1387238400000}, 'grade': 'C', 'score': 50},
#    {'date': {'$date': 1354752000000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1337558400000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1325203200000}, 'grade': 'A', 'score': 12}],
#   'name': 'Golden Pizza',
#   'restaurant_id': '40395921'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ed8'),
#   'address': {'building': '1660',
#    'coord': [-74.162854, 40.60778699999999],
#    'street': 'Richmond Avenue',
#    'zipcode': '10314'},
#   'borough': 'Staten Island',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1401753600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1369267200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1338854400000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1324944000000}, 'grade': 'C', 'score': 52}],
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395935'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ed9'),
#   'address': {'building': '2516',
#    'coord': [-73.86709549999999, 40.8640754],
#    'street': 'White Plains Road',
#    'zipcode': '10467'},
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': {'$date': 1391644800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1359504000000}, 'grade': 'A', 'score': 2},
#    {'date': {'$date': 1327968000000}, 'grade': 'A', 'score': 11}],
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395992'},
#  {'_id': ObjectId('673453bb5d3531401d7c0eda'),
#   'address': {'building': '84',
#    'coord': [-73.9776503, 40.7521147],
#    'street': 'East 42 Street',
#    'zipcode': '10017'},
#   'borough': 'Manhattan',
#   'cuisine': 'Bagels/Pretzels',
#   'grades': [{'date': {'$date': 1403049600000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1383004800000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1367193600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1335744000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1324252800000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1312761600000}, 'grade': 'A', 'score': 7}],
#   'name': 'Hot & Crusty Bakery',
#   'restaurant_id': '40395996'},
#  {'_id': ObjectId('673453bb5d3531401d7c0edb'),
#   'address': {'building': '65',
#    'coord': [-73.98606099999999, 40.728176],
#    'street': 'St Marks Place',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'date': {'$date': 1418169600000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1403740800000}, 'grade': 'B', 'score': 27},
#    {'date': {'$date': 1378771200000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1363910400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1346803200000}, 'grade': 'B', 'score': 20}],
#   'name': 'Jules Bistro',
#   'restaurant_id': '40396000'},
#  {'_id': ObjectId('673453bb5d3531401d7c0edc'),
#   'address': {'building': '180',
#    'coord': [-73.98087199999999, 40.775067],
#    'street': 'Columbus Avenue',
#    'zipcode': '10023'},
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1386374400000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1369872000000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1332460800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1322006400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1305590400000}, 'grade': 'B', 'score': 18}],
#   'name': 'Il Violino',
#   'restaurant_id': '40396019'},
#  {'_id': ObjectId('673453bb5d3531401d7c0edd'),
#   'address': {'building': '78',
#    'coord': [-73.9981541, 40.7351897],
#    'street': 'West   11 Street',
#    'zipcode': '10011'},
#   'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'date': {'$date': 1396569600000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1364256000000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1345593600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1329782400000}, 'grade': 'A', 'score': 10}],
#   'name': 'French Roast',
#   'restaurant_id': '40396020'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ede'),
#   'address': {'building': '532',
#    'coord': [-73.9738917, 40.7605744],
#    'street': 'Madison Avenue',
#    'zipcode': '10022'},
#   'borough': 'Manhattan',
#   'cuisine': 'Delicatessen',
#   'grades': [{'date': {'$date': 1418169600000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1403740800000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1383091200000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1370563200000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1350345600000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1336003200000}, 'grade': 'B', 'score': 16},
#    {'date': {'$date': 1324944000000}, 'grade': 'A', 'score': 5}],
#   'name': "Smiler'S Deli",
#   'restaurant_id': '40396037'},
#  {'_id': ObjectId('673453bb5d3531401d7c0edf'),
#   'address': {'building': '780',
#    'coord': [-73.8630529, 40.8456372],
#    'street': 'Morris Park Ave',
#    'zipcode': '10462'},
#   'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'grades': [{'date': {'$date': 1410220800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1374105600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1361750400000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1346716800000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1333929600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1317081600000}, 'grade': 'A', 'score': 2}],
#   'name': 'Chick-N-Ribs',
#   'restaurant_id': '40396053'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ee0'),
#   'address': {'building': '74',
#    'coord': [-73.9956844, 40.7262603],
#    'street': 'Bleeker Street',
#    'zipcode': '10012'},
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'grades': [{'date': {'$date': 1396224000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1364428800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1342742400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1328745600000}, 'grade': 'A', 'score': 11}],
#   'name': 'Two Boots To Go-Go',
#   'restaurant_id': '40396066'},
#  {'_id': ObjectId('673453bb5d3531401d7c0ee1'),
#   'address': {'building': '10',
#    'coord': [-73.9815103, 40.7475731],
#    'street': 'Park Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'date': {'$date': 1404777600000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1386806400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1375315200000}, 'grade': 'C', 'score': 9},
#    {'date': {'$date': 1358812800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1337299200000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1323820800000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1312156800000}, 'grade': 'A', 'score': 8}],
#   'name': "Mendy'S",
#   'restaurant_id': '40396074'},
#  ...]

# %% [markdown]
# proyeccion : especifica qué columnas o campos de los documentos seleccionados

# %%
# Mostrar todos los documentos de la colección restaurantes
# filtro = {"cuisine": "Bakery", "borough": "Bronx"}
filtro = {}
proyeccion = {"name": 1, "_id":0} #id 0 es para q no aparezca el id 
list(restaurantes.find(filtro, proyeccion))
# Out:
# [{'name': 'Morris Park Bake Shop'},
#  {'name': "Wendy'S"},
#  {'name': 'Dj Reynolds Pub And Restaurant'},
#  {'name': 'Riviera Caterer'},
#  {'name': 'Tov Kosher Kitchen'},
#  {'name': 'Brunos On The Boulevard'},
#  {'name': 'Kosher Island'},
#  {'name': "Wilken'S Fine Food"},
#  {'name': 'Regina Caterers'},
#  {'name': 'Taste The Tropics Ice Cream'},
#  {'name': 'Wild Asia'},
#  {'name': 'C & C Catering Service'},
#  {'name': 'May May Kitchen'},
#  {'name': '1 East 66Th Street Kitchen'},
#  {'name': 'Seuda Foods'},
#  {'name': 'Carvel Ice Cream'},
#  {'name': 'Carvel Ice Cream'},
#  {'name': 'Nordic Delicacies'},
#  {'name': 'Glorious Food'},
#  {'name': 'The Movable Feast'},
#  {'name': "Sal'S Deli"},
#  {'name': "Bully'S Deli"},
#  {'name': "Steve Chu'S Deli & Grocery"},
#  {'name': "Harriet'S Kitchen"},
#  {'name': 'P & S Deli Grocery'},
#  {'name': 'Angelika Film Center'},
#  {'name': 'White Castle'},
#  {'name': 'Ho Mei Restaurant'},
#  {'name': 'The Country Cafe'},
#  {'name': "Shashemene Int'L Restaura"},
#  {'name': 'Downtown Deli'},
#  {'name': 'Carvel Ice Cream'},
#  {'name': "Dunkin' Donuts"},
#  {'name': 'Mejlander & Mulgannon'},
#  {'name': "Olive'S"},
#  {'name': 'Happy Garden'},
#  {'name': 'Cafe Metro'},
#  {'name': "Tony'S Deli"},
#  {'name': 'Lexler Deli'},
#  {'name': 'Bagels N Buns'},
#  {'name': 'Hot Bagels'},
#  {'name': 'Snack Time Grill'},
#  {'name': "Lorenzo & Maria'S"},
#  {'name': "Domino'S Pizza"},
#  {'name': 'Berkely'},
#  {'name': "Sonny'S Heros"},
#  {'name': 'Carvel Ice Cream'},
#  {'name': 'Golden Pavillion'},
#  {'name': "Domino'S Pizza"},
#  {'name': 'Spoon Bread Catering'},
#  {'name': 'Kosher Bagel Hole'},
#  {'name': 'Terminal Cafe/Yankee Clipper'},
#  {'name': 'Plaza Bagels & Deli'},
#  {'name': 'Happy Garden'},
#  {'name': 'B & M Hot Bagel & Grocery'},
#  {'name': 'Texas Rotisserie'},
#  {'name': 'Philadelhia Grille Express'},
#  {'name': 'Peter Luger Steakhouse'},
#  {'name': 'Metropolitan Club'},
#  {'name': 'Palm Restaurant'},
#  {'name': '21 Club'},
#  {'name': 'Manhem Club'},
#  {'name': 'Isle Of Capri Resturant'},
#  {'name': 'Old Town Bar & Restaurant'},
#  {'name': 'Polish National Home'},
#  {'name': 'Seville Restaurant'},
#  {'name': 'Criminal Court Bldg Cafeteria'},
#  {'name': 'Gottscheer Hall'},
#  {'name': 'Nyac Main Dining Room'},
#  {'name': '7B Bar'},
#  {'name': 'Ben-Best Deli & Restaurant'},
#  {'name': 'Cafe Atelier (Art Students League)'},
#  {'name': "Donohue'S Steak House"},
#  {'name': 'Tout Va Bien'},
#  {'name': "Junior'S"},
#  {'name': 'Great Kills Yacht Club'},
#  {'name': 'Marchis Restaurant'},
#  {'name': 'Towne Cafe'},
#  {'name': 'Dining Room'},
#  {'name': 'Old Homestead'},
#  {'name': 'New Park Pizzeria & Restaurant'},
#  {'name': 'Douglaston Club'},
#  {'name': 'Serendipity 3'},
#  {'name': 'Melody Lanes'},
#  {'name': "Rizzo'S Fine Pizza"},
#  {'name': 'The New Starling Athletic Club Of The Bronx'},
#  {'name': 'White Horse Tavern'},
#  {'name': 'Crystal Room'},
#  {'name': "Labetti'S Post # 2159"},
#  {'name': 'Shell Lanes'},
#  {'name': "Mcsorley'S Old Ale House"},
#  {'name': 'Forlinis Restaurant'},
#  {'name': 'South Shore Swimming Club'},
#  {'name': 'Corner Bistro'},
#  {'name': 'Nostrand Donut Shop'},
#  {'name': "Dorrian'S Red Hand Restaurant"},
#  {'name': 'La Grenouille'},
#  {'name': 'Como Pizza'},
#  {'name': 'Keats Restaurant'},
#  {'name': 'Angelo Of Mulberry St.'},
#  {'name': "Panchito'S"},
#  {'name': 'New Corner'},
#  {'name': 'The Princeton Club'},
#  {'name': "Arturo'S"},
#  {'name': 'Le Perigord'},
#  {'name': "Reynold'S Bar"},
#  {'name': "Joe & Pat'S Pizzeria"},
#  {'name': 'Spain Restaurant & Bar'},
#  {'name': 'Palace Cafe'},
#  {'name': 'Yankee Tavern'},
#  {'name': 'Donut Pub'},
#  {'name': "Moran'S Chelsea"},
#  {'name': 'Reben Luncheonette'},
#  {'name': 'V & T Restaurant'},
#  {'name': 'King Yum Restaurant'},
#  {'name': "Jahn'S Restaurant"},
#  {'name': 'J&V Famous Pizza'},
#  {'name': 'La Parisienne Diner'},
#  {'name': 'Joe Allen Restaurant'},
#  {'name': "Joyce'S Tavern"},
#  {'name': 'Il Vagabondo Restaurant'},
#  {'name': 'Barbetta Restaurant'},
#  {'name': "Gargiulo'S Restaurant"},
#  {'name': "Patsy'S Italian Restaurant"},
#  {'name': 'Parkside Restaurant'},
#  {'name': "Lavelle'S Admiral'S Club"},
#  {'name': "Neary'S Pub"},
#  {'name': 'New York Pizza Suprema'},
#  {'name': 'Mcdwyers Pub'},
#  {'name': 'Mee Sum Coffee Shop'},
#  {'name': "Nancy'S Fire Side"},
#  {'name': 'Hop Kee Restaurant'},
#  {'name': 'Nancy Whiskey Pub'},
#  {'name': 'Blarney Bar'},
#  {'name': 'Margherita Pizza'},
#  {'name': "Healy'S Pub"},
#  {'name': 'Fifth Avenue Bingo'},
#  {'name': "Denino'S Pizzeria Tavern"},
#  {'name': "Michael'S Restaurant"},
#  {'name': 'Nanni Restaurant'},
#  {'name': "Lenihan'S Saloon"},
#  {'name': 'Emilio Iii Bar'},
#  {'name': 'Killarney Rose'},
#  {'name': 'Don Peppe'},
#  {'name': 'Blarney Castle'},
#  {'name': 'Three Star Restaurant'},
#  {'name': 'Blarney Rock'},
#  {'name': "Dangerfield'S Night Club"},
#  {'name': "Desmond'S Tavern"},
#  {'name': 'Naomi Kosher Pizza'},
#  {'name': 'Roll-N-Roaster'},
#  {'name': 'Tio Pepe'},
#  {'name': 'Brennan & Carr'},
#  {'name': 'The Punch Bowl'},
#  {'name': 'Jardin De China Rest'},
#  {'name': 'Irish Cottage'},
#  {'name': 'Blarney Stone'},
#  {'name': 'Shimons Kosher Pizza'},
#  {'name': 'The Riviera Cafe'},
#  {'name': "Fascati'S Pizzeria"},
#  {'name': "Baby Bo'S Burritos"},
#  {'name': "Li Greci'S Staaten Restaurant"},
#  {'name': 'Shun Lee Palace Restaurant'},
#  {'name': 'Tamaqua'},
#  {'name': 'Munchtime'},
#  {'name': 'Cara Mia'},
#  {'name': 'Ihop'},
#  {'name': "Maloney'S Bar"},
#  {'name': 'La Fusta Restaurant'},
#  {'name': 'Richmond County Country Club'},
#  {'name': 'Little Brown Jug'},
#  {'name': "Lulu'S Coffee Shop"},
#  {'name': "Mitchell'S Restaurant"},
#  {'name': 'El Charro Espanol'},
#  {'name': "Finnegan'S Wake"},
#  {'name': 'Da Vinci Pizza'},
#  {'name': 'Mexico Lindo Restaurant'},
#  {'name': 'Marina Delray'},
#  {'name': 'New Floridian Diner'},
#  {'name': 'Twins Pub'},
#  {'name': 'Narrows Coffee Shop'},
#  {'name': 'Broome Street Bar'},
#  {'name': "O'Hanlon'S Pub"},
#  {'name': 'Charlies Sports Bar'},
#  {'name': 'Jg Melon Restaurant'},
#  {'name': "Jack'S Pizza & Pasta"},
#  {'name': 'Emerald Pub'},
#  {'name': 'Tap Room'},
#  {'name': 'Cocktail Room (Nyac)'},
#  {'name': 'Flame Restaurant Coffee House'},
#  {'name': 'Jackson Hole'},
#  {'name': 'Zum Stammtisch'},
#  {'name': "John'S Restaurant"},
#  {'name': 'Grassroot Tavern'},
#  {'name': "Buddy'S Wonder Bar"},
#  {'name': 'The Assembly Bar'},
#  {'name': 'Mr Broadway Kosher Restaurant'},
#  {'name': 'Piccola Venezia'},
#  {'name': 'Malaga Restaurant'},
#  {'name': "Ni-Ni'S Cafe"},
#  {'name': 'Capitol Restaurant'},
#  {'name': 'La Bonne Soupe Bistro'},
#  {'name': 'Mimis Restaurant & Bar'},
#  {'name': "Lenny'S Clam Bar"},
#  {'name': 'Griffis Faculty Club'},
#  {'name': "Gray'S Papaya"},
#  {'name': 'Dani Pizza And Restaurant'},
#  {'name': "Mcdonald'S"},
#  {'name': 'El Greco Diner'},
#  {'name': 'One If By Land Two If By Sea'},
#  {'name': "Mcdonald'S"},
#  {'name': 'Fiorellos'},
#  {'name': 'Lb Spumoni Gardens'},
#  {'name': 'Amore Pizzeria & Restaurant'},
#  {'name': "The Lark'S Nest"},
#  {'name': 'Terrace Cafe'},
#  {'name': 'African Terrace'},
#  {'name': 'Cool Zone'},
#  {'name': 'Beaver Pond'},
#  {'name': 'African Market (Baboon Cafe)'},
#  {'name': 'Roadhouse Restaurant'},
#  {'name': 'Ford Foundation Cafeteria'},
#  {'name': 'Elephant & Castle'},
#  {'name': 'Mill Basin Kosher Deli'},
#  {'name': 'Oyster Bar'},
#  {'name': 'Cherry Tavern'},
#  {'name': 'Colonnade Diner'},
#  {'name': 'Red Flame Diner'},
#  {'name': 'Maggies Place'},
#  {'name': "Brady'S Bar"},
#  {'name': 'Da Silvano Restaurant'},
#  {'name': 'Benjamin'},
#  {'name': "Jimmy'S Corner"},
#  {'name': 'Frost Restaurant'},
#  {'name': "Sammy'S Steakhouse"},
#  {'name': 'Il Cortile Restaurant'},
#  {'name': "Denny'S Pub"},
#  {'name': 'Maries Crisis Cafe'},
#  {'name': 'Boots & Saddle Bar'},
#  {'name': 'New Parkway Restaurant'},
#  {'name': 'Cafe Riazor'},
#  {'name': 'Raouls'},
#  {'name': 'The Brook'},
#  {'name': 'Marbella Restaurant'},
#  {'name': "P.J.' S"},
#  {'name': 'Hatsuhana Restaurant'},
#  {'name': 'La Mangeoire'},
#  {'name': "Valentino'S Pizza"},
#  {'name': 'Viand Coffee Shop'},
#  {'name': 'Palm Too'},
#  {'name': "Steve'S Coffee Shop"},
#  {'name': 'Blue Bay Restaurant'},
#  {'name': 'Nada-Sushi'},
#  {'name': 'The Hytes Bar'},
#  {'name': 'Pergola Des Artistes'},
#  {'name': "Jody'S Club"},
#  {'name': "Reif'S Tavern"},
#  {'name': 'Whitestone Lanes'},
#  {'name': "John'S Pizzeria"},
#  {'name': 'Seashore Restaurant'},
#  {'name': 'White Horse Tavern'},
#  {'name': 'Caffe Reggio'},
#  {'name': 'Cafe Un Deux Trois'},
#  {'name': "Armando'S Pizza"},
#  {'name': 'Dan Tempura'},
#  {'name': 'Knickerbocker Bar & Grill'},
#  {'name': "Mcdonald'S"},
#  {'name': 'El Pote Espanol'},
#  {'name': 'Cafe Capri'},
#  {'name': 'Bronx Grill'},
#  {'name': 'The River Cafe'},
#  {'name': 'Mudville Saloon'},
#  {'name': "Johnny'S Reef Restaurant"},
#  {'name': 'White Castle'},
#  {'name': 'White Castle'},
#  {'name': 'White Castle'},
#  {'name': 'White Castle'},
#  {'name': "Ferdinando'S Restaurant"},
#  {'name': "Mcdonald'S"},
#  {'name': 'Viand Cafe'},
#  {'name': 'Nectar Coffee Shop'},
#  {'name': 'The Cupping Room'},
#  {'name': "Mcdonald'S"},
#  {'name': "Pete'S Tavern"},
#  {'name': "Gino'S Pizzeria"},
#  {'name': "Jim Brady'S Restaurant"},
#  {'name': 'Villa Mosconi Restaurant'},
#  {'name': "P & K'S Grill"},
#  {'name': "Mcdonald'S"},
#  {'name': 'Reme Restaurant'},
#  {'name': 'The New Amity Restaurant'},
#  {'name': 'Volare Restaurant'},
#  {'name': 'Sparks Steak House'},
#  {'name': 'The Dart Inn'},
#  {'name': "Bamonte'S Restaurant"},
#  {'name': 'Pizza Town'},
#  {'name': "Mcdonald'S"},
#  {'name': "John Mulligan'S Fireside Pub"},
#  {'name': 'Burger King'},
#  {'name': 'Ear Inn'},
#  {'name': 'Burger King'},
#  {'name': 'Burger King'},
#  {'name': 'Mughlai Restaurant'},
#  {'name': 'Greenpoint Tavern'},
#  {'name': "Mcdonald'S"},
#  {'name': "Tony'S Pizzeria"},
#  {'name': "Rossini'S"},
#  {'name': "Pat'S Stationary"},
#  {'name': "Three Guy'S Restaurant"},
#  {'name': 'Cucina Vivolo'},
#  {'name': 'The Players Club'},
#  {'name': 'Divers Cove'},
#  {'name': 'Tjk Cafe & Restaurant'},
#  {'name': 'Cafe Espanol'},
#  {'name': 'Smith & Wollensky'},
#  {'name': "Mcdonald'S"},
#  {'name': 'Olive Tree Cafe & Comedy Cellar'},
#  {'name': 'Perkins Family Restaurant & Bakery'},
#  {'name': 'Burger King'},
#  {'name': 'Burger King'},
#  {'name': 'Tokubei 86'},
#  {'name': 'Manducatis'},
#  {'name': 'Sizzler'},
#  {'name': 'Mama Lucia'},
#  {'name': 'Coliseum Bar Restaurant'},
#  {'name': 'Mariella Pizza'},
#  {'name': "Vinny'S Pizza"},
#  {'name': 'Kosher Delight'},
#  {'name': 'West Bank Cafe'},
#  {'name': 'The Four Seasons'},
#  {'name': 'La Baraka Restaurant'},
#  {'name': 'Dairy Luncheonette'},
#  {'name': "Zafi'S Luncheonette"},
#  {'name': 'La Palina Restaurant'},
#  {'name': "Schaffer'S Tavern"},
#  {'name': "Ty'S"},
#  {'name': "Aunt Bella'S Rest Of Little Neck"},
#  {'name': 'Mariner Inn'},
#  {'name': 'North Shore Diner'},
#  {'name': 'Exclusive Catering'},
#  {'name': 'Green House Cafe'},
#  {'name': "Mcdonald'S"},
#  {'name': 'Water Front Crab House'},
#  {'name': 'La Ripaille Restaurant'},
#  {'name': 'Marina Cafe'},
#  {'name': 'Don Filippo Restaurant'},
#  {'name': 'Burger King'},
#  {'name': 'Dazies Restaurant'},
#  {'name': 'Triestes Restaurant'},
#  {'name': 'Omonia Cafe'},
#  {'name': "Murals On 54/Randolphs'S"},
#  {'name': 'Veterans Of Foreign Wars Post #107 Canteen'},
#  {'name': 'Caruso Pizza #2'},
#  {'name': 'Tropical House Baking Co.'},
#  {'name': 'Burger King'},
#  {'name': 'Yankee Jz Pizza'},
#  {'name': 'Clinton Restaurant'},
#  {'name': 'Shabu-Shabu 70 Restaurant'},
#  {'name': "Chen'S Chinese"},
#  {'name': 'The Greek Corner'},
#  {'name': 'Racquet & Tennis Club'},
#  {'name': 'Casa Pepe'},
#  {'name': 'Astro Restaurant'},
#  {'name': 'Golden Dove Diner'},
#  {'name': 'Caffe Dante'},
#  {'name': 'Korner Pizzeria'},
#  {'name': "Henry'S End"},
#  {'name': 'Souen Restaurant'},
#  {'name': 'Villa Berulia'},
#  {'name': "Victor'S Cafe"},
#  {'name': 'Petes Pizzeria & Restaurant'},
#  {'name': 'Keens Steakhouse'},
#  {'name': 'Bar 515'},
#  {'name': 'Ready Penny Inn'},
#  {'name': 'Il Mulino'},
#  {'name': 'Felidia Restaurant'},
#  {'name': "Mcdonald'S"},
#  {'name': 'The Malt House'},
#  {'name': 'Shun Lee'},
#  {'name': 'Ihop'},
#  {'name': 'Bridgeview Diner'},
#  {'name': "Burke'S Pub"},
#  {'name': 'Hill Tap Tavern'},
#  {'name': 'Pongsri Thai Restaurant'},
#  {'name': 'Primavera Pizza & Pasta'},
#  {'name': "Tony'S Pier Restaurant"},
#  {'name': "Elio'S"},
#  {'name': 'Quality Cafe & Restaurant'},
#  {'name': 'Kasteli Ii'},
#  {'name': 'Victoria Pizza'},
#  {'name': 'Molly Wee Pub'},
#  {'name': 'La Mediterranee Restaurant'},
#  {'name': 'El Caribe'},
#  {'name': 'Omen Japanese Cuisine'},
#  {'name': "Mcdonald'S"},
#  {'name': "Mcdonald'S"},
#  {'name': 'Bar Vetro'},
#  {'name': "Rosie O'Grady Restaurant"},
#  {'name': 'Europa Go-Go Dancing'},
#  {'name': 'Casa Bella'},
#  {'name': 'Raccoon Lodge'},
#  {'name': 'Chez Napolean'},
#  {'name': "Turkey'S Nest Tavern"},
#  {'name': 'Sabrosura Restaurant'},
#  {'name': 'La Villa De Pizza & Restaurant'},
#  {'name': 'Ozone Pizzeria'},
#  {'name': 'Ponticello Restaurant'},
#  {'name': 'Agra Restaurant'},
#  {'name': "Lindy'S"},
#  {'name': "Arturo'S"},
#  {'name': 'Paris Blues'},
#  {'name': "Gene'S Resturant"},
#  {'name': 'Maria Ristorante'},
#  {'name': 'Cozy Soup & Burger'},
#  {'name': "Neron'S Pizza"},
#  {'name': 'Villa Fiorita'},
#  {'name': 'Vegas Diner'},
#  {'name': 'Moms Luncheonette'},
#  {'name': 'Candle Bar'},
#  {'name': 'Tevere 84'},
#  {'name': 'Haagen-Dazs'},
#  {'name': 'Fontana Famous Pizza & Gyro'},
#  {'name': "Charlie'S Mom Chinese Restaurant"},
#  {'name': "Lusardi'S Restaurant"},
#  {'name': 'Portofino'},
#  {'name': "King'S Arms Restaurant"},
#  {'name': 'Blue Note Jazz'},
#  {'name': 'The Water Club'},
#  {'name': 'Marco Polo Ristorante'},
#  {'name': 'Manhattan Monster'},
#  {'name': 'American Museum Of Natural History Food Court'},
#  {'name': 'War Memorial Ice Skating Rink'},
#  {'name': 'Tripoli Restaurant'},
#  {'name': 'Chez Jaqueline'},
#  {'name': 'Pj Bernstein Deli & Restaurant'},
#  {'name': "Pj Carney'S"},
#  {'name': "Water'S Edge Club"},
#  {'name': 'Tomoe Sushi'},
#  {'name': 'Amsterdam Restaurant & Tapas Lounge'},
#  {'name': "Jp'S Waterside Restaurant"},
#  {'name': 'Rogers Irish Tavern'},
#  {'name': 'John & Joe Pizzeria & Restaurant'},
#  {'name': 'Sunset Pizzeria'},
#  {'name': "Mcdonald'S"},
#  {'name': 'Utopia Restaurant'},
#  {'name': 'Jackson Hole'},
#  {'name': 'Napoli Pizza'},
#  {'name': 'Vesuvio Restaurant & Pizza'},
#  {'name': 'Western Bakery'},
#  {'name': 'Johns Cafe & Resturant'},
#  {'name': 'Karavas Place'},
#  {'name': 'Cafe Luxembourg'},
#  {'name': 'Windjammers Bar'},
#  {'name': "Dunkin' Donuts/Baskin' Robbins"},
#  {'name': 'Broadway Restaurant'},
#  {'name': 'Narita Japanese Restaurant'},
#  {'name': 'Cuchifrito'},
#  {'name': "Mary Ann'S"},
#  {'name': 'Red Rose'},
#  {'name': "Tony'S Pizza"},
#  {'name': 'Fiorentino Ristorante'},
#  {'name': "Port O' Calls"},
#  {'name': 'Il Cantinori Restauraunt'},
#  {'name': 'Andrews Coffee Shop'},
#  {'name': "Mike'S Pub"},
#  {'name': 'The Clubhouse'},
#  {'name': 'Kang Suh Korean Restaurant'},
#  {'name': 'Fame Diner'},
#  {'name': 'Knights Of Baron Dekalb'},
#  {'name': 'Union Hall'},
#  {'name': 'Kosher Hut Of Brooklyn'},
#  {'name': 'Terra Blues'},
#  {'name': "Caesar'S Palace"},
#  {'name': 'Flamingo'},
#  {'name': "Monte'S"},
#  {'name': 'Gotham Bar & Grill'},
#  {'name': "Mcaleer'S Pub"},
#  {'name': 'London Lennies'},
#  {'name': "Dunkin' Donuts"},
#  {'name': 'Cooper Town Diner'},
#  {'name': "Delmonico'S Kitchen"},
#  {'name': 'Hasaki Restaurant'},
#  {'name': 'Imperial Coffee House'},
#  {'name': 'Mezzaluna'},
#  {'name': 'Restuarant Nippon'},
#  {'name': "O'Hara'S"},
#  {'name': 'Aqueduct North'},
#  {'name': "Mcdonald'S"},
#  {'name': 'E.A.T. Cafe'},
#  {'name': 'Yankee Clipper'},
#  {'name': 'Rex Manor'},
#  {'name': 'Cuchifritos'},
#  {'name': 'Club 101'},
#  {'name': 'Riverdale Diner'},
#  {'name': 'Carlos Pizza'},
#  {'name': 'The Bitter End'},
#  {'name': 'Arriba Arriba'},
#  {'name': 'Geido Restaurant'},
#  {'name': 'Barney Greengrass'},
#  {'name': 'Petrossian Restauraunt'},
#  {'name': 'Annam Braham Restaurant'},
#  {'name': 'Supernova-Novotel Hotel'},
#  {'name': 'Montero Bar & Grill'},
#  {'name': 'Pisa Pizzeria'},
#  {'name': 'Porto Bello Restaurant'},
#  {'name': "Pete'S Clam Stop"},
#  {'name': 'Burrito Loco'},
#  {'name': 'Fit Cafeteria (Building A)'},
#  {'name': 'Smiling Pizza'},
#  {'name': "Riverhead Gentlemen'S Club"},
#  {'name': 'Symposium Greek Restaurant'},
#  {'name': 'Gandhi'},
#  {'name': "Nina'S Restaurant Pizzeria"},
#  {'name': 'Village Yokocho'},
#  {'name': "Clark'S Restaurant"},
#  {'name': 'Pietros'},
#  {'name': "Miss Lily'S 7A"},
#  {'name': 'Noho Star Restaurant'},
#  {'name': 'Rosa Mexicano'},
#  {'name': "Duffy'S"},
#  {'name': 'Uno Chicago Grill'},
#  {'name': 'Latourette Golf Course'},
#  {'name': 'Dyker Beach Golf (Grill Room)'},
#  {'name': "Glenda'S Restaurant"},
#  {'name': "My Father'S Place"},
#  {'name': 'Santa Fe Grill & Bar'},
#  {'name': 'Sidewalk Bar & Restaurant'},
#  {'name': "Coogan'S"},
#  {'name': "Mcdonald'S"},
#  {'name': 'Caffe Vivaldi'},
#  {'name': 'Castlehill Diner'},
#  {'name': "Tommy'S Pizza"},
#  {'name': 'Regency Hotel'},
#  {'name': "Parnell'S Pub"},
#  {'name': 'La Fe Restaurant'},
#  {'name': 'Ocean Dragon Restaurant'},
#  {'name': "Mom'S Fried Chicken"},
#  {'name': 'Cobblestone Pub'},
#  {'name': "Cha Cha'S Backyard Garden Bar & Cafe"},
#  {'name': "O'Sullivan'S Pub"},
#  {'name': 'Spring St. Natural Restaurant'},
#  {'name': 'Pizza Wagon'},
#  {'name': 'Russian Turkish Baths'},
#  {'name': 'Tortilla Flats'},
#  {'name': 'Il Toscano Ristorante'},
#  {'name': 'Pier 25A Restaurant'},
#  {'name': 'Sistina Restaurant'},
#  {'name': "Gaby'S Pizza"},
#  {'name': 'Verdi Restaurant'},
#  {'name': 'Cornelia Street Cafe'},
#  {'name': 'Le Bernardin'},
#  {'name': 'The Grotto'},
#  {'name': "Tony'S Pizzeria"},
#  {'name': "Brandy'S Piano Bar"},
#  {'name': 'Real Madrid Restaurant'},
#  {'name': "Canlon'S Restaurant"},
#  {'name': "Cousin John'S Cafe And Bakery"},
#  {'name': 'Jackson Hole'},
#  {'name': 'Short Stop Restaurant'},
#  {'name': 'Russian Samovar'},
#  {'name': 'Barone Pizza'},
#  {'name': 'Flash Dancers'},
#  {'name': "Pizza D'Oro"},
#  {'name': "Mcdonald'S"},
#  {'name': "Josie'S Restaurant"},
#  {'name': 'Phil & Sons Restaurant & Pizzeria'},
#  {'name': 'La Mela Restaurant'},
#  {'name': 'Pj Morans'},
#  {'name': 'Omega Coffee Shop'},
#  {'name': 'Friend Of A Farmer'},
#  {'name': 'Frankie & Johnnies Steakhouse'},
#  {'name': "Sancho'S Restaurant"},
#  {'name': 'Dream Pizza'},
#  {'name': 'India Passage Restaurant'},
#  {'name': 'Burger Barn Restaurant'},
#  {'name': "Irene'S Place"},
#  {'name': 'Kanes Deli Diner'},
#  {'name': 'Veselka Restaurant'},
#  {'name': 'White Castle'},
#  {'name': 'J & R Pizza'},
#  {'name': 'Chez Josephine'},
#  {'name': 'Mishima Restaurant'},
#  {'name': "Dunkin' Donuts/Baskin Robbins"},
#  {'name': 'Victory Sweet Shop'},
#  {'name': "Rocco'S Calamari"},
#  {'name': 'Cafe Edison'},
#  {'name': 'Grand Canyon'},
#  {'name': 'Cappuccino Cafe'},
#  {'name': "Carol'S Cafe"},
#  {'name': 'Pangea Restaurant'},
#  {'name': 'Automatic Slims'},
#  {'name': 'De Robertis Pastry Shop'},
#  {'name': 'Cloister Cafe'},
#  {'name': "Jimbo'S Hamburger Place"},
#  {'name': 'Dairy Palace'},
#  {'name': '200 Fifth Avenue Restaurant & Sports Bar'},
#  {'name': 'Va Bene'},
#  {'name': 'Lattanzi'},
#  {'name': 'Pizza Garden'},
#  {'name': 'Island'},
#  {'name': 'Sushiden'},
#  {'name': 'Lefkos Pygos Cafe'},
#  {'name': 'Eastwood Manor'},
#  {'name': 'Salumeria Beillese/ Biricchino Rest'},
#  {'name': 'Academy Restauraunt'},
#  {'name': 'Park Plaza Restaurant'},
#  {'name': 'Trattoria Alba'},
#  {'name': "Sam'S Place"},
#  {'name': "Ray'S Pizza"},
#  {'name': "Hunter'S Steak & Ale House"},
#  {'name': "Ljubo'S Pizzeria"},
#  {'name': 'Dakota Diner'},
#  {'name': 'Primola Restaurant'},
#  {'name': 'Arirang Hibachi Steak House'},
#  {'name': "Wendy'S"},
#  {'name': 'Country Donuts'},
#  {'name': 'Doral Donuts'},
#  {'name': "Sally & George'S Place"},
#  {'name': 'Jacks Ale House'},
#  {'name': 'Venice Pizza'},
#  {'name': "Winnie'S Bar"},
#  {'name': 'Pizza Plus'},
#  {'name': 'Niles Restaurant'},
#  {'name': "Tasty'S"},
#  {'name': 'Oakland Cafeteria/Queensborough Community College'},
#  {'name': 'Q.B.Comm.College-Main Kitchen/Tiger Bites Pizza Section'},
#  {'name': 'China Grill'},
#  {'name': 'New York University - Law School'},
#  {'name': 'Karavas Pizza N Pita'},
#  {'name': "Erin'S Isle"},
#  {'name': "Tina'S Restaurant"},
#  {'name': 'Westside Restaurant'},
#  {'name': 'Sal And Carmine Pizza'},
#  {'name': 'White Castle'},
#  {'name': "Rocco'S Pizzeria"},
#  {'name': 'Periyali'},
#  {'name': 'Club Metropolitan'},
#  {'name': "Frank'S Soup Bowl"},
#  {'name': 'Copper Kettle'},
#  {'name': 'Sanremo Pizza'},
#  {'name': 'Arno Ristorante'},
#  {'name': 'Science Cafe (Queensborough  Community College)'},
#  {'name': 'White Castle'},
#  {'name': 'El Azteca Mexican Restaurant'},
#  {'name': "T & G Whitney'S"},
#  {'name': "Lupe'S East L.A. Kitchen"},
#  {'name': 'Due'},
#  {'name': 'La Casa Del Pollo Restaurant'},
#  {'name': "Pellegrino'S"},
#  {'name': 'White Castle'},
#  {'name': 'Da Umberto Restaurant'},
#  {'name': 'White Castle'},
#  {'name': "Teddy'S Bar And Grill"},
#  {'name': 'Live Bait Bar & Restaurant'},
#  {'name': 'Jimmy Max Restaurant'},
#  {'name': 'Peculiar Pub'},
#  {'name': "T.G.I. Friday'S"},
#  {'name': 'Uno Chicago Grill'},
#  {'name': 'Cafe Lalo'},
#  {'name': "Arturo'S Pizza"},
#  {'name': 'Tal Bagels Deli'},
#  {'name': 'Nostrand Island Eatery'},
#  {'name': 'Venice Restaurant'},
#  {'name': 'Walnut Bus Stop'},
#  {'name': "Kelly'S Pub"},
#  {'name': 'Rosebank Tavern'},
#  {'name': 'Trattoria Della Arte'},
#  {'name': 'Areo Restaurant'},
#  {'name': 'Green Pavilion Restaurant & Sports Lounge'},
#  {'name': 'Westway Diner'},
#  {'name': 'Rocking Horse Cafe'},
#  {'name': 'Tre Giovani Pizza & Pasta'},
#  {'name': 'Galicia Restaurant'},
#  {'name': 'Lenox Hill Grill/Pizza'},
#  {'name': "T.G.I. Friday'S"},
#  {'name': "Wendy'S"},
#  {'name': 'Masawa'},
#  {'name': "Luigi'S Pizza"},
#  {'name': "Sob'S"},
#  {'name': "Yip'S"},
#  {'name': 'Scaletta Ristorante'},
#  {'name': "Walker'S Restaurant"},
#  {'name': 'Holland Bar'},
#  {'name': 'Lucky Pizza'},
#  {'name': 'The Pizza Place'},
#  {'name': 'Amnon Kosher Pizza'},
#  {'name': 'White Castle'},
#  {'name': "T.G.I. Friday'S"},
#  {'name': 'Angelica Kitchen'},
#  {'name': 'Cowgirl Hall Of Fame'},
#  {'name': 'Pipers Kilt'},
#  {'name': "Lee'S Villa Chinese Restaurant"},
#  {'name': 'Isla Restauraunt'},
#  {'name': 'Famous Famiglia Pizza'},
#  {'name': "Champ'S Deli"},
#  {'name': "Spoto'S Restaurant"},
#  {'name': 'Puttin On A Bagel'},
#  {'name': 'Dive Bar'},
#  {'name': 'Bennys Burritos'},
#  {'name': 'Brooklyn Botanic Catering Hall'},
#  {'name': 'Glendale Pizza'},
#  {'name': 'The Cornell Center Of New York'},
#  {'name': "Queen Bee'S Tavern"},
#  {'name': 'Nectar Of 82Nd Street'},
#  {'name': 'White Castle'},
#  {'name': 'Bella Luna'},
#  {'name': "T.G.I. Friday'S"},
#  {'name': 'Baskin Robbins'},
#  {'name': '2A'},
#  {'name': 'Sette Mezzo'},
#  {'name': "Teresa'S Resturant"},
#  {'name': "Yama Japanese Restaurant'"},
#  {'name': "Chadwick'S"},
#  {'name': 'Dallas Bbq'},
#  {'name': 'La Rivista Restaurant'},
#  {'name': 'El Castillo De Jagua Rest'},
#  {'name': 'Pax Wholesome Foods'},
#  {'name': 'Sakebar Decibel'},
#  {'name': 'T.G.I. Fridays'},
#  {'name': 'Bagel Cafe'},
#  {'name': "Benny'S Burritos"},
#  {'name': 'Guayoyo'},
#  {'name': 'Sacco Pizza'},
#  {'name': "Sac'S Pizza Place"},
#  {'name': 'Rivoli Pizza Restaurant'},
#  {'name': 'Royal Pizza'},
#  {'name': 'Da Tommasso'},
#  {'name': 'Baybridge Szechuan Restaurant'},
#  {'name': 'Lucky Strike'},
#  {'name': 'Ideal Donut'},
#  {'name': "Tom'S Restaurant"},
#  {'name': 'Campeon'},
#  {'name': "Vinny'S Famous Pizza"},
#  {'name': 'Townhouse Of Ny'},
#  {'name': 'Dallas Bbq'},
#  {'name': "Rino'S"},
#  {'name': 'Bliss Street Station Restaurant'},
#  {'name': 'Uno Chicago Grill'},
#  {'name': "Rosa'S Pizza"},
#  {'name': 'Ah! Chihuahua'},
#  {'name': 'Giando'},
#  {'name': 'Champ Gourmet'},
#  {'name': 'Austin House'},
#  {'name': 'Wharf Bar And Grill'},
#  {'name': 'Classic Coffee Shop'},
#  {'name': 'Queen'},
#  {'name': 'O G Restaurant'},
#  {'name': 'Pomodoro Ristorante'},
#  {'name': 'Quatorze Bistro'},
#  {'name': '5 Burro Cafe'},
#  {'name': "Lucho'S Place"},
#  {'name': "Cleopatra'S Needle"},
#  {'name': 'Barfly'},
#  {'name': 'Haveli'},
#  {'name': 'Cho-Sen Garden'},
#  {'name': "O'Flanagan'S"},
#  {'name': 'Papazzio Restaurant'},
#  {'name': 'Villa Barone Manor'},
#  {'name': "The Famous Jimbo'S Hamburger Palace"},
#  {'name': 'Taste Of India Ii Restaurant'},
#  {'name': 'Stage Door Deli'},
#  {'name': 'Kum Kau Kitchen'},
#  {'name': 'Danny Blaine'},
#  {'name': 'Han Bat Restaurant'},
#  {'name': "Caterina'S Pizza"},
#  {'name': "Dennis' Place"},
#  {'name': 'White Castle'},
#  {'name': "Joey'S Place"},
#  {'name': 'Loui Seafood'},
#  {'name': 'Irish Brigade'},
#  {'name': 'The Edge Bar'},
#  {'name': 'Cafe Luna'},
#  {'name': "Scotty'S Diner"},
#  {'name': "Killarney'S Pub"},
#  {'name': 'Miracali Bakery'},
#  {'name': "Daniel'S Bagel"},
#  {'name': 'Kabab Cafe'},
#  {'name': "Luke'S Bar & Grill"},
#  {'name': 'A & S Pizzeria'},
#  {'name': 'Solera Restaurant'},
#  {'name': 'Belaire Cafe'},
#  {'name': 'Lazzaras Pizza Cafe'},
#  {'name': 'Little Pie Company'},
#  {'name': "Malachy'S"},
#  {'name': 'Bello Restaurant'},
#  {'name': 'Pronto Pizza'},
#  {'name': 'Grotto Azzura Pizzeria'},
#  {'name': 'The Palace Theater'},
#  {'name': "Sybil'S Bakery"},
#  {'name': "Richer'S Bakery"},
#  {'name': 'El Lina Restaurant'},
#  {'name': 'Bar Association Of The City Of Ny Kitchen'},
#  {'name': 'Bay Ridge Manor Catering'},
#  {'name': '3 Guys'},
#  {'name': "Vaccaro'S Pizzeria & Trattoria"},
#  {'name': "Gleason'S Cafe"},
#  {'name': 'Air France Lounge'},
#  {'name': 'The Beekman'},
#  {'name': 'Peking Restaurant'},
#  {'name': 'Vico Ristorante'},
#  {'name': 'Szechuan Delight Restaurant'},
#  {'name': 'Tea And Sympathy'},
#  {'name': 'Bel Paese Italian Deli'},
#  {'name': 'Collado Restaurant'},
#  {'name': 'Taka Hashi Restaurant'},
#  {'name': "Mcdonald'S"},
#  {'name': 'Tokya'},
#  {'name': "Mcdonald'S"},
#  {'name': 'Orso'},
#  {'name': 'H & H Midtown Bagels East'},
#  {'name': 'White Castle'},
#  {'name': "Lily'S Bar @ Roger Smith Hotel"},
#  {'name': 'Ihop'},
#  {'name': 'Hillside Swimming Club'},
#  {'name': 'La Strada Restaurant'},
#  {'name': 'The Nippon Club'},
#  {'name': 'Sutton Cafe Restaurant'},
#  {'name': "Walter'S Bar"},
#  {'name': "Salvatore And Lloyd'S Pizza"},
#  {'name': 'Novecento'},
#  {'name': 'Beyoglu'},
#  {'name': 'Fordham Seafood And Chicken'},
#  {'name': 'Fay Da Bakery'},
#  {'name': 'Cambridge Caterers'},
#  {'name': "Mcdonald'S"},
#  {'name': "Charle'S Corner Restaurant & Deli"},
#  {'name': 'Cafe Bella Vita'},
#  {'name': 'Absolute Bagels'},
#  {'name': 'B.Q.E. Cafe Billiards'},
#  {'name': 'Tal Bagel'},
#  {'name': "Dunkin' Donuts"},
#  {'name': 'Ipanema Bar'},
#  {'name': 'Tartine'},
#  {'name': 'Henrietta Hudson'},
#  {'name': "Sal'S Pizzeria"},
#  {'name': 'Lucys'},
#  {'name': 'Dojo Restaurant'},
#  {'name': "Gabriel'S Bar & Grill"},
#  {'name': 'Nueva Villa China Restaurant'},
#  {'name': 'Jaiya Thai Oriental Restaurant'},
#  {'name': 'Bergen Beach Cafe'},
#  {'name': 'Ihop'},
#  {'name': 'El Cantinero'},
#  {'name': "Molly'S"},
#  {'name': 'Azuri Cafe'},
#  {'name': "Amelia'S Restaurant"},
#  {'name': 'National Restaurant & Catering'},
#  {'name': 'Jackson House Restaurant'},
#  {'name': 'Georgia Diner'},
#  {'name': 'Patrick Conways'},
#  {'name': 'Metrostar Cafe'},
#  {'name': 'Scalinatella Ristaurant'},
#  {'name': "Friend'S Tavern"},
#  {'name': 'Rincon Salvadoreno Restaurant'},
#  {'name': 'La Nueva Victoria Restaurant'},
#  {'name': 'Amsterdam Billiards'},
#  {'name': 'Yen Yen Restaurant'},
#  {'name': "Buddy'S Burrito & Taco Bar"},
#  {'name': 'Oasis Cafe'},
#  {'name': 'White Castle'},
#  {'name': 'Demarchelier Restaurant'},
#  {'name': 'E.J Luncheonette'},
#  {'name': 'Court Square Diner'},
#  {'name': 'V & S Pizzeria Of Sheapshead Bay'},
#  {'name': 'Davis Polk Dining Room'},
#  {'name': "Mcdonald'S"},
#  {'name': 'Bella Napoli'},
#  {'name': "Cody'S Ale House Grill"},
#  {'name': 'Down The Hatch'},
#  {'name': 'J.J. Bubbles'},
#  {'name': "Fitzgerald'S Pub"},
#  {'name': 'Faros Restaurant'},
#  {'name': 'Gun Post Lanes Snack Bar'},
#  {'name': 'Pasta Lovers Trattoria'},
#  {'name': 'Don Giovanni Restaurant'},
#  {'name': 'Los Toldos Restaurant'},
#  {'name': "Glen Patrick'S Pub"},
#  {'name': 'El Molino Rojo Restaurant'},
#  {'name': 'Shabu Tatsu'},
#  {'name': 'Tribeca Grill'},
#  {'name': 'Popeyes Chicken & Biscuits'},
#  {'name': 'C & B Luncheonette'},
#  {'name': 'San Pietro'},
#  {'name': 'Indo Chine'},
#  {'name': "Dunkin' Donuts"},
#  {'name': "Glen Patrick'S Pub"},
#  {'name': 'Muldoons Bar'},
#  {'name': 'Pizza Boy Ii'},
#  {'name': 'Grandstand Tavern'},
#  {'name': 'Julliard & S.A.B. Cafeteria'},
#  {'name': "Tony'S Pizza Ii"},
#  {'name': "Manetta'S Ristorante"},
#  {'name': 'Niagara/ Lovers Of Today/ Cabin Down Below'},
#  {'name': "O'Brien'S Pub"},
#  {'name': 'Salvi Restaurant'},
#  {'name': 'Tibbett Diner'},
#  {'name': 'White Castle'},
#  {'name': 'Delmonico Gourmet'},
#  {'name': 'Flight 151'},
#  {'name': 'Garden Of Eat-In'},
#  {'name': "Sandy'S Deli & Roti"},
#  {'name': 'Bombay Masala'},
#  {'name': 'Jackson Hole'},
#  {'name': 'Cronin & Phelan Pub & Restaurant'},
#  {'name': 'Pizza Plate'},
#  {'name': 'San Remo Pizza'},
#  {'name': 'Topaz Thai Restaurant'},
#  {'name': 'Moonstruck East'},
#  {'name': 'Pascalou'},
#  {'name': 'Tommaso Restaurant'},
#  {'name': "Frank'S Pizza Restaurant"},
#  {'name': 'Da Rosina Restaurant'},
#  {'name': "Abitino'S Pizza"},
#  {'name': 'Little Poland Restaurant'},
#  {'name': 'Empire Szechuan Noodle House'},
#  {'name': 'Island Taste'},
#  {'name': 'Piccolo Angolo'},
#  {'name': 'Master Wok'},
#  {'name': 'Bar Six'},
#  {'name': 'Baraonda'},
#  {'name': 'A.J. Pizzeria'},
#  {'name': 'Mateus Restaurant'},
#  {'name': "Luigi'S Restaurant"},
#  {'name': 'Marumi'},
#  {'name': 'Members Dining Room @ The Met Museum'},
#  {'name': 'The Restaurant'},
#  {'name': "Egger'S Ice Cream Parlor"},
#  {'name': "Gino'S Pizza"},
#  {'name': 'The End Zone Bar'},
#  {'name': 'Ambassador Dining Room  At Saratoga Family Inn'},
#  {'name': 'The Abbey Pub'},
#  {'name': 'Fine & Shapiro'},
#  {'name': 'E & L Bakery & Coffee Shop'},
#  {'name': "Caroline'S On Broadway"},
#  {'name': 'Wembley Athletic Club'},
#  {'name': "Cullen'S Tavern"},
#  {'name': 'The Upper Crust'},
#  {'name': 'Las Isla Restaurant'},
#  {'name': 'Campagnola Restaurant'},
#  {'name': 'Tuscany Grill'},
#  {'name': "Russo'S On The Bay"},
#  {'name': 'Buccaneer Diner'},
#  {'name': 'Jing Fong Restaurant'},
#  {'name': 'American Airlines Employee Cafeteria'},
#  {'name': 'Becco'},
#  {'name': "Dunkin' Donuts"},
#  {'name': "Rudy'S Bar & Grill"},
#  {'name': "Austin'S Steak & Ale House"},
#  {'name': 'Coyote Ugly'},
#  {'name': 'Prima Pasta & Cafe'},
#  {'name': "Gino'S Pizzeria Restaurant"},
#  {'name': "Tony'S Pizzeria & Restaurant"},
#  {'name': 'Uncle Vanya'},
#  {'name': 'Uno Chicago Grill'},
#  {'name': "Dempsey'S Pub"},
#  {'name': 'Winchesters Pub'},
#  {'name': 'Cafe Cardini'},
#  {'name': 'T-Bone Diner'},
#  {'name': 'Sunrise Coffee Shop'},
#  {'name': 'My Three Sons Restaurant'},
#  {'name': 'Chicken Delicious'},
#  {'name': 'Felix'},
#  {'name': "Mike'S Donuts"},
#  {'name': "Ilda'S Place Ii"},
#  {'name': 'Le Petit Cafe'},
#  {'name': 'Broadway Station'},
#  {'name': 'Porto Prince Star Restaurant'},
#  {'name': 'White Castle'},
#  {'name': 'Alpha Donuts'},
#  {'name': 'Mcdonald Avenue Diner'},
#  {'name': "Mezcal'S Dos Restaurant"},
#  {'name': 'Sugar Bun Bakery'},
#  {'name': 'Country Donuts'},
#  {'name': "Frank'S Place"},
#  {'name': 'Elmhurst Famous Pizza'},
#  {'name': "Mcdonald'S"},
#  {'name': 'Camilles'},
#  {'name': 'Olympic Flame Diner'},
#  {'name': 'Indigo Indian Cuisine'},
#  {'name': 'Caruso Pizzeria & Restaurant'},
#  {'name': 'Java Restaurant'},
#  {'name': 'Tequilla Sunrise'},
#  {'name': 'Les Halles'},
#  {'name': 'Pizza Nosh'},
#  {'name': 'Caridad Restaurant'},
#  {'name': 'White Castle'},
#  {'name': 'The Stumble Inn'},
#  {'name': 'Rosa #2 Pizzeria'},
#  {'name': "Mcdonald'S"},
#  {'name': 'Golden Pizza'},
#  {'name': "Mcdonald'S"},
#  {'name': "Mcdonald'S"},
#  {'name': 'Hot & Crusty Bakery'},
#  {'name': 'Jules Bistro'},
#  {'name': 'Il Violino'},
#  {'name': 'French Roast'},
#  {'name': "Smiler'S Deli"},
#  {'name': 'Chick-N-Ribs'},
#  {'name': 'Two Boots To Go-Go'},
#  {'name': "Mendy'S"},
#  ...]

# %%
#Mostrar los campos restaurant_id, nombre, distrito y cocina, pero excluya el campo _id para todos los documentos de la colección restaurantes

list(restaurantes.find({'borough':'Bronx'},{'_id':0,'restaurant_id':1,'name':1,'borough':1,'cuisine':1}))
# Out:
# [{'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Morris Park Bake Shop',
#   'restaurant_id': '30075445'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Wild Asia',
#   'restaurant_id': '40357217'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363093'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden',
#   'restaurant_id': '40363289'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden',
#   'restaurant_id': '40364296'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Manhem Club',
#   'restaurant_id': '40364363'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The New Starling Athletic Club Of The Bronx',
#   'restaurant_id': '40364956'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Yankee Tavern',
#   'restaurant_id': '40365499'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Mcdwyers Pub',
#   'restaurant_id': '40365893'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The Punch Bowl',
#   'restaurant_id': '40366497'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Munchtime',
#   'restaurant_id': '40366748'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop',
#   'restaurant_id': '40366833'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': "Lulu'S Coffee Shop",
#   'restaurant_id': '40366938'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Marina Delray',
#   'restaurant_id': '40367161'},
#  {'borough': 'Bronx',
#   'cuisine': 'Not Listed/Not Applicable',
#   'name': "The Lark'S Nest",
#   'restaurant_id': '40367946'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Terrace Cafe',
#   'restaurant_id': '40368018'},
#  {'borough': 'Bronx',
#   'cuisine': 'African',
#   'name': 'African Terrace',
#   'restaurant_id': '40368021'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Cool Zone',
#   'restaurant_id': '40368022'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Beaver Pond',
#   'restaurant_id': '40368025'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'African Market (Baboon Cafe)',
#   'restaurant_id': '40368026'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Blue Bay Restaurant',
#   'restaurant_id': '40369087'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Seashore Restaurant',
#   'restaurant_id': '40369299'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Bronx Grill',
#   'restaurant_id': '40369601'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Johnny'S Reef Restaurant",
#   'restaurant_id': '40369641'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40369669'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "P & K'S Grill",
#   'restaurant_id': '40369895'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40369915'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "John Mulligan'S Fireside Pub",
#   'restaurant_id': '40370150'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40372196'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Yankee Jz Pizza',
#   'restaurant_id': '40372631'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop',
#   'restaurant_id': '40373938'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Tony'S Pier Restaurant",
#   'restaurant_id': '40374136'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Quality Cafe & Restaurant',
#   'restaurant_id': '40374259'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese/Cuban',
#   'name': 'Sabrosura Restaurant',
#   'restaurant_id': '40375136'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Jp'S Waterside Restaurant",
#   'restaurant_id': '40377124'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'John & Joe Pizzeria & Restaurant',
#   'restaurant_id': '40377243'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tony'S Pizza",
#   'restaurant_id': '40378347'},
#  {'borough': 'Bronx',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts",
#   'restaurant_id': '40379573'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Aqueduct North',
#   'restaurant_id': '40379894'},
#  {'borough': 'Bronx',
#   'cuisine': 'Spanish',
#   'name': 'Cuchifritos',
#   'restaurant_id': '40380164'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Riverdale Diner',
#   'restaurant_id': '40380253'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Castlehill Diner',
#   'restaurant_id': '40382517'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tommy'S Pizza",
#   'restaurant_id': '40382652'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': "Mom'S Fried Chicken",
#   'restaurant_id': '40382900'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Short Stop Restaurant',
#   'restaurant_id': '40383819'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Burger Barn Restaurant',
#   'restaurant_id': '40384486'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Eastwood Manor',
#   'restaurant_id': '40385680'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Ljubo'S Pizzeria",
#   'restaurant_id': '40385955'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S",
#   'restaurant_id': '40386062'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Venice Pizza',
#   'restaurant_id': '40386278'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': "Frank'S Soup Bowl",
#   'restaurant_id': '40386672'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40387143'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40387178'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Arturo'S Pizza",
#   'restaurant_id': '40387399'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Venice Restaurant',
#   'restaurant_id': '40387477'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Walnut Bus Stop',
#   'restaurant_id': '40387528'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S",
#   'restaurant_id': '40388016'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'The Pizza Place',
#   'restaurant_id': '40388253'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40388269'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Isla Restauraunt',
#   'restaurant_id': '40388392'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Spoto'S Restaurant",
#   'restaurant_id': '40388462'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': 'Bagel Cafe',
#   'restaurant_id': '40389011'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Vinny'S Famous Pizza",
#   'restaurant_id': '40389365'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Rino'S",
#   'restaurant_id': '40389594'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Villa Barone Manor',
#   'restaurant_id': '40390266'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Loui Seafood',
#   'restaurant_id': '40390814'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Gleason'S Cafe",
#   'restaurant_id': '40391375'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40391639'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham Seafood And Chicken',
#   'restaurant_id': '40392190'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Gun Post Lanes Snack Bar',
#   'restaurant_id': '40393563'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Molino Rojo Restaurant',
#   'restaurant_id': '40393688'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "O'Brien'S Pub",
#   'restaurant_id': '40394024'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Tibbett Diner',
#   'restaurant_id': '40394030'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'E & L Bakery & Coffee Shop',
#   'restaurant_id': '40394761'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Wembley Athletic Club',
#   'restaurant_id': '40394770'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Cullen'S Tavern",
#   'restaurant_id': '40394838'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40395511'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395653'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Golden Pizza',
#   'restaurant_id': '40395921'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395992'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Chick-N-Ribs',
#   'restaurant_id': '40396053'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40396399'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Pugsley Pizza',
#   'restaurant_id': '40396548'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40397219'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Dominick'S Bar & Restaurant",
#   'restaurant_id': '40397574'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Zaro'S Bread Basket",
#   'restaurant_id': '40397863'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Lechonera Criolla',
#   'restaurant_id': '40398642'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Enzo Cafe',
#   'restaurant_id': '40398852'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Joe'S Pizza",
#   'restaurant_id': '40398910'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': "Lolita'S Restaurant",
#   'restaurant_id': '40398958'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40399778'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bagels/Pretzels',
#   'name': 'Rolen Bagels',
#   'restaurant_id': '40399988'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Fordham Fried Chicken & Sea Food',
#   'restaurant_id': '40400799'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Celeste'S Snack Bar",
#   'restaurant_id': '40401250'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Pelham Bay Diner',
#   'restaurant_id': '40401316'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40402106'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Villa Barone',
#   'restaurant_id': '40402187'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Stuyvesant Yacht Club',
#   'restaurant_id': '40402679'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Riverdale Yacht Club',
#   'restaurant_id': '40402699'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Ambassador Diner',
#   'restaurant_id': '40403946'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bagels/Pretzels',
#   'name': 'Bagel Corner',
#   'restaurant_id': '40423450'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Kingston Tropical Bakery',
#   'restaurant_id': '40423481'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Concourse Jamaican Bakery',
#   'restaurant_id': '40423547'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Artuso Pastry Shop',
#   'restaurant_id': '40423571'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Champion Bakery',
#   'restaurant_id': '40423830'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Al Cholo Bakery',
#   'restaurant_id': '40424273'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Franco Bakery',
#   'restaurant_id': '40424765'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Biarritz Bakery',
#   'restaurant_id': '40424919'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': "Jackie'S West Indian Bakery",
#   'restaurant_id': '40424972'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Vaquero Barras',
#   'restaurant_id': '40510301'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'China Wok Ii',
#   'restaurant_id': '40510328'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Pitusa Bakery',
#   'restaurant_id': '40510823'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Woodlawn Cafe',
#   'restaurant_id': '40512207'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40512610'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Crown Diner',
#   'restaurant_id': '40512746'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40515211'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Artie'S",
#   'restaurant_id': '40515670'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Crosstown Diner',
#   'restaurant_id': '40515675'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Catania'S Pizza Cafe",
#   'restaurant_id': '40521624'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Jimmy Ryan'S",
#   'restaurant_id': '40524837'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Park Billiards',
#   'restaurant_id': '40524910'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40524973'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Full Moon Pizza',
#   'restaurant_id': '40525206'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Capri Ii Pizza',
#   'restaurant_id': '40525767'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Dragon City',
#   'restaurant_id': '40529203'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Nacional Bakery #1',
#   'restaurant_id': '40530630'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese/Cuban',
#   'name': 'New Pabellon De Oro Restaurant',
#   'restaurant_id': '40535823'},
#  {'borough': 'Bronx',
#   'cuisine': 'Spanish',
#   'name': 'Cosmos Restaurant',
#   'restaurant_id': '40538061'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Bowler Land',
#   'restaurant_id': '40539772'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Feeding Tree Style West Indian Restaurant',
#   'restaurant_id': '40541088'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Rio Cobre Restaurant',
#   'restaurant_id': '40545598'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Pasta Pasta Restaurant',
#   'restaurant_id': '40545786'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Ray'S Pizza Restuarant",
#   'restaurant_id': '40548730'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Louie'Sdale Diner",
#   'restaurant_id': '40549539'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'Montezuma Restaurant',
#   'restaurant_id': '40549885'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40549913'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40550801'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Hunan Balcony',
#   'restaurant_id': '40551996'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Great Wall Restaurant',
#   'restaurant_id': '40552226'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Boston Market',
#   'restaurant_id': '40553581'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'La Bella Rosa Bakery',
#   'restaurant_id': '40554018'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Kennedy Fried Chicken',
#   'restaurant_id': '40557466'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Isla Cuchifritos',
#   'restaurant_id': '40557901'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Keenans',
#   'restaurant_id': '40558516'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40559279'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Caridad Restaurant',
#   'restaurant_id': '40560308'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Lena Restaurant',
#   'restaurant_id': '40560823'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'La Perla Mexicana',
#   'restaurant_id': '40566706'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Sugar City Bakery',
#   'restaurant_id': '40568460'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Lopez'S Pizzeria And Coffee Shop",
#   'restaurant_id': '40568964'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Glen Roy Bar And Grill',
#   'restaurant_id': '40569838'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'An Beal Bocht Cafe',
#   'restaurant_id': '40570634'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'Diamante Poblano Restaurant',
#   'restaurant_id': '40570910'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Archer Sports Bar',
#   'restaurant_id': '40571081'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Lucky House Restaurant',
#   'restaurant_id': '40571587'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Shamrock Inn',
#   'restaurant_id': '40572406'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'New Wah Kitchen',
#   'restaurant_id': '40573101'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Crab Shanty',
#   'restaurant_id': '40573338'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Throgs Neck Clipper',
#   'restaurant_id': '40574209'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Cafe Lou'S",
#   'restaurant_id': '40575255'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Barries Restaurant',
#   'restaurant_id': '40576056'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Giralda Bakery',
#   'restaurant_id': '40578388'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'New Capital Restaurant',
#   'restaurant_id': '40585102'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Pelham Bake Shop',
#   'restaurant_id': '40587400'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40592181'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Yolanda Pizzeria Restaurant',
#   'restaurant_id': '40594879'},
#  {'borough': 'Bronx',
#   'cuisine': 'Greek',
#   'name': 'Gyro King',
#   'restaurant_id': '40596246'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40598230'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'City Island Diner /Snug Bar',
#   'restaurant_id': '40604207'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "P.J. Brady'S Tavern",
#   'restaurant_id': '40607093'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Bedford Cafe & Restaurant',
#   'restaurant_id': '40608422'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Capri Pizza Restaurant',
#   'restaurant_id': '40617679'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Pasquale Rigoletto Restaurant',
#   'restaurant_id': '40618281'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Webster Cafe',
#   'restaurant_id': '40618714'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tony'S Pizza",
#   'restaurant_id': '40620484'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Caffe Egidio',
#   'restaurant_id': '40621241'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Black Whale',
#   'restaurant_id': '40622037'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Express',
#   'restaurant_id': '40623708'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Billy'S Sport Bar Restaurant & Lounge",
#   'restaurant_id': '40624470'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Italia 1',
#   'restaurant_id': '40634607'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Steve'S Bakery",
#   'restaurant_id': '40644030'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Sabrosura',
#   'restaurant_id': '40645073'},
#  {'borough': 'Bronx',
#   'cuisine': 'Sandwiches',
#   'name': 'Blimpie',
#   'restaurant_id': '40649156'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'Los Girasoles Restaurant',
#   'restaurant_id': '40653926'},
#  {'borough': 'Bronx',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts",
#   'restaurant_id': '40654198'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Cafe Al Mercato',
#   'restaurant_id': '40654328'},
#  {'borough': 'Bronx',
#   'cuisine': 'Soul Food',
#   'name': "Sam'S Restaurant",
#   'restaurant_id': '40655946'},
#  {'borough': 'Bronx',
#   'cuisine': 'Steak',
#   'name': 'Riverdale Steak House',
#   'restaurant_id': '40656594'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Pepe Joes Pizzeria',
#   'restaurant_id': '40663973'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Gino'S Pastry Shop",
#   'restaurant_id': '40665681'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40665719'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': "Loeser'S Hebrew National",
#   'restaurant_id': '40666155'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40669100'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Firozas Roti Bar',
#   'restaurant_id': '40669394'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40671411'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Market Restaurant (C-D Block)',
#   'restaurant_id': '40674404'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': "Behan'S Pub",
#   'restaurant_id': '40675225'},
#  {'borough': 'Bronx',
#   'cuisine': 'Other',
#   'name': "Johnny'S O'S",
#   'restaurant_id': '40678067'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': "Joe'S Place",
#   'restaurant_id': '40680764'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40684999'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Bartow Pizza',
#   'restaurant_id': '40687266'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Fella'S Bar",
#   'restaurant_id': '40689434'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Checkers',
#   'restaurant_id': '40690910'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Sammy'S Fishbox",
#   'restaurant_id': '40691110'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Snack Bar (Located Between A-B Between Fancy Food And Masters)',
#   'restaurant_id': '40693095'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "J.R'S Cabaret",
#   'restaurant_id': '40693952'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Gary And Gino'S",
#   'restaurant_id': '40694187'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Parrilla Latina Steakhouse',
#   'restaurant_id': '40694273'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Nick Garden Coffee Shop',
#   'restaurant_id': '40699339'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Latino Restaurant',
#   'restaurant_id': '40699772'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'New Hing Restaurant',
#   'restaurant_id': '40701165'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Emilia'S Restaurant",
#   'restaurant_id': '40705438'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'Mi Pueblito Bakery/Comida Tipica Mexicana',
#   'restaurant_id': '40705983'},
#  {'borough': 'Bronx',
#   'cuisine': 'Barbecue',
#   'name': 'The Barbecue Pit',
#   'restaurant_id': '40716007'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Pine Bar & Grill',
#   'restaurant_id': '40717234'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Prospect Coffee Shop',
#   'restaurant_id': '40719693'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Barnes & Noble Booksellers',
#   'restaurant_id': '40722176'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40724205'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Market Place Pizza',
#   'restaurant_id': '40725375'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Jolly Tinker',
#   'restaurant_id': '40730115'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Angelica'S Bakery",
#   'restaurant_id': '40730301'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Captain'S Pizzeria And Restaurant",
#   'restaurant_id': '40731746'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40734703'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Portofino Cafe',
#   'restaurant_id': '40736253'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': "Ali'S Roti Shop",
#   'restaurant_id': '40738028'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Teresa'S Gourmet",
#   'restaurant_id': '40740446'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Susie'S Pies",
#   'restaurant_id': '40741630'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40742990'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40742997'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40743000'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40743359'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Picanteria El Botecito',
#   'restaurant_id': '40744238'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Nonis Coffee Shop',
#   'restaurant_id': '40747192'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Blue Diner',
#   'restaurant_id': '40747940'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Applebee'S Neighborhood Grill & Bar",
#   'restaurant_id': '40752494'},
#  {'borough': 'Bronx',
#   'cuisine': 'Juice, Smoothies, Fruit Salads',
#   'name': 'Bally Total Fitness',
#   'restaurant_id': '40752699'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Morris Park Pizza',
#   'restaurant_id': '40754765'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Circle Pizzeria',
#   'restaurant_id': '40755548'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Bella Napoli',
#   'restaurant_id': '40759930'},
#  {'borough': 'Bronx',
#   'cuisine': 'Juice, Smoothies, Fruit Salads',
#   'name': 'Astral Fitness & Wellness',
#   'restaurant_id': '40760469'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Hong Kong Restaurant',
#   'restaurant_id': '40765358'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Caridad',
#   'restaurant_id': '40781213'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Dancing Crane Cafe (Bx Zoo)',
#   'restaurant_id': '40793858'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40794103'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40794912'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Section 5 Pizza Restaurant',
#   'restaurant_id': '40799031'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Step In Restaurant & Lounge',
#   'restaurant_id': '40800483'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40800986'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40801605'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': "Kristy'S Restaurant",
#   'restaurant_id': '40804049'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'San German Cuchifrito',
#   'restaurant_id': '40810657'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'J & J Restaurant & Cuchifritos',
#   'restaurant_id': '40812317'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40814300'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Boulevard Tavern',
#   'restaurant_id': '40815627'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Shore Haven Diner',
#   'restaurant_id': '40815664'},
#  {'borough': 'Bronx',
#   'cuisine': 'Steak',
#   'name': "Jake'S Steakhouse",
#   'restaurant_id': '40819558'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Madison'S",
#   'restaurant_id': '40823884'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'East Dynasty',
#   'restaurant_id': '40827529'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40828609'},
#  {'borough': 'Bronx',
#   'cuisine': 'African',
#   'name': 'Ebe Ye Yie African Restaurant',
#   'restaurant_id': '40832718'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Malecon Restaurant',
#   'restaurant_id': '40837042'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': 'City Island Deli',
#   'restaurant_id': '40839264'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Gurra Cafe',
#   'restaurant_id': '40840124'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Lin Home Chinese Restaura',
#   'restaurant_id': '40842437'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'To Go Express',
#   'restaurant_id': '40843062'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Chirping Chicken',
#   'restaurant_id': '40847914'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Peacock Restaurant',
#   'restaurant_id': '40849313'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40849624'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40850448'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The Williamsbridge Tavern',
#   'restaurant_id': '40852754'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'Vista Hermosa Deli Restaurant',
#   'restaurant_id': '40853915'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Vivienne'S",
#   'restaurant_id': '40856176'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Starbucks Coffee',
#   'restaurant_id': '40856325'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': "Lin'S Garden",
#   'restaurant_id': '40857406'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40860841'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Casa Promesa',
#   'restaurant_id': '40861141'},
#  {'borough': 'Bronx',
#   'cuisine': 'Sandwiches',
#   'name': 'Subway',
#   'restaurant_id': '40862204'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Shalon Restaurant',
#   'restaurant_id': '40863225'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Broadway Pizza & Pasta',
#   'restaurant_id': '40863575'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40863944'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40863963'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40866315'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40866322'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40866340'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Mi Sueno Restaurant',
#   'restaurant_id': '40866951'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40868904'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40869179'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Mr Mcgoo'S",
#   'restaurant_id': '40869211'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Buen Ambiente',
#   'restaurant_id': '40869790'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Popeyes Chicken & Biscuits',
#   'restaurant_id': '40869873'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Liberato Restaurant',
#   'restaurant_id': '40871403'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Wilbel Pizza',
#   'restaurant_id': '40871979'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham University - Mcginley Center',
#   'restaurant_id': '40874831'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham University/Mcginley Center/Ramskeller Kitchen',
#   'restaurant_id': '40874915'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Seafood  City',
#   'restaurant_id': '40875290'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel',
#   'restaurant_id': '40876932'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham University - Millenium Grill',
#   'restaurant_id': '40877246'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': 'Fordham University - Student Deli',
#   'restaurant_id': '40877285'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'La Nueva Giralda Bakery',
#   'restaurant_id': '40877421'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Sheas Emerald',
#   'restaurant_id': '40883581'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Memories Lounge',
#   'restaurant_id': '40883866'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Roca Tone Seafood Restaurant',
#   'restaurant_id': '40885478'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'The Best Italian Pizza',
#   'restaurant_id': '40886422'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'J.E. Bakery',
#   'restaurant_id': '40890186'},
#  {'borough': 'Bronx',
#   'cuisine': 'Soul Food',
#   'name': 'Cea Lo Cafe',
#   'restaurant_id': '40890407'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Mug-Z'S Sports Bar",
#   'restaurant_id': '40891377'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Frank'S Pizzeria",
#   'restaurant_id': '40892887'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Nb. National Bakery',
#   'restaurant_id': '40897418'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'New Rainbow Restaurant',
#   'restaurant_id': '40899178'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Morris Park Bake Shop',
#   'restaurant_id': '30075445'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Wild Asia',
#   'restaurant_id': '40357217'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363093'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden',
#   'restaurant_id': '40363289'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden',
#   'restaurant_id': '40364296'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Manhem Club',
#   'restaurant_id': '40364363'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The New Starling Athletic Club Of The Bronx',
#   'restaurant_id': '40364956'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Yankee Tavern',
#   'restaurant_id': '40365499'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Mcdwyers Pub',
#   'restaurant_id': '40365893'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The Punch Bowl',
#   'restaurant_id': '40366497'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Munchtime',
#   'restaurant_id': '40366748'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop',
#   'restaurant_id': '40366833'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': "Lulu'S Coffee Shop",
#   'restaurant_id': '40366938'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Marina Delray',
#   'restaurant_id': '40367161'},
#  {'borough': 'Bronx',
#   'cuisine': 'Not Listed/Not Applicable',
#   'name': "The Lark'S Nest",
#   'restaurant_id': '40367946'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Terrace Cafe',
#   'restaurant_id': '40368018'},
#  {'borough': 'Bronx',
#   'cuisine': 'African',
#   'name': 'African Terrace',
#   'restaurant_id': '40368021'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Cool Zone',
#   'restaurant_id': '40368022'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Beaver Pond',
#   'restaurant_id': '40368025'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'African Market (Baboon Cafe)',
#   'restaurant_id': '40368026'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Blue Bay Restaurant',
#   'restaurant_id': '40369087'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Seashore Restaurant',
#   'restaurant_id': '40369299'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Bronx Grill',
#   'restaurant_id': '40369601'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Johnny'S Reef Restaurant",
#   'restaurant_id': '40369641'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40369669'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "P & K'S Grill",
#   'restaurant_id': '40369895'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40369915'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "John Mulligan'S Fireside Pub",
#   'restaurant_id': '40370150'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40372196'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Yankee Jz Pizza',
#   'restaurant_id': '40372631'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop',
#   'restaurant_id': '40373938'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Tony'S Pier Restaurant",
#   'restaurant_id': '40374136'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Quality Cafe & Restaurant',
#   'restaurant_id': '40374259'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese/Cuban',
#   'name': 'Sabrosura Restaurant',
#   'restaurant_id': '40375136'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Jp'S Waterside Restaurant",
#   'restaurant_id': '40377124'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'John & Joe Pizzeria & Restaurant',
#   'restaurant_id': '40377243'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tony'S Pizza",
#   'restaurant_id': '40378347'},
#  {'borough': 'Bronx',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts",
#   'restaurant_id': '40379573'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Aqueduct North',
#   'restaurant_id': '40379894'},
#  {'borough': 'Bronx',
#   'cuisine': 'Spanish',
#   'name': 'Cuchifritos',
#   'restaurant_id': '40380164'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Riverdale Diner',
#   'restaurant_id': '40380253'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Castlehill Diner',
#   'restaurant_id': '40382517'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tommy'S Pizza",
#   'restaurant_id': '40382652'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': "Mom'S Fried Chicken",
#   'restaurant_id': '40382900'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Short Stop Restaurant',
#   'restaurant_id': '40383819'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Burger Barn Restaurant',
#   'restaurant_id': '40384486'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Eastwood Manor',
#   'restaurant_id': '40385680'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Ljubo'S Pizzeria",
#   'restaurant_id': '40385955'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S",
#   'restaurant_id': '40386062'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Venice Pizza',
#   'restaurant_id': '40386278'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': "Frank'S Soup Bowl",
#   'restaurant_id': '40386672'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40387143'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40387178'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Arturo'S Pizza",
#   'restaurant_id': '40387399'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Venice Restaurant',
#   'restaurant_id': '40387477'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Walnut Bus Stop',
#   'restaurant_id': '40387528'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S",
#   'restaurant_id': '40388016'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'The Pizza Place',
#   'restaurant_id': '40388253'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40388269'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Isla Restauraunt',
#   'restaurant_id': '40388392'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Spoto'S Restaurant",
#   'restaurant_id': '40388462'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': 'Bagel Cafe',
#   'restaurant_id': '40389011'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Vinny'S Famous Pizza",
#   'restaurant_id': '40389365'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Rino'S",
#   'restaurant_id': '40389594'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Villa Barone Manor',
#   'restaurant_id': '40390266'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Loui Seafood',
#   'restaurant_id': '40390814'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Gleason'S Cafe",
#   'restaurant_id': '40391375'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40391639'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham Seafood And Chicken',
#   'restaurant_id': '40392190'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Gun Post Lanes Snack Bar',
#   'restaurant_id': '40393563'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Molino Rojo Restaurant',
#   'restaurant_id': '40393688'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "O'Brien'S Pub",
#   'restaurant_id': '40394024'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Tibbett Diner',
#   'restaurant_id': '40394030'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'E & L Bakery & Coffee Shop',
#   'restaurant_id': '40394761'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Wembley Athletic Club',
#   'restaurant_id': '40394770'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Cullen'S Tavern",
#   'restaurant_id': '40394838'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40395511'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395653'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Golden Pizza',
#   'restaurant_id': '40395921'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40395992'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Chick-N-Ribs',
#   'restaurant_id': '40396053'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40396399'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Pugsley Pizza',
#   'restaurant_id': '40396548'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40397219'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Dominick'S Bar & Restaurant",
#   'restaurant_id': '40397574'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': "Zaro'S Bread Basket",
#   'restaurant_id': '40397863'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Lechonera Criolla',
#   'restaurant_id': '40398642'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Enzo Cafe',
#   'restaurant_id': '40398852'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Joe'S Pizza",
#   'restaurant_id': '40398910'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': "Lolita'S Restaurant",
#   'restaurant_id': '40398958'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40399778'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bagels/Pretzels',
#   'name': 'Rolen Bagels',
#   'restaurant_id': '40399988'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Fordham Fried Chicken & Sea Food',
#   'restaurant_id': '40400799'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Celeste'S Snack Bar",
#   'restaurant_id': '40401250'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Pelham Bay Diner',
#   'restaurant_id': '40401316'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40402106'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Villa Barone',
#   'restaurant_id': '40402187'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Stuyvesant Yacht Club',
#   'restaurant_id': '40402679'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Riverdale Yacht Club',
#   'restaurant_id': '40402699'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Ambassador Diner',
#   'restaurant_id': '40403946'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bagels/Pretzels',
#   'name': 'Bagel Corner',
#   'restaurant_id': '40423450'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Kingston Tropical Bakery',
#   'restaurant_id': '40423481'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Concourse Jamaican Bakery',
#   'restaurant_id': '40423547'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Artuso Pastry Shop',
#   'restaurant_id': '40423571'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Champion Bakery',
#   'restaurant_id': '40423830'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Al Cholo Bakery',
#   'restaurant_id': '40424273'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Franco Bakery',
#   'restaurant_id': '40424765'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Biarritz Bakery',
#   'restaurant_id': '40424919'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': "Jackie'S West Indian Bakery",
#   'restaurant_id': '40424972'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Vaquero Barras',
#   'restaurant_id': '40510301'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'China Wok Ii',
#   'restaurant_id': '40510328'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Pitusa Bakery',
#   'restaurant_id': '40510823'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Woodlawn Cafe',
# ...
#   'cuisine': 'American ',
#   'name': 'Dancing Crane Cafe (Bx Zoo)',
#   'restaurant_id': '40793858'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40794103'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40794912'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Section 5 Pizza Restaurant',
#   'restaurant_id': '40799031'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Step In Restaurant & Lounge',
#   'restaurant_id': '40800483'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40800986'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40801605'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': "Kristy'S Restaurant",
#   'restaurant_id': '40804049'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'San German Cuchifrito',
#   'restaurant_id': '40810657'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'J & J Restaurant & Cuchifritos',
#   'restaurant_id': '40812317'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40814300'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Boulevard Tavern',
#   'restaurant_id': '40815627'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Shore Haven Diner',
#   'restaurant_id': '40815664'},
#  {'borough': 'Bronx',
#   'cuisine': 'Steak',
#   'name': "Jake'S Steakhouse",
#   'restaurant_id': '40819558'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Madison'S",
#   'restaurant_id': '40823884'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'East Dynasty',
#   'restaurant_id': '40827529'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40828609'},
#  {'borough': 'Bronx',
#   'cuisine': 'African',
#   'name': 'Ebe Ye Yie African Restaurant',
#   'restaurant_id': '40832718'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Malecon Restaurant',
#   'restaurant_id': '40837042'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': 'City Island Deli',
#   'restaurant_id': '40839264'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Gurra Cafe',
#   'restaurant_id': '40840124'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Lin Home Chinese Restaura',
#   'restaurant_id': '40842437'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'To Go Express',
#   'restaurant_id': '40843062'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Chirping Chicken',
#   'restaurant_id': '40847914'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Peacock Restaurant',
#   'restaurant_id': '40849313'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40849624'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40850448'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The Williamsbridge Tavern',
#   'restaurant_id': '40852754'},
#  {'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'Vista Hermosa Deli Restaurant',
#   'restaurant_id': '40853915'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Vivienne'S",
#   'restaurant_id': '40856176'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Starbucks Coffee',
#   'restaurant_id': '40856325'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': "Lin'S Garden",
#   'restaurant_id': '40857406'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40860841'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Casa Promesa',
#   'restaurant_id': '40861141'},
#  {'borough': 'Bronx',
#   'cuisine': 'Sandwiches',
#   'name': 'Subway',
#   'restaurant_id': '40862204'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Shalon Restaurant',
#   'restaurant_id': '40863225'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Broadway Pizza & Pasta',
#   'restaurant_id': '40863575'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40863944'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King',
#   'restaurant_id': '40863963'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40866315'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40866322'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40866340'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Mi Sueno Restaurant',
#   'restaurant_id': '40866951'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40868904'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40869179'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Mr Mcgoo'S",
#   'restaurant_id': '40869211'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Buen Ambiente',
#   'restaurant_id': '40869790'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Popeyes Chicken & Biscuits',
#   'restaurant_id': '40869873'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Liberato Restaurant',
#   'restaurant_id': '40871403'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Wilbel Pizza',
#   'restaurant_id': '40871979'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham University - Mcginley Center',
#   'restaurant_id': '40874831'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham University/Mcginley Center/Ramskeller Kitchen',
#   'restaurant_id': '40874915'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Seafood  City',
#   'restaurant_id': '40875290'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel',
#   'restaurant_id': '40876932'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham University - Millenium Grill',
#   'restaurant_id': '40877246'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': 'Fordham University - Student Deli',
#   'restaurant_id': '40877285'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'La Nueva Giralda Bakery',
#   'restaurant_id': '40877421'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Sheas Emerald',
#   'restaurant_id': '40883581'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Memories Lounge',
#   'restaurant_id': '40883866'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Roca Tone Seafood Restaurant',
#   'restaurant_id': '40885478'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'The Best Italian Pizza',
#   'restaurant_id': '40886422'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'J.E. Bakery',
#   'restaurant_id': '40890186'},
#  {'borough': 'Bronx',
#   'cuisine': 'Soul Food',
#   'name': 'Cea Lo Cafe',
#   'restaurant_id': '40890407'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Mug-Z'S Sports Bar",
#   'restaurant_id': '40891377'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Frank'S Pizzeria",
#   'restaurant_id': '40892887'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Nb. National Bakery',
#   'restaurant_id': '40897418'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'New Rainbow Restaurant',
#   'restaurant_id': '40899178'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Morris Park Bake Shop',
#   'restaurant_id': '30075445'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Wild Asia',
#   'restaurant_id': '40357217'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363093'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden',
#   'restaurant_id': '40363289'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden',
#   'restaurant_id': '40364296'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Manhem Club',
#   'restaurant_id': '40364363'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The New Starling Athletic Club Of The Bronx',
#   'restaurant_id': '40364956'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Yankee Tavern',
#   'restaurant_id': '40365499'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Mcdwyers Pub',
#   'restaurant_id': '40365893'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The Punch Bowl',
#   'restaurant_id': '40366497'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Munchtime',
#   'restaurant_id': '40366748'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop',
#   'restaurant_id': '40366833'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': "Lulu'S Coffee Shop",
#   'restaurant_id': '40366938'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Marina Delray',
#   'restaurant_id': '40367161'},
#  {'borough': 'Bronx',
#   'cuisine': 'Not Listed/Not Applicable',
#   'name': "The Lark'S Nest",
#   'restaurant_id': '40367946'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Terrace Cafe',
#   'restaurant_id': '40368018'},
#  {'borough': 'Bronx',
#   'cuisine': 'African',
#   'name': 'African Terrace',
#   'restaurant_id': '40368021'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Cool Zone',
#   'restaurant_id': '40368022'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Beaver Pond',
#   'restaurant_id': '40368025'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'African Market (Baboon Cafe)',
#   'restaurant_id': '40368026'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Blue Bay Restaurant',
#   'restaurant_id': '40369087'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Seashore Restaurant',
#   'restaurant_id': '40369299'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Bronx Grill',
#   'restaurant_id': '40369601'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Johnny'S Reef Restaurant",
#   'restaurant_id': '40369641'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40369669'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "P & K'S Grill",
#   'restaurant_id': '40369895'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40369915'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "John Mulligan'S Fireside Pub",
#   'restaurant_id': '40370150'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40372196'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Yankee Jz Pizza',
#   'restaurant_id': '40372631'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop',
#   'restaurant_id': '40373938'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Tony'S Pier Restaurant",
#   'restaurant_id': '40374136'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Quality Cafe & Restaurant',
#   'restaurant_id': '40374259'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese/Cuban',
#   'name': 'Sabrosura Restaurant',
#   'restaurant_id': '40375136'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Jp'S Waterside Restaurant",
#   'restaurant_id': '40377124'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'John & Joe Pizzeria & Restaurant',
#   'restaurant_id': '40377243'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tony'S Pizza",
#   'restaurant_id': '40378347'},
#  {'borough': 'Bronx',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts",
#   'restaurant_id': '40379573'},
#  {'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Aqueduct North',
#   'restaurant_id': '40379894'},
#  {'borough': 'Bronx',
#   'cuisine': 'Spanish',
#   'name': 'Cuchifritos',
#   'restaurant_id': '40380164'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Riverdale Diner',
#   'restaurant_id': '40380253'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Castlehill Diner',
#   'restaurant_id': '40382517'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tommy'S Pizza",
#   'restaurant_id': '40382652'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': "Mom'S Fried Chicken",
#   'restaurant_id': '40382900'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Short Stop Restaurant',
#   'restaurant_id': '40383819'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Burger Barn Restaurant',
#   'restaurant_id': '40384486'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Eastwood Manor',
#   'restaurant_id': '40385680'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Ljubo'S Pizzeria",
#   'restaurant_id': '40385955'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S",
#   'restaurant_id': '40386062'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Venice Pizza',
#   'restaurant_id': '40386278'},
#  {'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': "Frank'S Soup Bowl",
#   'restaurant_id': '40386672'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40387143'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40387178'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Arturo'S Pizza",
#   'restaurant_id': '40387399'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Venice Restaurant',
#   'restaurant_id': '40387477'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Walnut Bus Stop',
#   'restaurant_id': '40387528'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S",
#   'restaurant_id': '40388016'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'The Pizza Place',
#   'restaurant_id': '40388253'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle',
#   'restaurant_id': '40388269'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Isla Restauraunt',
#   'restaurant_id': '40388392'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Spoto'S Restaurant",
#   'restaurant_id': '40388462'},
#  {'borough': 'Bronx',
#   'cuisine': 'Delicatessen',
#   'name': 'Bagel Cafe',
#   'restaurant_id': '40389011'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Vinny'S Famous Pizza",
#   'restaurant_id': '40389365'},
#  {'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': "Rino'S",
#   'restaurant_id': '40389594'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Villa Barone Manor',
#   'restaurant_id': '40390266'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Loui Seafood',
#   'restaurant_id': '40390814'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Gleason'S Cafe",
#   'restaurant_id': '40391375'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S",
#   'restaurant_id': '40391639'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Fordham Seafood And Chicken',
#   'restaurant_id': '40392190'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Gun Post Lanes Snack Bar',
#   'restaurant_id': '40393563'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Molino Rojo Restaurant',
#   'restaurant_id': '40393688'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "O'Brien'S Pub",
#   'restaurant_id': '40394024'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Tibbett Diner',
#   'restaurant_id': '40394030'},
#  ...]

# %%
# Mostrar los primeros 5 restaurantes que se encuentran en el distrito Bronx
list((restaurantes.find({'borough':'Bronx'},{'_id':0}).limit(5)).sort("name"))
# Out:
# [{'address': {'building': '2300',
#    'coord': [-73.8786113, 40.8502883],
#    'street': 'Southern Boulevard',
#    'zipcode': '10460'},
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1400630400000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1369699200000}, 'grade': 'A', 'score': 3},
#    {'date': {'$date': 1339977600000}, 'grade': 'A', 'score': 4},
#    {'date': {'$date': 1307404800000}, 'grade': 'A', 'score': 9}],
#   'name': 'African Market (Baboon Cafe)',
#   'restaurant_id': '40368026'},
#  {'address': {'building': '2300',
#    'coord': [-73.8786113, 40.8502883],
#    'street': 'Southern Boulevard',
#    'zipcode': '10460'},
#   'borough': 'Bronx',
#   'cuisine': 'African',
#   'grades': [{'date': {'$date': 1400630400000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1370044800000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1339459200000}, 'grade': 'A', 'score': 0},
#    {'date': {'$date': 1307491200000}, 'grade': 'A', 'score': 0}],
#   'name': 'African Terrace',
#   'restaurant_id': '40368021'},
#  {'address': {'building': '3825',
#    'coord': [-73.86267, 40.884484],
#    'street': 'White Plains Road',
#    'zipcode': '10467'},
#   'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'grades': [{'date': {'$date': 1415232000000}, 'grade': 'Z', 'score': 20},
#    {'date': {'$date': 1402876800000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1382313600000}, 'grade': 'B', 'score': 15},
#    {'date': {'$date': 1369008000000}, 'grade': 'B', 'score': 22},
#    {'date': {'$date': 1334620800000}, 'grade': 'A', 'score': 10}],
#   'name': 'Al Cholo Bakery',
#   'restaurant_id': '40424273'},
#  {'address': {'building': '4220',
#    'coord': [-73.85672319999999, 40.8939927],
#    'street': 'White Plains Road',
#    'zipcode': '10466'},
#   'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'grades': [{'date': {'$date': 1415232000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1383696000000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1369958400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1353974400000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1340841600000}, 'grade': 'A', 'score': 7},
#    {'date': {'$date': 1326931200000}, 'grade': 'A', 'score': 13}],
#   'name': "Ali'S Roti Shop",
#   'restaurant_id': '40738028'},
#  {'address': {'building': '730',
#    'coord': [-73.89954829999999, 40.8164378],
#    'street': 'Kelly Street',
#    'zipcode': '10455'},
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1421712000000},
#     'grade': 'Not Yet Graded',
#     'score': 4}],
#   'name': 'Ambassador Diner',
#   'restaurant_id': '40403946'}]

# %%
#4. Devolver los restaurantes que lograron una puntuación superior a 80 pero inferior a 100

filtro = {"grades.score": {"$not" : {"$lt": 20}}}
proyeccion = {"name": 1, "grades": 1, "_id" : 0}
list(restaurantes.find(filtro,proyeccion))
# Out:
# [{'grades': [{'date': {'$date': 1404691200000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1389398400000}, 'grade': 'C', 'score': 32},
#    {'date': {'$date': 1372118400000}, 'grade': 'C', 'score': 36},
#    {'date': {'$date': 1351123200000}, 'grade': 'B', 'score': 23},
#    {'date': {'$date': 1334016000000}, 'grade': 'B', 'score': 25},
#    {'date': {'$date': 1320105600000}, 'grade': 'C', 'score': 42}],
#   'name': 'Tobacco Road'},
#  {'grades': [{'date': {'$date': 1421193600000}, 'grade': 'Z', 'score': 25},
#    {'date': {'$date': 1399939200000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1381104000000}, 'grade': 'B', 'score': 20},
#    {'date': {'$date': 1368576000000}, 'grade': 'C', 'score': 40},
#    {'date': {'$date': 1350950400000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1335916800000}, 'grade': 'B', 'score': 21}],
#   'name': "Tony'S Pizzeria & Restaurant"},
#  {'grades': [{'date': {'$date': 1404691200000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1389398400000}, 'grade': 'C', 'score': 32},
#    {'date': {'$date': 1372118400000}, 'grade': 'C', 'score': 36},
#    {'date': {'$date': 1351123200000}, 'grade': 'B', 'score': 23},
#    {'date': {'$date': 1334016000000}, 'grade': 'B', 'score': 25},
#    {'date': {'$date': 1320105600000}, 'grade': 'C', 'score': 42}],
#   'name': 'Tobacco Road'},
#  {'grades': [{'date': {'$date': 1421193600000}, 'grade': 'Z', 'score': 25},
#    {'date': {'$date': 1399939200000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1381104000000}, 'grade': 'B', 'score': 20},
#    {'date': {'$date': 1368576000000}, 'grade': 'C', 'score': 40},
#    {'date': {'$date': 1350950400000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1335916800000}, 'grade': 'B', 'score': 21}],
#   'name': "Tony'S Pizzeria & Restaurant"}]

# %% [markdown]
# 5. Devolver los restaurantes que se ubican en un valor de latitud inferior a -95.754168

# %%
for doc in restaurantes.find().limit(5):  # Muestra 5 documentos como ejemplo para ver como ha llamdo a mis variables
  print(doc)
# Out:
# {'_id': ObjectId('67349b13ace753fad167f78b'), 'address': {'building': '1007', 'coord': [-73.856077, 40.848447], 'street': 'Morris Park Ave', 'zipcode': '10462'}, 'borough': 'Bronx', 'cuisine': 'Bakery', 'grades': [{'date': {'$date': 1393804800000}, 'grade': 'A', 'score': 2}, {'date': {'$date': 1378857600000}, 'grade': 'A', 'score': 6}, {'date': {'$date': 1358985600000}, 'grade': 'A', 'score': 10}, {'date': {'$date': 1322006400000}, 'grade': 'A', 'score': 9}, {'date': {'$date': 1299715200000}, 'grade': 'B', 'score': 14}], 'name': 'Morris Park Bake Shop', 'restaurant_id': '30075445'}
# {'_id': ObjectId('67349b13ace753fad167f78c'), 'address': {'building': '469', 'coord': [-73.961704, 40.662942], 'street': 'Flatbush Avenue', 'zipcode': '11225'}, 'borough': 'Brooklyn', 'cuisine': 'Hamburgers', 'grades': [{'date': {'$date': 1419897600000}, 'grade': 'A', 'score': 8}, {'date': {'$date': 1404172800000}, 'grade': 'B', 'score': 23}, {'date': {'$date': 1367280000000}, 'grade': 'A', 'score': 12}, {'date': {'$date': 1336435200000}, 'grade': 'A', 'score': 12}], 'name': "Wendy'S", 'restaurant_id': '30112340'}
# {'_id': ObjectId('67349b13ace753fad167f78d'), 'address': {'building': '351', 'coord': [-73.98513559999999, 40.7676919], 'street': 'West   57 Street', 'zipcode': '10019'}, 'borough': 'Manhattan', 'cuisine': 'Irish', 'grades': [{'date': {'$date': 1409961600000}, 'grade': 'A', 'score': 2}, {'date': {'$date': 1374451200000}, 'grade': 'A', 'score': 11}, {'date': {'$date': 1343692800000}, 'grade': 'A', 'score': 12}, {'date': {'$date': 1325116800000}, 'grade': 'A', 'score': 12}], 'name': 'Dj Reynolds Pub And Restaurant', 'restaurant_id': '30191841'}
# {'_id': ObjectId('67349b13ace753fad167f78e'), 'address': {'building': '2780', 'coord': [-73.98241999999999, 40.579505], 'street': 'Stillwell Avenue', 'zipcode': '11224'}, 'borough': 'Brooklyn', 'cuisine': 'American ', 'grades': [{'date': {'$date': 1402358400000}, 'grade': 'A', 'score': 5}, {'date': {'$date': 1370390400000}, 'grade': 'A', 'score': 7}, {'date': {'$date': 1334275200000}, 'grade': 'A', 'score': 12}, {'date': {'$date': 1318377600000}, 'grade': 'A', 'score': 12}], 'name': 'Riviera Caterer', 'restaurant_id': '40356018'}
# {'_id': ObjectId('67349b13ace753fad167f78f'), 'address': {'building': '97-22', 'coord': [-73.8601152, 40.7311739], 'street': '63 Road', 'zipcode': '11374'}, 'borough': 'Queens', 'cuisine': 'Jewish/Kosher', 'grades': [{'date': {'$date': 1416787200000}, 'grade': 'Z', 'score': 20}, {'date': {'$date': 1358380800000}, 'grade': 'A', 'score': 13}, {'date': {'$date': 1343865600000}, 'grade': 'A', 'score': 13}, {'date': {'$date': 1323907200000}, 'grade': 'B', 'score': 25}], 'name': 'Tov Kosher Kitchen', 'restaurant_id': '40356068'}

# %%
filtro = {"address.coord.1": {"$lt":-95.754168}} #el 1 es para acceder al segudno elemento 
proyeccion = {}
list(restaurantes.find(filtro, proyeccion))
# Out:
# []

# %% [markdown]
# 6. Devolver los restaurantes que no preparan cocina americana y lograron una puntuación superior a 70 y se ubicaron en una longitud inferior a -65.754168. Nota: Realice esta consulta sin usar el operador $and

# %%
filtro = {
    "address.coord.0": {"$lt":-65.754168},
    "grades.score": {"$gt": 70},
    "cuisine" : {"$not": {"$eq":"American"}}
    #el 1 es para acceder al segudno elemento 
} 

proyeccion = { "_id": 0}

list(restaurantes.find(filtro, proyeccion))
# Out:
# [{'address': {'building': '65',
#    'coord': [-73.9782725, 40.7624022],
#    'street': 'West   54 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1408665600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1395964800000}, 'grade': 'C', 'score': 131},
#    {'date': {'$date': 1380067200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1365379200000}, 'grade': 'B', 'score': 25},
#    {'date': {'$date': 1350259200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1318982400000}, 'grade': 'A', 'score': 13}],
#   'name': "Murals On 54/Randolphs'S",
#   'restaurant_id': '40372466'},
#  {'address': {'building': '345',
#    'coord': [-73.9864626, 40.7266739],
#    'street': 'East 6 Street',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': {'$date': 1410739200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1389657600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1369872000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1366761600000}, 'grade': 'P', 'score': 2},
#    {'date': {'$date': 1349049600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1333670400000}, 'grade': 'C', 'score': 92},
#    {'date': {'$date': 1320278400000}, 'grade': 'C', 'score': 41}],
#   'name': 'Gandhi',
#   'restaurant_id': '40381295'},
#  {'address': {'building': '14',
#    'coord': [-73.9883909, 40.740735],
#    'street': 'East   23 Street',
#    'zipcode': '10010'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1414454400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1397088000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1375920000000}, 'grade': 'C', 'score': 58},
#    {'date': {'$date': 1360800000000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1339718400000}, 'grade': 'C', 'score': 71}],
#   'name': 'Live Bait Bar & Restaurant',
#   'restaurant_id': '40387237'},
#  {'address': {'building': '130',
#    'coord': [-73.984758, 40.7457939],
#    'street': 'Madison Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'date': {'$date': 1419379200000}, 'grade': 'Z', 'score': 31},
#    {'date': {'$date': 1402963200000}, 'grade': 'C', 'score': 98},
#    {'date': {'$date': 1386806400000}, 'grade': 'C', 'score': 32},
#    {'date': {'$date': 1369180800000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1335916800000}, 'grade': 'A', 'score': 11}],
#   'name': 'Bella Napoli',
#   'restaurant_id': '40393488'},
#  {'address': {'building': '101',
#    'coord': [-73.9243061, 40.8276297],
#    'street': 'East 161 Street',
#    'zipcode': '10451'},
#   'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'grades': [{'date': {'$date': 1397088000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1380585600000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1365638400000}, 'grade': 'B', 'score': 25},
#    {'date': {'$date': 1351123200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1349827200000}, 'grade': 'P', 'score': 12},
#    {'date': {'$date': 1337904000000}, 'grade': 'B', 'score': 14},
#    {'date': {'$date': 1315958400000}, 'grade': 'B', 'score': 26},
#    {'date': {'$date': 1303689600000}, 'grade': 'C', 'score': 76}],
#   'name': 'El Molino Rojo Restaurant',
#   'restaurant_id': '40393688'},
#  {'address': {'building': '289',
#    'coord': [-73.94610279999999, 40.7137587],
#    'street': 'Manhattan Avenue',
#    'zipcode': '11211'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Bakery',
#   'grades': [{'date': {'$date': 1395187200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1381363200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1367884800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1347321600000}, 'grade': 'B', 'score': 18},
#    {'date': {'$date': 1334707200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1317081600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1304380800000}, 'grade': 'C', 'score': 77}],
#   'name': 'Fortunato Bros Cafe & Bakery',
#   'restaurant_id': '40400561'},
#  {'address': {'building': '243',
#    'coord': [-73.9889479, 40.7568894],
#    'street': 'West   42 Street',
#    'zipcode': '10036'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1414713600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1400198400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1384819200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1364169600000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1346803200000}, 'grade': 'B', 'score': 26},
#    {'date': {'$date': 1334016000000}, 'grade': 'C', 'score': 49},
#    {'date': {'$date': 1321833600000}, 'grade': 'C', 'score': 80}],
#   'name': 'B.B. Kings',
#   'restaurant_id': '40704853'},
#  {'address': {'building': '231',
#    'coord': [-73.9772294, 40.7527262],
#    'street': 'Grand Central Station',
#    'zipcode': '10017'},
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1420588800000}, 'grade': 'Z', 'score': 20},
#    {'date': {'$date': 1404345600000}, 'grade': 'B', 'score': 14},
#    {'date': {'$date': 1387584000000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1368748800000}, 'grade': 'C', 'score': 76},
#    {'date': {'$date': 1334880000000}, 'grade': 'A', 'score': 12}],
#   'name': 'Two Boots Grand Central',
#   'restaurant_id': '40725591'},
#  {'address': {'building': '',
#    'coord': [-74.0163793, 40.7167671],
#    'street': 'Hudson River',
#    'zipcode': '10282'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1403827200000}, 'grade': 'C', 'score': 89},
#    {'date': {'$date': 1370476800000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1340064000000}, 'grade': 'A', 'score': 13}],
#   'name': 'West 79Th Street Boat Basin Cafe',
#   'restaurant_id': '40756344'},
#  {'address': {'building': '65',
#    'coord': [-73.9782725, 40.7624022],
#    'street': 'West   54 Street',
#    'zipcode': '10019'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1408665600000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1395964800000}, 'grade': 'C', 'score': 131},
#    {'date': {'$date': 1380067200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1365379200000}, 'grade': 'B', 'score': 25},
#    {'date': {'$date': 1350259200000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1318982400000}, 'grade': 'A', 'score': 13}],
#   'name': "Murals On 54/Randolphs'S",
#   'restaurant_id': '40372466'},
#  {'address': {'building': '345',
#    'coord': [-73.9864626, 40.7266739],
#    'street': 'East 6 Street',
#    'zipcode': '10003'},
#   'borough': 'Manhattan',
#   'cuisine': 'Indian',
#   'grades': [{'date': {'$date': 1410739200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1389657600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1369872000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1366761600000}, 'grade': 'P', 'score': 2},
#    {'date': {'$date': 1349049600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1333670400000}, 'grade': 'C', 'score': 92},
#    {'date': {'$date': 1320278400000}, 'grade': 'C', 'score': 41}],
#   'name': 'Gandhi',
#   'restaurant_id': '40381295'},
#  {'address': {'building': '14',
#    'coord': [-73.9883909, 40.740735],
#    'street': 'East   23 Street',
#    'zipcode': '10010'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1414454400000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1397088000000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1375920000000}, 'grade': 'C', 'score': 58},
#    {'date': {'$date': 1360800000000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1339718400000}, 'grade': 'C', 'score': 71}],
#   'name': 'Live Bait Bar & Restaurant',
#   'restaurant_id': '40387237'},
#  {'address': {'building': '130',
#    'coord': [-73.984758, 40.7457939],
#    'street': 'Madison Avenue',
#    'zipcode': '10016'},
#   'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'date': {'$date': 1419379200000}, 'grade': 'Z', 'score': 31},
#    {'date': {'$date': 1402963200000}, 'grade': 'C', 'score': 98},
#    {'date': {'$date': 1386806400000}, 'grade': 'C', 'score': 32},
#    {'date': {'$date': 1369180800000}, 'grade': 'B', 'score': 21},
#    {'date': {'$date': 1335916800000}, 'grade': 'A', 'score': 11}],
#   'name': 'Bella Napoli',
#   'restaurant_id': '40393488'},
#  {'address': {'building': '101',
#    'coord': [-73.9243061, 40.8276297],
#    'street': 'East 161 Street',
#    'zipcode': '10451'},
#   'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'grades': [{'date': {'$date': 1397088000000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1380585600000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1365638400000}, 'grade': 'B', 'score': 25},
#    {'date': {'$date': 1351123200000}, 'grade': 'A', 'score': 12},
#    {'date': {'$date': 1349827200000}, 'grade': 'P', 'score': 12},
#    {'date': {'$date': 1337904000000}, 'grade': 'B', 'score': 14},
#    {'date': {'$date': 1315958400000}, 'grade': 'B', 'score': 26},
#    {'date': {'$date': 1303689600000}, 'grade': 'C', 'score': 76}],
#   'name': 'El Molino Rojo Restaurant',
#   'restaurant_id': '40393688'},
#  {'address': {'building': '289',
#    'coord': [-73.94610279999999, 40.7137587],
#    'street': 'Manhattan Avenue',
#    'zipcode': '11211'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Bakery',
#   'grades': [{'date': {'$date': 1395187200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1381363200000}, 'grade': 'A', 'score': 10},
#    {'date': {'$date': 1367884800000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1347321600000}, 'grade': 'B', 'score': 18},
#    {'date': {'$date': 1334707200000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1317081600000}, 'grade': 'A', 'score': 8},
#    {'date': {'$date': 1304380800000}, 'grade': 'C', 'score': 77}],
#   'name': 'Fortunato Bros Cafe & Bakery',
#   'restaurant_id': '40400561'},
#  {'address': {'building': '243',
#    'coord': [-73.9889479, 40.7568894],
#    'street': 'West   42 Street',
#    'zipcode': '10036'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1414713600000}, 'grade': 'A', 'score': 9},
#    {'date': {'$date': 1400198400000}, 'grade': 'A', 'score': 11},
#    {'date': {'$date': 1384819200000}, 'grade': 'A', 'score': 5},
#    {'date': {'$date': 1364169600000}, 'grade': 'B', 'score': 19},
#    {'date': {'$date': 1346803200000}, 'grade': 'B', 'score': 26},
#    {'date': {'$date': 1334016000000}, 'grade': 'C', 'score': 49},
#    {'date': {'$date': 1321833600000}, 'grade': 'C', 'score': 80}],
#   'name': 'B.B. Kings',
#   'restaurant_id': '40704853'},
#  {'address': {'building': '231',
#    'coord': [-73.9772294, 40.7527262],
#    'street': 'Grand Central Station',
#    'zipcode': '10017'},
#   'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'date': {'$date': 1420588800000}, 'grade': 'Z', 'score': 20},
#    {'date': {'$date': 1404345600000}, 'grade': 'B', 'score': 14},
#    {'date': {'$date': 1387584000000}, 'grade': 'A', 'score': 13},
#    {'date': {'$date': 1368748800000}, 'grade': 'C', 'score': 76},
#    {'date': {'$date': 1334880000000}, 'grade': 'A', 'score': 12}],
#   'name': 'Two Boots Grand Central',
#   'restaurant_id': '40725591'},
#  {'address': {'building': '',
#    'coord': [-74.0163793, 40.7167671],
#    'street': 'Hudson River',
#    'zipcode': '10282'},
#   'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'date': {'$date': 1403827200000}, 'grade': 'C', 'score': 89},
#    {'date': {'$date': 1370476800000}, 'grade': 'A', 'score': 6},
#    {'date': {'$date': 1340064000000}, 'grade': 'A', 'score': 13}],
#   'name': 'West 79Th Street Boat Basin Cafe',
#   'restaurant_id': '40756344'}]

# %% [markdown]
# 7. Devolver los restaurantes que no preparan cocina americana y lograron un punto de calificación 'A' que no pertenece al distrito de Brooklyn. El documento debe mostrarse según la cocina en orden descendente.

# %%
filtro = {
    "address.borough": {"$not": {"$eq":"Brooklyn"}},
    "grades.grade": "A",
    "cuisine" : {"$not": {"$eq":"American"}}
}    

proyeccion = {"name": 1, "cuisine": 1, "grades.grade": 1, "borough": 1, "_id": 0}
#los 1 en la proyección indican que deseas incluir esos campos
list(restaurantes.find(filtro, proyeccion).sort("cuisine", -1))
# Out:
# [{'borough': 'Manhattan',
#   'cuisine': 'Vietnamese/Cambodian/Malaysia',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Thai Son'},
#  {'borough': 'Queens',
#   'cuisine': 'Vietnamese/Cambodian/Malaysia',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'P'},
#    {'grade': 'B'}],
#   'name': 'Pho Bac Vietnamese Seafood Cuisine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vietnamese/Cambodian/Malaysia',
#   'grades': [{'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'Nha-Trang Centre Vietnam Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vietnamese/Cambodian/Malaysia',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Thai Son'},
#  {'borough': 'Queens',
#   'cuisine': 'Vietnamese/Cambodian/Malaysia',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'P'},
#    {'grade': 'B'}],
#   'name': 'Pho Bac Vietnamese Seafood Cuisine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vietnamese/Cambodian/Malaysia',
#   'grades': [{'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'Nha-Trang Centre Vietnam Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vietnamese/Cambodian/Malaysia',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Thai Son'},
#  {'borough': 'Queens',
#   'cuisine': 'Vietnamese/Cambodian/Malaysia',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'P'},
#    {'grade': 'B'}],
#   'name': 'Pho Bac Vietnamese Seafood Cuisine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vietnamese/Cambodian/Malaysia',
#   'grades': [{'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'Nha-Trang Centre Vietnam Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Angelica Kitchen'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Candle Cafe'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Village Yogurt'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Village Natural'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'}],
#   'name': 'Strictly Vegetarian'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Caravan Of Dreams'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Mana'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'}],
#   'name': 'Original Vegetarian Restaurant'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Bliss Bakery & Cafe'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Red Bamboo'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Angelica Kitchen'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Candle Cafe'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Village Yogurt'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Village Natural'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'}],
#   'name': 'Strictly Vegetarian'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Caravan Of Dreams'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Mana'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'}],
#   'name': 'Original Vegetarian Restaurant'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Bliss Bakery & Cafe'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Red Bamboo'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Angelica Kitchen'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Candle Cafe'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Village Yogurt'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Village Natural'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'}],
#   'name': 'Strictly Vegetarian'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Caravan Of Dreams'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Mana'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'}],
#   'name': 'Original Vegetarian Restaurant'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Bliss Bakery & Cafe'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Red Bamboo'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'The Country Cafe'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Turkish Kitchen'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Uskudar Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Pasha Turkish Restaurant'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Sahara Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}],
#   'name': 'Kebab House'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Turkish Cuisine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'B'}],
#   'name': 'Turkuaz Turkish Cuisine'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Istanbul Restaurant'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'Memo Shish Kebab'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'Saharas Turkish Cuisine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'The Country Cafe'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Turkish Kitchen'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Uskudar Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Pasha Turkish Restaurant'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Sahara Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}],
#   'name': 'Kebab House'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Turkish Cuisine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'B'}],
#   'name': 'Turkuaz Turkish Cuisine'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Istanbul Restaurant'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'Memo Shish Kebab'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'Saharas Turkish Cuisine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'The Country Cafe'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Turkish Kitchen'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Uskudar Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Pasha Turkish Restaurant'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Sahara Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}],
#   'name': 'Kebab House'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Turkish Cuisine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'B'}],
#   'name': 'Turkuaz Turkish Cuisine'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Istanbul Restaurant'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'Memo Shish Kebab'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'Saharas Turkish Cuisine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'P'}],
#   'name': 'Pongsri Thai Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Jaiya Thai Oriental Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}],
#   'name': 'Topaz Thai Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'P'}],
#   'name': 'Arharn Thai Cuisine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Bangkok Grand Palace'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Bangkok Thai House'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'C'}],
#   'name': 'Rohm Thai'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'P'},
#    {'grade': 'C'},
#    {'grade': 'C'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'C'}],
#   'name': 'Cafe Asean'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'P'},
#    {'grade': 'A'}],
#   'name': "Bennie'S Thai Cafe"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Republic Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'Z'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'C'}],
#   'name': 'Erawan Thai Cuisine'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Joya'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'Wondee Siam Ii'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'}],
#   'name': 'Ott Thai Cuisine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'P'}],
#   'name': 'Pongsri Thai Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Jaiya Thai Oriental Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}],
#   'name': 'Topaz Thai Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'P'}],
#   'name': 'Arharn Thai Cuisine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Bangkok Grand Palace'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Bangkok Thai House'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'C'}],
#   'name': 'Rohm Thai'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'P'},
#    {'grade': 'C'},
#    {'grade': 'C'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'C'}],
#   'name': 'Cafe Asean'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'P'},
#    {'grade': 'A'}],
#   'name': "Bennie'S Thai Cafe"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Republic Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'Z'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'C'}],
#   'name': 'Erawan Thai Cuisine'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Joya'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'Wondee Siam Ii'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'}],
#   'name': 'Ott Thai Cuisine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'P'}],
#   'name': 'Pongsri Thai Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Jaiya Thai Oriental Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}],
#   'name': 'Topaz Thai Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'P'}],
#   'name': 'Arharn Thai Cuisine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Bangkok Grand Palace'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Bangkok Thai House'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'C'}],
#   'name': 'Rohm Thai'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'P'},
#    {'grade': 'C'},
#    {'grade': 'C'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'C'}],
#   'name': 'Cafe Asean'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'P'},
#    {'grade': 'A'}],
#   'name': "Bennie'S Thai Cafe"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Republic Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'Z'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'C'}],
#   'name': 'Erawan Thai Cuisine'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Joya'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'Wondee Siam Ii'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Thai',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'}],
#   'name': 'Ott Thai Cuisine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Baby Bo'S Burritos"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Burrito Loco'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Santa Fe Grill & Bar'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Tortilla Flats'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Cowgirl Hall Of Fame'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Bennys Burritos'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': "Benny'S Burritos"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': "Buddy'S Burrito & Taco Bar"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': "Harry'S Burrito Junction"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'Z'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'The Heights Bar & Grill'},
#  {'borough': 'Queens',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Taco Bell'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Blockheads Burritos'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Burrito Box'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Baby Bo'S Burritos"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Burrito Loco'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Santa Fe Grill & Bar'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Tortilla Flats'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Cowgirl Hall Of Fame'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Bennys Burritos'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': "Benny'S Burritos"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': "Buddy'S Burrito & Taco Bar"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': "Harry'S Burrito Junction"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'Z'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'The Heights Bar & Grill'},
#  {'borough': 'Queens',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Taco Bell'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Blockheads Burritos'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Burrito Box'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Baby Bo'S Burritos"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Burrito Loco'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Santa Fe Grill & Bar'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Tortilla Flats'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Cowgirl Hall Of Fame'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Bennys Burritos'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': "Benny'S Burritos"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': "Buddy'S Burrito & Taco Bar"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': "Harry'S Burrito Junction"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'Z'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'The Heights Bar & Grill'},
#  {'borough': 'Queens',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Taco Bell'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Blockheads Burritos'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Burrito Box'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tapas',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Kana Tapas Bar & Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tapas',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'}],
#   'name': 'Cafe Ronda'},
#  {'borough': 'Queens',
#   'cuisine': 'Tapas',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'El Boqueron Tapas Bar & Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tapas',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Verlaine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tapas',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Kana Tapas Bar & Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tapas',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'}],
#   'name': 'Cafe Ronda'},
#  {'borough': 'Queens',
#   'cuisine': 'Tapas',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'El Boqueron Tapas Bar & Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tapas',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Verlaine'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tapas',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Kana Tapas Bar & Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tapas',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'}],
#   'name': 'Cafe Ronda'},
#  {'borough': 'Queens',
#   'cuisine': 'Tapas',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'El Boqueron Tapas Bar & Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tapas',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Verlaine'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Peter Luger Steakhouse'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Donohue'S Steak House"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Sammy'S Steakhouse"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Sparks Steak House'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'Z'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Keens Steakhouse'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Frankie & Johnnies Steakhouse'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Hunter'S Steak & Ale House"},
#  {'borough': 'Queens',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Bliss Street Station Restaurant'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Arirang Hibachi Steakhouse'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'T-Bar Steak & Lounge'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Bobby Van'S"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Quality Meats'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Michael Jordan'S Steak House - In Grand Central"},
#  {'borough': 'Bronx',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Riverdale Steak House'},
#  {'borough': 'Queens',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': "My Uncle'S Steak Restaurant"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Wolf And Lamb'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Del Frisco'S"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Palm Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Hillstone Manhattan'},
#  {'borough': 'Bronx',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Jake'S Steakhouse"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Ruth'S Chris Steak House"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Peter Luger Steakhouse'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Donohue'S Steak House"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Sammy'S Steakhouse"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Sparks Steak House'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'Z'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Keens Steakhouse'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Frankie & Johnnies Steakhouse'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Hunter'S Steak & Ale House"},
#  {'borough': 'Queens',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Bliss Street Station Restaurant'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Arirang Hibachi Steakhouse'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'T-Bar Steak & Lounge'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Bobby Van'S"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Quality Meats'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Michael Jordan'S Steak House - In Grand Central"},
#  {'borough': 'Bronx',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Riverdale Steak House'},
#  {'borough': 'Queens',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': "My Uncle'S Steak Restaurant"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Wolf And Lamb'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Del Frisco'S"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Palm Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Hillstone Manhattan'},
#  {'borough': 'Bronx',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Jake'S Steakhouse"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Ruth'S Chris Steak House"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Peter Luger Steakhouse'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Donohue'S Steak House"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Sammy'S Steakhouse"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Sparks Steak House'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'Z'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Keens Steakhouse'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Frankie & Johnnies Steakhouse'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Hunter'S Steak & Ale House"},
#  {'borough': 'Queens',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Bliss Street Station Restaurant'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Arirang Hibachi Steakhouse'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'T-Bar Steak & Lounge'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Bobby Van'S"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Quality Meats'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Michael Jordan'S Steak House - In Grand Central"},
#  {'borough': 'Bronx',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Riverdale Steak House'},
#  {'borough': 'Queens',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': "My Uncle'S Steak Restaurant"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Wolf And Lamb'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Del Frisco'S"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Palm Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Hillstone Manhattan'},
#  {'borough': 'Bronx',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Jake'S Steakhouse"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Ruth'S Chris Steak House"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Spain Restaurant & Bar'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'B'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Tio Pepe'},
#  {'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'P'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'La Fusta Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'El Charro Espanol'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'P'},
#    {'grade': 'B'},
#    {'grade': 'B'}],
#   'name': 'Malaga Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Cafe Riazor'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'C'},
#    {'grade': 'B'}],
#   'name': 'Cafe Espanol'},
#  {'borough': 'Bronx',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Cuchifritos'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Real Madrid Restaurant'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Sancho'S Restaurant"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Charle'S Corner Restaurant & Deli"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Ipanema Bar'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Caridad Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Pollos A La Brasa'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Toledo'},
#  {'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Scorpio Bar'},
#  {'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'El Olivo'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'El Rinconcito Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'Z'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Los Arrieros Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Nelly'S Cafe"},
#  {'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Tierras Columbianas'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Don Paco  Lopez Panderia'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'La Cabana Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Riazor Blue Tapas Bar'},
#  {'borough': 'Bronx',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Cosmos Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}],
#   'name': 'Don Coqui'},
#  {'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'C'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': "El Chivito D'Oro Iii"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}],
#   'name': "Francisco'S Centro Vasco"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'La Lechonera Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'P'},
#    {'grade': 'A'}],
#   'name': 'Bicheiros Bar'},
#  {'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'grades': [{'grade': 'A'},
# ...
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'John & Joe Pizzeria & Restaurant'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Sunset Pizzeria'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'C'}],
#   'name': 'Vesuvio Restaurant & Pizza'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Pisa Pizzeria'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Nina'S Restaurant Pizzeria"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Tony'S Pizzeria"},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Phil & Sons Restaurant & Pizzeria'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Ljubo'S Pizzeria"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'B'}, {'grade': 'B'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Rocco'S Pizzeria"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'}],
#   'name': 'Uno Chicago Grill'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'P'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Pomodoro Ristorante'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'A & S Pizzeria'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Grotto Azzura Pizzeria'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'Z'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'B'}],
#   'name': "Vaccaro'S Pizzeria & Trattoria"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Sal'S Pizzeria"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'V & S Pizzeria Of Sheapshead Bay'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'Z'},
#    {'grade': 'C'},
#    {'grade': 'C'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'Bella Napoli'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'B'}],
#   'name': "Tony'S Pizza Ii"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'A.J. Pizzeria'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Tony'S Pizzeria & Restaurant"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'P'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Caruso Pizzeria & Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Rosa #2 Pizzeria'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Gennaro'S Rest & Pizzeria"},
#  {'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': "Angelo'S Pizzeria/Mimmo'S Restaurant"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'La Villa Pizzeria'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Caterina'S Pizzeria"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Mikes Pizza'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'B'}, {'grade': 'B'}, {'grade': 'B'}],
#   'name': 'John & Tonys Pizza'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'P'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'La Casa Bella'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Rocco'S Pizzeria"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Papa Leone Pizzeria'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Lombardi'S"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Randazzo Pizza Restaurant'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'B'},
#    {'grade': 'B'}],
#   'name': 'Plum Tomatoes Pizzeria & Restaurant'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'B'}, {'grade': 'C'}, {'grade': 'A'}],
#   'name': "Vincent'S Pizzeria"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'}],
#   'name': 'Brooklyn Pizza'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': "Daniello'S Pizzeria"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Tribeca Pizzeria'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Minitalia Pizzeria'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Romeo'S Pizzeria"},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'B'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Corato Pizza Ii'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': "Vinnie'S Pizzeria/ Luncheonette"},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'}],
#   'name': "Lopez'S Pizzeria And Coffee Shop"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Pete'S Place Pizza"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Lenny & John'S Pizza"},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Gino'S Pizzeria"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Triangolo Pizzeria'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'P'}],
#   'name': 'Picasso Pizzeria'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Krispy Pizzeria'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'S S Calabro Pizzeria'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Xtra Cheese Pizzeria'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'My Little Pizzeria'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'L. A. Pizzeria'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Yolanda Pizzeria Restaurant'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Tony'S Brick Oven"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Marios Pizzeria'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'Z'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'La Bruschetta Restaurant'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'Perfecto Pizzeria'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Rossville Pizzeria'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Patsy'S Pizzeria"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': "Nicky'S Pizza"},
#  {'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Barios Pizza & Restaurant'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Danny'S Pizzeria Ii"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Monty Q'S"},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'C'},
#    {'grade': 'A'}],
#   'name': "Francesco'S Pizzeria Restaurant"},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'C'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Peppino'S Pizzeria"},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Pepe Joes Pizzeria'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'C'},
#    {'grade': 'A'}],
#   'name': "John'S Pizzeria"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'}],
#   'name': 'Rockys & Nickys Pizzeria'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'Z'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Donato'S Pizzeria Restaurant"},
#  {'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'B'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': 'Ambrosinos Pizzeria'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Dino'S Pizza & Pasta"},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Captain'S Pizzeria And Restaurant"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'Z'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'}],
#   'name': 'Del Corso Pizzeria'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'P'}],
#   'name': "Patsy'S Pizzeria"},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Patsy'S Pizzeria"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "Luigi'S Pizzeria"},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'P'},
#    {'grade': 'A'}],
#   'name': "Gaudio'S Pizzeria"},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Phillies Pizzeria Ii'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Cafe Rustico Ii'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Casabianca Pizzeria'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'Z'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': 'Italian Village Restaurant Pizzeria'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}, {'grade': 'A'}],
#   'name': "The Original Sal'S Pizzeria"},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'A'},
#    {'grade': 'B'},
#    {'grade': 'A'},
#    {'grade': 'A'}],
#   'name': "Rocco'S Pizzeria"},
#  ...]

# %% [markdown]
# 8. Devolver los restaurantes que pertenecen al distrito Bronx y preparan platos americanos o chinos

# %%
filtro = {
    "borough": "Bronx",
    "$or": [  
        {"cuisine": "American"},
        {"cuisine": "Chinese"}
    ]
}


proyeccion = {"name": 1, "cuisine": 1, "borough": 1, "_id": 0}
#los 1 en la proyección indican que deseas incluir esos campos
list(restaurantes.find(filtro, proyeccion))
# Out:
# [{'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Happy Garden'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Happy Garden'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'China Wok Ii'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Dragon City'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Hunan Balcony'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Great Wall Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Lucky House Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'New Wah Kitchen'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'New Hing Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Hong Kong Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': "Kristy'S Restaurant"},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'East Dynasty'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Lin Home Chinese Restaura'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Peacock Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': "Lin'S Garden"},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'New Rainbow Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Happy Garden'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Happy Garden'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'China Wok Ii'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Dragon City'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Hunan Balcony'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Great Wall Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Lucky House Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'New Wah Kitchen'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'New Hing Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Hong Kong Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': "Kristy'S Restaurant"},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'East Dynasty'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Lin Home Chinese Restaura'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Peacock Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': "Lin'S Garden"},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'New Rainbow Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Happy Garden'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Happy Garden'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'China Wok Ii'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Dragon City'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Hunan Balcony'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Great Wall Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Lucky House Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'New Wah Kitchen'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'New Hing Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Hong Kong Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': "Kristy'S Restaurant"},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'East Dynasty'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Lin Home Chinese Restaura'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'Peacock Restaurant'},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': "Lin'S Garden"},
#  {'borough': 'Bronx', 'cuisine': 'Chinese', 'name': 'New Rainbow Restaurant'}]

# %% [markdown]
# 9. Devolver ID del restaurante, nombre, distrito y la cocina para aquellos restaurantes que pertenecen al distrito de Staten Island o Queens o Bronx o Brooklyn

# %%
filtro = {

    #coincidencias flexibles 
    #Permite coincidencias que ignoran mayúsculas/minúsculas ("$options": "i").
    "$or": [
        {"borough": {"$regex": "staten island", "$options": "i"}},
        {"borough": {"$regex": "queens", "$options": "i"}},
        {"borough": {"$regex": "bronx", "$options": "i"}},
        {"borough": {"$regex": "brooklyn", "$options": "i"}}
    ]
}

proyeccion = {"name": 1, "cuisine": 1, "borough": 1, "_id": 1}
list(restaurantes.find(filtro, proyeccion))
# Out:
# [{'_id': ObjectId('67349b13ace753fad167f78b'),
#   'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Morris Park Bake Shop'},
#  {'_id': ObjectId('67349b13ace753fad167f78c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S"},
#  {'_id': ObjectId('67349b13ace753fad167f78e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Riviera Caterer'},
#  {'_id': ObjectId('67349b13ace753fad167f78f'),
#   'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Tov Kosher Kitchen'},
#  {'_id': ObjectId('67349b13ace753fad167f790'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Brunos On The Boulevard'},
#  {'_id': ObjectId('67349b13ace753fad167f791'),
#   'borough': 'Staten Island',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Kosher Island'},
#  {'_id': ObjectId('67349b13ace753fad167f792'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'name': "Wilken'S Fine Food"},
#  {'_id': ObjectId('67349b13ace753fad167f793'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Regina Caterers'},
#  {'_id': ObjectId('67349b13ace753fad167f794'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Taste The Tropics Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad167f795'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Wild Asia'},
#  {'_id': ObjectId('67349b13ace753fad167f796'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'C & C Catering Service'},
#  {'_id': ObjectId('67349b13ace753fad167f797'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'May May Kitchen'},
#  {'_id': ObjectId('67349b13ace753fad167f799'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Seuda Foods'},
#  {'_id': ObjectId('67349b13ace753fad167f79a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad167f79b'),
#   'borough': 'Queens',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad167f79c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'name': 'Nordic Delicacies'},
#  {'_id': ObjectId('67349b13ace753fad167f79e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'The Movable Feast'},
#  {'_id': ObjectId('67349b13ace753fad167f79f'),
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'name': "Sal'S Deli"},
#  {'_id': ObjectId('67349b13ace753fad167f7a1'),
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'name': "Steve Chu'S Deli & Grocery"},
#  {'_id': ObjectId('67349b13ace753fad167f7a5'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f7a6'),
#   'borough': 'Queens',
#   'cuisine': 'Chinese',
#   'name': 'Ho Mei Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f7a8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': "Shashemene Int'L Restaura"},
#  {'_id': ObjectId('67349b13ace753fad167f7aa'),
#   'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad167f7ab'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts"},
#  {'_id': ObjectId('67349b13ace753fad167f7ac'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Mejlander & Mulgannon'},
#  {'_id': ObjectId('67349b13ace753fad167f7ae'),
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden'},
#  {'_id': ObjectId('67349b13ace753fad167f7b0'),
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'name': "Tony'S Deli"},
#  {'_id': ObjectId('67349b13ace753fad167f7b2'),
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'name': 'Bagels N Buns'},
#  {'_id': ObjectId('67349b13ace753fad167f7b3'),
#   'borough': 'Queens',
#   'cuisine': 'Bagels/Pretzels',
#   'name': 'Hot Bagels'},
#  {'_id': ObjectId('67349b13ace753fad167f7b4'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Snack Time Grill'},
#  {'_id': ObjectId('67349b13ace753fad167f7b8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Sonny'S Heros"},
#  {'_id': ObjectId('67349b13ace753fad167f7b9'),
#   'borough': 'Staten Island',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'name': 'Carvel Ice Cream'},
#  {'_id': ObjectId('67349b13ace753fad167f7ba'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'Golden Pavillion'},
#  {'_id': ObjectId('67349b13ace753fad167f7bd'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Kosher Bagel Hole'},
#  {'_id': ObjectId('67349b13ace753fad167f7be'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Terminal Cafe/Yankee Clipper'},
#  {'_id': ObjectId('67349b13ace753fad167f7bf'),
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'name': 'Plaza Bagels & Deli'},
#  {'_id': ObjectId('67349b13ace753fad167f7c0'),
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Happy Garden'},
#  {'_id': ObjectId('67349b13ace753fad167f7c1'),
#   'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'name': 'B & M Hot Bagel & Grocery'},
#  {'_id': ObjectId('67349b13ace753fad167f7c3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Philadelhia Grille Express'},
#  {'_id': ObjectId('67349b13ace753fad167f7c4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'name': 'Peter Luger Steakhouse'},
#  {'_id': ObjectId('67349b13ace753fad167f7c8'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Manhem Club'},
#  {'_id': ObjectId('67349b13ace753fad167f7cb'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Polish',
#   'name': 'Polish National Home'},
#  {'_id': ObjectId('67349b13ace753fad167f7ce'),
#   'borough': 'Queens',
#   'cuisine': 'German',
#   'name': 'Gottscheer Hall'},
#  {'_id': ObjectId('67349b13ace753fad167f7d1'),
#   'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Ben-Best Deli & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f7d5'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Junior'S"},
#  {'_id': ObjectId('67349b13ace753fad167f7d6'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Great Kills Yacht Club'},
#  {'_id': ObjectId('67349b13ace753fad167f7d8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Towne Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f7db'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'name': 'New Park Pizzeria & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f7dc'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Douglaston Club'},
#  {'_id': ObjectId('67349b13ace753fad167f7de'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Melody Lanes'},
#  {'_id': ObjectId('67349b13ace753fad167f7df'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': "Rizzo'S Fine Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f7e0'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The New Starling Athletic Club Of The Bronx'},
#  {'_id': ObjectId('67349b13ace753fad167f7e2'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': 'Crystal Room'},
#  {'_id': ObjectId('67349b13ace753fad167f7e3'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Labetti'S Post # 2159"},
#  {'_id': ObjectId('67349b13ace753fad167f7e4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Shell Lanes'},
#  {'_id': ObjectId('67349b13ace753fad167f7e7'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'South Shore Swimming Club'},
#  {'_id': ObjectId('67349b13ace753fad167f7e9'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Donuts',
#   'name': 'Nostrand Donut Shop'},
#  {'_id': ObjectId('67349b13ace753fad167f7f0'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'New Corner'},
#  {'_id': ObjectId('67349b13ace753fad167f7f5'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'name': "Joe & Pat'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f7f7'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Palace Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f7f8'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Yankee Tavern'},
#  {'_id': ObjectId('67349b13ace753fad167f7fb'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Reben Luncheonette'},
#  {'_id': ObjectId('67349b13ace753fad167f7fd'),
#   'borough': 'Queens',
#   'cuisine': 'Chinese',
#   'name': 'King Yum Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f7fe'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Jahn'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f7ff'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'J&V Famous Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f802'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Joyce'S Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167f805'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': "Gargiulo'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f807'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Parkside Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f808'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Lavelle'S Admiral'S Club"},
#  {'_id': ObjectId('67349b13ace753fad167f80b'),
#   'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Mcdwyers Pub'},
#  {'_id': ObjectId('67349b13ace753fad167f80d'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Nancy'S Fire Side"},
#  {'_id': ObjectId('67349b13ace753fad167f810'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Blarney Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f811'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Margherita Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f812'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Healy'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167f813'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Fifth Avenue Bingo'},
#  {'_id': ObjectId('67349b13ace753fad167f814'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'name': "Denino'S Pizzeria Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167f815'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': "Michael'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f817'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Lenihan'S Saloon"},
#  {'_id': ObjectId('67349b13ace753fad167f818'),
#   'borough': 'Queens',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Emilio Iii Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f81a'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Don Peppe'},
#  {'_id': ObjectId('67349b13ace753fad167f81b'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Blarney Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f81c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Three Star Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f820'),
#   'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Naomi Kosher Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f821'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Roll-N-Roaster'},
#  {'_id': ObjectId('67349b13ace753fad167f823'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Brennan & Carr'},
#  {'_id': ObjectId('67349b13ace753fad167f824'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'The Punch Bowl'},
#  {'_id': ObjectId('67349b13ace753fad167f825'),
#   'borough': 'Queens',
#   'cuisine': 'Chinese',
#   'name': 'Jardin De China Rest'},
#  {'_id': ObjectId('67349b13ace753fad167f826'),
#   'borough': 'Queens',
#   'cuisine': 'Irish',
#   'name': 'Irish Cottage'},
#  {'_id': ObjectId('67349b13ace753fad167f828'),
#   'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Shimons Kosher Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f82a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Fascati'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f82c'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Li Greci'S Staaten Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f82e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Tamaqua'},
#  {'_id': ObjectId('67349b13ace753fad167f82f'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Munchtime'},
#  {'_id': ObjectId('67349b13ace753fad167f830'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Cara Mia'},
#  {'_id': ObjectId('67349b13ace753fad167f831'),
#   'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop'},
#  {'_id': ObjectId('67349b13ace753fad167f832'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Maloney'S Bar"},
#  {'_id': ObjectId('67349b13ace753fad167f833'),
#   'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'name': 'La Fusta Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f834'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Richmond County Country Club'},
#  {'_id': ObjectId('67349b13ace753fad167f835'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Little Brown Jug'},
#  {'_id': ObjectId('67349b13ace753fad167f836'),
#   'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': "Lulu'S Coffee Shop"},
#  {'_id': ObjectId('67349b13ace753fad167f837'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Soul Food',
#   'name': "Mitchell'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f83a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Da Vinci Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f83c'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Marina Delray'},
#  {'_id': ObjectId('67349b13ace753fad167f83d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'New Floridian Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f83f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Narrows Coffee Shop'},
#  {'_id': ObjectId('67349b13ace753fad167f841'),
#   'borough': 'Queens',
#   'cuisine': 'Irish',
#   'name': "O'Hanlon'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167f842'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Charlies Sports Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f844'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'name': "Jack'S Pizza & Pasta"},
#  {'_id': ObjectId('67349b13ace753fad167f84a'),
#   'borough': 'Queens',
#   'cuisine': 'German',
#   'name': 'Zum Stammtisch'},
#  {'_id': ObjectId('67349b13ace753fad167f84d'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Buddy'S Wonder Bar"},
#  {'_id': ObjectId('67349b13ace753fad167f84e'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'The Assembly Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f850'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Piccola Venezia'},
#  {'_id': ObjectId('67349b13ace753fad167f852'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': "Ni-Ni'S Cafe"},
#  {'_id': ObjectId('67349b13ace753fad167f856'),
#   'borough': 'Queens',
#   'cuisine': 'Seafood',
#   'name': "Lenny'S Clam Bar"},
#  {'_id': ObjectId('67349b13ace753fad167f859'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Dani Pizza And Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f85a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f85b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Greek',
#   'name': 'El Greco Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f85d'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f85f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Lb Spumoni Gardens'},
#  {'_id': ObjectId('67349b13ace753fad167f860'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Amore Pizzeria & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f861'),
#   'borough': 'Bronx',
#   'cuisine': 'Not Listed/Not Applicable',
#   'name': "The Lark'S Nest"},
#  {'_id': ObjectId('67349b13ace753fad167f862'),
#   'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Terrace Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f863'),
#   'borough': 'Bronx',
#   'cuisine': 'African',
#   'name': 'African Terrace'},
#  {'_id': ObjectId('67349b13ace753fad167f864'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Cool Zone'},
#  {'_id': ObjectId('67349b13ace753fad167f865'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Beaver Pond'},
#  {'_id': ObjectId('67349b13ace753fad167f866'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'African Market (Baboon Cafe)'},
#  {'_id': ObjectId('67349b13ace753fad167f867'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': 'Roadhouse Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f86a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Mill Basin Kosher Deli'},
#  {'_id': ObjectId('67349b13ace753fad167f86d'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Colonnade Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f874'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Frost Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f877'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Denny'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167f87a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'New Parkway Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f87e'),
#   'borough': 'Queens',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Marbella Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f87f'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "P.J.' S"},
#  {'_id': ObjectId('67349b13ace753fad167f882'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'name': "Valentino'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f885'),
#   'borough': 'Queens',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': "Steve'S Coffee Shop"},
#  {'_id': ObjectId('67349b13ace753fad167f886'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Blue Bay Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f888'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'The Hytes Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f88a'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Jody'S Club"},
#  {'_id': ObjectId('67349b13ace753fad167f88c'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Whitestone Lanes'},
#  {'_id': ObjectId('67349b13ace753fad167f88d'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': "John'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f88e'),
#   'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Seashore Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f892'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Armando'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f895'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f897'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Cafe Capri'},
#  {'_id': ObjectId('67349b13ace753fad167f898'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Bronx Grill'},
#  {'_id': ObjectId('67349b13ace753fad167f899'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'The River Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f89b'),
#   'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Johnny'S Reef Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f89c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f89d'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f89e'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f89f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f8a0'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': "Ferdinando'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f8a1'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8a5'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8a7'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'name': "Gino'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f8aa'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "P & K'S Grill"},
#  {'_id': ObjectId('67349b13ace753fad167f8ab'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8b0'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'The Dart Inn'},
#  {'_id': ObjectId('67349b13ace753fad167f8b1'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': "Bamonte'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f8b2'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Town'},
#  {'_id': ObjectId('67349b13ace753fad167f8b4'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "John Mulligan'S Fireside Pub"},
#  {'_id': ObjectId('67349b13ace753fad167f8b5'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167f8b7'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167f8b8'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167f8ba'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Greenpoint Tavern'},
#  {'_id': ObjectId('67349b13ace753fad167f8bb'),
#   'borough': 'Staten Island',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8bc'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Tony'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f8be'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Pat'S Stationary"},
#  {'_id': ObjectId('67349b13ace753fad167f8c2'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Divers Cove'},
#  {'_id': ObjectId('67349b13ace753fad167f8c3'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Tjk Cafe & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8c6'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8c8'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Perkins Family Restaurant & Bakery'},
#  {'_id': ObjectId('67349b13ace753fad167f8c9'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167f8ca'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167f8cc'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Manducatis'},
#  {'_id': ObjectId('67349b13ace753fad167f8cd'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Sizzler'},
#  {'_id': ObjectId('67349b13ace753fad167f8ce'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Mama Lucia'},
#  {'_id': ObjectId('67349b13ace753fad167f8d1'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': "Vinny'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f8d2'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Kosher Delight'},
#  {'_id': ObjectId('67349b13ace753fad167f8d5'),
#   'borough': 'Queens',
#   'cuisine': 'French',
#   'name': 'La Baraka Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8d6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Dairy Luncheonette'},
#  {'_id': ObjectId('67349b13ace753fad167f8d8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'La Palina Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8d9'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Schaffer'S Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167f8db'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': "Aunt Bella'S Rest Of Little Neck"},
#  {'_id': ObjectId('67349b13ace753fad167f8dc'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Mariner Inn'},
#  {'_id': ObjectId('67349b13ace753fad167f8dd'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'North Shore Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f8de'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Exclusive Catering'},
#  {'_id': ObjectId('67349b13ace753fad167f8df'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Green House Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f8e0'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f8e1'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Water Front Crab House'},
#  {'_id': ObjectId('67349b13ace753fad167f8e3'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': 'Marina Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f8e5'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167f8e6'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Dazies Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8e7'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Triestes Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8e8'),
#   'borough': 'Queens',
#   'cuisine': 'Greek',
#   'name': 'Omonia Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f8ea'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Veterans Of Foreign Wars Post #107 Canteen'},
#  {'_id': ObjectId('67349b13ace753fad167f8ec'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Bakery',
#   'name': 'Tropical House Baking Co.'},
#  {'_id': ObjectId('67349b13ace753fad167f8ed'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167f8ee'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Yankee Jz Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f8ef'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Clinton Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f8f1'),
#   'borough': 'Staten Island',
#   'cuisine': 'Chinese',
#   'name': "Chen'S Chinese"},
#  {'_id': ObjectId('67349b13ace753fad167f8f4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Mexican',
#   'name': 'Casa Pepe'},
#  {'_id': ObjectId('67349b13ace753fad167f8f6'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Golden Dove Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f8f8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Korner Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167f8f9'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Henry'S End"},
#  {'_id': ObjectId('67349b13ace753fad167f8fd'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Petes Pizzeria & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f900'),
#   'borough': 'Queens',
#   'cuisine': 'Irish',
#   'name': 'Ready Penny Inn'},
#  {'_id': ObjectId('67349b13ace753fad167f903'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f906'),
#   'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop'},
#  {'_id': ObjectId('67349b13ace753fad167f907'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Bridgeview Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f908'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Burke'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167f909'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Hill Tap Tavern'},
#  {'_id': ObjectId('67349b13ace753fad167f90c'),
#   'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Tony'S Pier Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f90e'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Quality Cafe & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f910'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Victoria Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f913'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'El Caribe'},
#  {'_id': ObjectId('67349b13ace753fad167f915'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f916'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f919'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Europa Go-Go Dancing'},
#  {'_id': ObjectId('67349b13ace753fad167f91d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Turkey'S Nest Tavern"},
#  {'_id': ObjectId('67349b13ace753fad167f91e'),
#   'borough': 'Bronx',
#   'cuisine': 'Chinese/Cuban',
#   'name': 'Sabrosura Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f91f'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'La Villa De Pizza & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f920'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Ozone Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167f921'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Ponticello Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f927'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Maria Ristorante'},
#  {'_id': ObjectId('67349b13ace753fad167f929'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': "Neron'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f92a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Villa Fiorita'},
#  {'_id': ObjectId('67349b13ace753fad167f92b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Vegas Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f92c'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Moms Luncheonette'},
#  {'_id': ObjectId('67349b13ace753fad167f930'),
#   'borough': 'Queens',
#   'cuisine': 'Greek',
#   'name': 'Fontana Famous Pizza & Gyro'},
#  {'_id': ObjectId('67349b13ace753fad167f933'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Portofino'},
#  {'_id': ObjectId('67349b13ace753fad167f934'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "King'S Arms Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f937'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Marco Polo Ristorante'},
#  {'_id': ObjectId('67349b13ace753fad167f93a'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'War Memorial Ice Skating Rink'},
#  {'_id': ObjectId('67349b13ace753fad167f93b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Mediterranean',
#   'name': 'Tripoli Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f93f'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Water'S Edge Club"},
#  {'_id': ObjectId('67349b13ace753fad167f942'),
#   'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': "Jp'S Waterside Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f943'),
#   'borough': 'Queens',
#   'cuisine': 'Irish',
#   'name': 'Rogers Irish Tavern'},
#  {'_id': ObjectId('67349b13ace753fad167f944'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': 'John & Joe Pizzeria & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f945'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Sunset Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167f946'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f949'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Napoli Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f94a'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Vesuvio Restaurant & Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f94b'),
#   'borough': 'Queens',
#   'cuisine': 'Caribbean',
#   'name': 'Western Bakery'},
#  {'_id': ObjectId('67349b13ace753fad167f94f'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Windjammers Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f950'),
#   'borough': 'Queens',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts/Baskin' Robbins"},
#  {'_id': ObjectId('67349b13ace753fad167f952'),
#   'borough': 'Queens',
#   'cuisine': 'Japanese',
#   'name': 'Narita Japanese Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f955'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Red Rose'},
#  {'_id': ObjectId('67349b13ace753fad167f956'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tony'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f957'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Fiorentino Ristorante'},
#  {'_id': ObjectId('67349b13ace753fad167f958'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Port O' Calls"},
#  {'_id': ObjectId('67349b13ace753fad167f95b'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Mike'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167f95c'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'The Clubhouse'},
#  {'_id': ObjectId('67349b13ace753fad167f95e'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Fame Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f95f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Knights Of Baron Dekalb'},
#  {'_id': ObjectId('67349b13ace753fad167f960'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Union Hall'},
#  {'_id': ObjectId('67349b13ace753fad167f961'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Kosher Hut Of Brooklyn'},
#  {'_id': ObjectId('67349b13ace753fad167f964'),
#   'borough': 'Queens',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Flamingo'},
#  {'_id': ObjectId('67349b13ace753fad167f968'),
#   'borough': 'Queens',
#   'cuisine': 'Seafood',
#   'name': 'London Lennies'},
#  {'_id': ObjectId('67349b13ace753fad167f969'),
#   'borough': 'Bronx',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts"},
#  {'_id': ObjectId('67349b13ace753fad167f971'),
#   'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Aqueduct North'},
#  {'_id': ObjectId('67349b13ace753fad167f974'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Yankee Clipper'},
#  {'_id': ObjectId('67349b13ace753fad167f975'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Rex Manor'},
#  {'_id': ObjectId('67349b13ace753fad167f976'),
#   'borough': 'Bronx',
#   'cuisine': 'Spanish',
#   'name': 'Cuchifritos'},
#  {'_id': ObjectId('67349b13ace753fad167f978'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Riverdale Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f979'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Carlos Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f97c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Japanese',
#   'name': 'Geido Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f97f'),
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'name': 'Annam Braham Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f981'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Bottled beverages, including water, sodas, juices, etc.',
#   'name': 'Montero Bar & Grill'},
#  {'_id': ObjectId('67349b13ace753fad167f982'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Pisa Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167f984'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Seafood',
#   'name': "Pete'S Clam Stop"},
#  {'_id': ObjectId('67349b13ace753fad167f987'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Smiling Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f988'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Riverhead Gentlemen'S Club"},
#  {'_id': ObjectId('67349b13ace753fad167f98b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Nina'S Restaurant Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f98d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Clark'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f992'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': "Duffy'S"},
#  {'_id': ObjectId('67349b13ace753fad167f993'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Uno Chicago Grill'},
#  {'_id': ObjectId('67349b13ace753fad167f994'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Latourette Golf Course'},
#  {'_id': ObjectId('67349b13ace753fad167f995'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Dyker Beach Golf (Grill Room)'},
#  {'_id': ObjectId('67349b13ace753fad167f996'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': "Glenda'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f997'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "My Father'S Place"},
#  {'_id': ObjectId('67349b13ace753fad167f998'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Tex-Mex',
#   'name': 'Santa Fe Grill & Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f99b'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f99d'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Castlehill Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f99e'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Tommy'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f9a1'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Fe Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f9a3'),
#   'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': "Mom'S Fried Chicken"},
#  {'_id': ObjectId('67349b13ace753fad167f9a4'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Cobblestone Pub'},
#  {'_id': ObjectId('67349b13ace753fad167f9a6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "O'Sullivan'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167f9a8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Wagon'},
#  {'_id': ObjectId('67349b13ace753fad167f9ab'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Il Toscano Ristorante'},
#  {'_id': ObjectId('67349b13ace753fad167f9ac'),
#   'borough': 'Queens',
#   'cuisine': 'Seafood',
#   'name': 'Pier 25A Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f9ae'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': "Gaby'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167f9af'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Verdi Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f9b3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Tony'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f9b5'),
#   'borough': 'Staten Island',
#   'cuisine': 'Spanish',
#   'name': 'Real Madrid Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f9b6'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': "Canlon'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f9b7'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Bakery',
#   'name': "Cousin John'S Cafe And Bakery"},
#  {'_id': ObjectId('67349b13ace753fad167f9b9'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Short Stop Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f9bb'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Barone Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f9bd'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza',
#   'name': "Pizza D'Oro"},
#  {'_id': ObjectId('67349b13ace753fad167f9be'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167f9c0'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'name': 'Phil & Sons Restaurant & Pizzeria'},
#  {'_id': ObjectId('67349b13ace753fad167f9c3'),
#   'borough': 'Queens',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Omega Coffee Shop'},
#  {'_id': ObjectId('67349b13ace753fad167f9c6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Spanish',
#   'name': "Sancho'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167f9c7'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Dream Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f9c8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Indian',
#   'name': 'India Passage Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f9c9'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Burger Barn Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f9ca'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Polish',
#   'name': "Irene'S Place"},
#  {'_id': ObjectId('67349b13ace753fad167f9cb'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Kanes Deli Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f9cd'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167f9ce'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'J & R Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f9d1'),
#   'borough': 'Queens',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts/Baskin Robbins"},
#  {'_id': ObjectId('67349b13ace753fad167f9d2'),
#   'borough': 'Queens',
#   'cuisine': 'Bakery',
#   'name': 'Victory Sweet Shop'},
#  {'_id': ObjectId('67349b13ace753fad167f9d3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': "Rocco'S Calamari"},
#  {'_id': ObjectId('67349b13ace753fad167f9d5'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Grand Canyon'},
#  {'_id': ObjectId('67349b13ace753fad167f9d6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Cappuccino Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f9d7'),
#   'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'name': "Carol'S Cafe"},
#  {'_id': ObjectId('67349b13ace753fad167f9dd'),
#   'borough': 'Staten Island',
#   'cuisine': 'Pizza',
#   'name': 'Dairy Palace'},
#  {'_id': ObjectId('67349b13ace753fad167f9de'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': '200 Fifth Avenue Restaurant & Sports Bar'},
#  {'_id': ObjectId('67349b13ace753fad167f9e1'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Garden'},
#  {'_id': ObjectId('67349b13ace753fad167f9e4'),
#   'borough': 'Queens',
#   'cuisine': 'Bakery',
#   'name': 'Lefkos Pygos Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167f9e5'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Eastwood Manor'},
#  {'_id': ObjectId('67349b13ace753fad167f9e7'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Academy Restauraunt'},
#  {'_id': ObjectId('67349b13ace753fad167f9e8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Park Plaza Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167f9ec'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'name': "Hunter'S Steak & Ale House"},
#  {'_id': ObjectId('67349b13ace753fad167f9ed'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Ljubo'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167f9ee'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Dakota Diner'},
#  {'_id': ObjectId('67349b13ace753fad167f9f0'),
#   'borough': 'Staten Island',
#   'cuisine': 'Japanese',
#   'name': 'Arirang Hibachi Steak House'},
#  {'_id': ObjectId('67349b13ace753fad167f9f1'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S"},
#  {'_id': ObjectId('67349b13ace753fad167f9f2'),
#   'borough': 'Staten Island',
#   'cuisine': 'Donuts',
#   'name': 'Country Donuts'},
#  {'_id': ObjectId('67349b13ace753fad167f9f3'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Doral Donuts'},
#  {'_id': ObjectId('67349b13ace753fad167f9f4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Middle Eastern',
#   'name': "Sally & George'S Place"},
#  {'_id': ObjectId('67349b13ace753fad167f9f5'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Jacks Ale House'},
#  {'_id': ObjectId('67349b13ace753fad167f9f6'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'Venice Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167f9f8'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Pizza Plus'},
#  {'_id': ObjectId('67349b13ace753fad167f9fa'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Tasty'S"},
#  {'_id': ObjectId('67349b13ace753fad167f9fb'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Oakland Cafeteria/Queensborough Community College'},
#  {'_id': ObjectId('67349b13ace753fad167f9fc'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Q.B.Comm.College-Main Kitchen/Tiger Bites Pizza Section'},
#  {'_id': ObjectId('67349b13ace753fad167fa00'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': "Erin'S Isle"},
#  {'_id': ObjectId('67349b13ace753fad167fa01'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Tina'S Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fa04'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fa05'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Rocco'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167fa08'),
#   'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': "Frank'S Soup Bowl"},
#  {'_id': ObjectId('67349b13ace753fad167fa09'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Copper Kettle'},
#  {'_id': ObjectId('67349b13ace753fad167fa0a'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Sanremo Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167fa0c'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Science Cafe (Queensborough  Community College)'},
#  {'_id': ObjectId('67349b13ace753fad167fa0d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fa12'),
#   'borough': 'Queens',
#   'cuisine': 'Chicken',
#   'name': 'La Casa Del Pollo Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fa14'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fa16'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fa17'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Teddy'S Bar And Grill"},
#  {'_id': ObjectId('67349b13ace753fad167fa19'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Jimmy Max Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fa1e'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': "Arturo'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fa20'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': 'Nostrand Island Eatery'},
#  {'_id': ObjectId('67349b13ace753fad167fa21'),
#   'borough': 'Bronx',
#   'cuisine': 'Italian',
#   'name': 'Venice Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fa22'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Walnut Bus Stop'},
#  {'_id': ObjectId('67349b13ace753fad167fa23'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Kelly'S Pub"},
#  {'_id': ObjectId('67349b13ace753fad167fa24'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Rosebank Tavern'},
#  {'_id': ObjectId('67349b13ace753fad167fa26'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Areo Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fa27'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Green Pavilion Restaurant & Sports Lounge'},
#  {'_id': ObjectId('67349b13ace753fad167fa2e'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S"},
#  {'_id': ObjectId('67349b13ace753fad167fa30'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Luigi'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fa36'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Lucky Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167fa37'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'name': 'The Pizza Place'},
#  {'_id': ObjectId('67349b13ace753fad167fa38'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Amnon Kosher Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167fa39'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167fa3e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': "Lee'S Villa Chinese Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fa3f'),
#   'borough': 'Bronx',
# ...
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Mikes Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167fe70'),
#   'borough': 'Queens',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts, Baskin Robbins"},
#  {'_id': ObjectId('67349b13ace753fad167fe71'),
#   'borough': 'Staten Island',
#   'cuisine': 'German',
#   'name': "Killmeyer'S Old Bavaria Inn."},
#  {'_id': ObjectId('67349b13ace753fad167fe72'),
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Hunan Balcony'},
#  {'_id': ObjectId('67349b13ace753fad167fe73'),
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Great Wall Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fe74'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': "Gigi'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167fe77'),
#   'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'name': 'Ground Level Beer Pub'},
#  {'_id': ObjectId('67349b13ace753fad167fe78'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Mexican',
#   'name': 'Acapulco Deli & Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fe7a'),
#   'borough': 'Staten Island',
#   'cuisine': 'Chinese',
#   'name': 'Happy Fortune'},
#  {'_id': ObjectId('67349b13ace753fad167fe7c'),
#   'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Boston Market'},
#  {'_id': ObjectId('67349b13ace753fad167fe7d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Lenny'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167fe7e'),
#   'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'La Bella Rosa Bakery'},
#  {'_id': ObjectId('67349b13ace753fad167fe80'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Familia Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fe82'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Am'},
#  {'_id': ObjectId('67349b13ace753fad167fe83'),
#   'borough': 'Queens',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Gauchito Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fe85'),
#   'borough': 'Queens',
#   'cuisine': 'Chinese',
#   'name': 'Oriental Star Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fe87'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': "Ciro'S Pizza Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167fe88'),
#   'borough': 'Bronx',
#   'cuisine': 'Chicken',
#   'name': 'Kennedy Fried Chicken'},
#  {'_id': ObjectId('67349b13ace753fad167fe8a'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Last Stop Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fe8b'),
#   'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Isla Cuchifritos'},
#  {'_id': ObjectId('67349b13ace753fad167fe8d'),
#   'borough': 'Queens',
#   'cuisine': 'Chinese',
#   'name': "New Feng'S Garden"},
#  {'_id': ObjectId('67349b13ace753fad167fe8e'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Keenans'},
#  {'_id': ObjectId('67349b13ace753fad167fe93'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Costco Wholesale'},
#  {'_id': ObjectId('67349b13ace753fad167fe94'),
#   'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167fe9b'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Jays Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fe9e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': '101 Restaurant And Bar'},
#  {'_id': ObjectId('67349b13ace753fad167fea1'),
#   'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Caridad Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fea7'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Gourmet On J'},
#  {'_id': ObjectId('67349b13ace753fad167fea8'),
#   'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Lena Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167feab'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': "Marino'S Pizza & Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167feb9'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Douglaston Golf Snacks'},
#  {'_id': ObjectId('67349b13ace753fad167feba'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Totonno'S Pizzeria"},
#  {'_id': ObjectId('67349b13ace753fad167febb'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Polish',
#   'name': 'Psc Cafeteria'},
#  {'_id': ObjectId('67349b13ace753fad167febe'),
#   'borough': 'Queens',
#   'cuisine': 'Mediterranean',
#   'name': 'Cafe Bar'},
#  {'_id': ObjectId('67349b13ace753fad167fec3'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': "Gussy'S Bar"},
#  {'_id': ObjectId('67349b13ace753fad167fec6'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Turkish',
#   'name': 'Sahara Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fec9'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Sandwiches/Salads/Mixed Buffet',
#   'name': 'Au Bon Pain'},
#  {'_id': ObjectId('67349b13ace753fad167fece'),
#   'borough': 'Queens',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'La Cabana Argentina'},
#  {'_id': ObjectId('67349b13ace753fad167fed0'),
#   'borough': 'Queens',
#   'cuisine': 'Chicken',
#   'name': 'Caravan Chicken'},
#  {'_id': ObjectId('67349b13ace753fad167fed2'),
#   'borough': 'Staten Island',
#   'cuisine': 'Bagels/Pretzels',
#   'name': 'Bagel Deli / Village Green Deli'},
#  {'_id': ObjectId('67349b13ace753fad167fed4'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'La Bagel Delight'},
#  {'_id': ObjectId('67349b13ace753fad167fed7'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Connie O'S"},
#  {'_id': ObjectId('67349b13ace753fad167fedc'),
#   'borough': 'Staten Island',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Starbucks Coffee'},
#  {'_id': ObjectId('67349b13ace753fad167fedd'),
#   'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'La Perla Mexicana'},
#  {'_id': ObjectId('67349b13ace753fad167fede'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Shem Tov'},
#  {'_id': ObjectId('67349b13ace753fad167fedf'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Mexican',
#   'name': 'Grand Morelos Diner & Bakery'},
#  {'_id': ObjectId('67349b13ace753fad167fee0'),
#   'borough': 'Queens',
#   'cuisine': 'Filipino',
#   'name': 'Krystal Pastry Shop'},
#  {'_id': ObjectId('67349b13ace753fad167fee3'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Usuluteco Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167fee4'),
#   'borough': 'Queens',
#   'cuisine': 'Pancakes/Waffles',
#   'name': 'Ihop'},
#  {'_id': ObjectId('67349b13ace753fad167fee6'),
#   'borough': 'Queens',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Starbucks Coffee'},
#  {'_id': ObjectId('67349b13ace753fad167fee8'),
#   'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Sugar City Bakery'},
#  {'_id': ObjectId('67349b13ace753fad167feee'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S"},
#  {'_id': ObjectId('67349b13ace753fad167feef'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S"},
#  {'_id': ObjectId('67349b13ace753fad167fef0'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': "Wendy'S"},
#  {'_id': ObjectId('67349b13ace753fad167fef1'),
#   'borough': 'Bronx',
#   'cuisine': 'Pizza/Italian',
#   'name': "Lopez'S Pizzeria And Coffee Shop"},
#  {'_id': ObjectId('67349b13ace753fad167fef3'),
#   'borough': 'Queens',
#   'cuisine': 'Chinese',
#   'name': 'Empire Wok Kitchen'},
#  {'_id': ObjectId('67349b13ace753fad167fef5'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Glen Roy Bar And Grill'},
#  {'_id': ObjectId('67349b13ace753fad167fef7'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Crystal Manor'},
#  {'_id': ObjectId('67349b13ace753fad167fefa'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'An Beal Bocht Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167fefe'),
#   'borough': 'Bronx',
#   'cuisine': 'Mexican',
#   'name': 'Diamante Poblano Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167ff00'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Archer Sports Bar'},
#  {'_id': ObjectId('67349b13ace753fad167ff04'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Georges Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167ff05'),
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'Lucky House Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167ff06'),
#   'borough': 'Queens',
#   'cuisine': 'Indian',
#   'name': 'Santoor Indian Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167ff07'),
#   'borough': 'Queens',
#   'cuisine': 'Caribbean',
#   'name': 'Golden Krust Caribbean Bakery & Grill'},
#  {'_id': ObjectId('67349b13ace753fad167ff08'),
#   'borough': 'Staten Island',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167ff0a'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'El Dorado Sports Lounge'},
#  {'_id': ObjectId('67349b13ace753fad167ff0c'),
#   'borough': 'Bronx',
#   'cuisine': 'Irish',
#   'name': 'Shamrock Inn'},
#  {'_id': ObjectId('67349b13ace753fad167ff0d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Donuts',
#   'name': "Dunkin' Donuts"},
#  {'_id': ObjectId('67349b13ace753fad167ff0e'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'Burger King'},
#  {'_id': ObjectId('67349b13ace753fad167ff11'),
#   'borough': 'Queens',
#   'cuisine': 'Bakery',
#   'name': 'Rio Dela Plata Bakery'},
#  {'_id': ObjectId('67349b13ace753fad167ff13'),
#   'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'name': 'New Wah Kitchen'},
#  {'_id': ObjectId('67349b13ace753fad167ff17'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'The Gate'},
#  {'_id': ObjectId('67349b13ace753fad167ff18'),
#   'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'name': 'Crab Shanty'},
#  {'_id': ObjectId('67349b13ace753fad167ff20'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'name': 'Great Wall Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167ff21'),
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'name': 'Whitestone Bagel Factory'},
#  {'_id': ObjectId('67349b13ace753fad167ff22'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': 'Throgs Neck Clipper'},
#  {'_id': ObjectId('67349b13ace753fad167ff25'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': 'Topaze Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167ff26'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Mexican',
#   'name': 'Mezcals Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167ff27'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Pete'S Place Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167ff28'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': "Vinny'S Of Carroll Garden Restaurant & Luncheonett"},
#  {'_id': ObjectId('67349b13ace753fad167ff2b'),
#   'borough': 'Bronx',
#   'cuisine': 'American ',
#   'name': "Cafe Lou'S"},
#  {'_id': ObjectId('67349b13ace753fad167ff2d'),
#   'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'name': 'Airport Deli'},
#  {'_id': ObjectId('67349b13ace753fad167ff2e'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Napoli Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167ff31'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Greek',
#   'name': 'Souvlaki House'},
#  {'_id': ObjectId('67349b13ace753fad167ff34'),
#   'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'name': 'White Castle'},
#  {'_id': ObjectId('67349b13ace753fad167ff36'),
#   'borough': 'Bronx',
#   'cuisine': 'Caribbean',
#   'name': 'Barries Restaurant'},
#  {'_id': ObjectId('67349b13ace753fad167ff39'),
#   'borough': 'Queens',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Egyptian Coffee Shop'},
#  {'_id': ObjectId('67349b13ace753fad167ff3a'),
#   'borough': 'Queens',
#   'cuisine': 'Irish',
#   'name': "Mc Guinness'S"},
#  {'_id': ObjectId('67349b13ace753fad167ff3c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Rocky'S Pizza Restaurant"},
#  {'_id': ObjectId('67349b13ace753fad167ff3d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Anna Maria Pizza Pasta'},
#  {'_id': ObjectId('67349b13ace753fad167ff41'),
#   'borough': 'Queens',
#   'cuisine': 'Caribbean',
#   'name': 'Jerk Hut'},
#  {'_id': ObjectId('67349b13ace753fad167ff42'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Bel-Aire Diner'},
#  {'_id': ObjectId('67349b13ace753fad167ff43'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': "Mama Carmela'S"},
#  {'_id': ObjectId('67349b13ace753fad167ff45'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Family Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167ff46'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': 'Imperial Biker Bar'},
#  {'_id': ObjectId('67349b13ace753fad167ff47'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'name': 'Royal Bakery & Roti Shop'},
#  {'_id': ObjectId('67349b13ace753fad167ff48'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': "Gino'S Pizza"},
#  {'_id': ObjectId('67349b13ace753fad167ff49'),
#   'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'name': 'Don Coqui'},
#  {'_id': ObjectId('67349b13ace753fad167ff4c'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Chicken',
#   'name': 'Popeyes Chicken & Biscuits'},
#  {'_id': ObjectId('67349b13ace753fad167ff4d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'name': "Mcdonald'S"},
#  {'_id': ObjectId('67349b13ace753fad167ff50'),
#   'borough': 'Queens',
#   'cuisine': 'Vietnamese/Cambodian/Malaysia',
#   'name': 'Pho Bac Vietnamese Seafood Cuisine'},
#  {'_id': ObjectId('67349b13ace753fad167ff51'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Bottled beverages, including water, sodas, juices, etc.',
#   'name': 'Claddagh Inn'},
#  {'_id': ObjectId('67349b13ace753fad167ff54'),
#   'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'name': 'Giralda Bakery'},
#  {'_id': ObjectId('67349b13ace753fad167ff55'),
#   'borough': 'Queens',
#   'cuisine': 'Italian',
#   'name': 'Villa Russo'},
#  {'_id': ObjectId('67349b13ace753fad167ff5c'),
#   'borough': 'Staten Island',
#   'cuisine': 'Chicken',
#   'name': 'Chicken Holiday Express'},
#  {'_id': ObjectId('67349b13ace753fad167ff5d'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'name': 'Think Sweet Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167ff5f'),
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'name': "Anna'S Cafe"},
#  {'_id': ObjectId('67349b13ace753fad167ff61'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Caffe Venezia'},
#  {'_id': ObjectId('67349b13ace753fad167ff62'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'Knapp St Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167ff64'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'name': 'The Original Pizza Of Avenue L'},
#  {'_id': ObjectId('67349b13ace753fad167ff67'),
#   'borough': 'Queens',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Starbucks Coffee'},
#  {'_id': ObjectId('67349b13ace753fad167ff69'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Café/Coffee/Tea',
#   'name': 'Starbucks Coffee #7358'},
#  {'_id': ObjectId('67349b13ace753fad167ff6f'),
#   'borough': 'Queens',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'Hornado Ecuatoriano'},
#  {'_id': ObjectId('67349b13ace753fad167ff71'),
#   'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'name': 'Boston Pizza'},
#  {'_id': ObjectId('67349b13ace753fad167ff72'),
#   'borough': 'Queens',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'name': 'El Dorado Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167ff73'),
#   'borough': 'Queens',
#   'cuisine': 'American ',
#   'name': 'Citibank Employee Cafeteria'},
#  {'_id': ObjectId('67349b13ace753fad167ff74'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'name': 'Pizza Royale'},
#  {'_id': ObjectId('67349b13ace753fad167ff77'),
#   'borough': 'Queens',
#   'cuisine': 'Bakery',
#   'name': 'Glendale Bakeshop & Cafe'},
#  {'_id': ObjectId('67349b13ace753fad167ff78'),
#   'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'name': "Lenny & John'S Pizza"},
#  ...]

# %% [markdown]
# 10. Devolver ID del restaurante, nombre, distrito y la cocina de aquellos restaurantes que lograron una puntuación que no supere los 10

# %%
filtro = {
    "grades.score": {"$lt": 10}
}

proyeccion = {"restaurant_id": 1,"name":1, "borough":1, "cuisine":1,"grades.score":1, "_id":0}
list(restaurantes.find(filtro, proyeccion))
# Out:
# [{'borough': 'Bronx',
#   'cuisine': 'Bakery',
#   'grades': [{'score': 2},
#    {'score': 6},
#    {'score': 10},
#    {'score': 9},
#    {'score': 14}],
#   'name': 'Morris Park Bake Shop',
#   'restaurant_id': '30075445'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'grades': [{'score': 8}, {'score': 23}, {'score': 12}, {'score': 12}],
#   'name': "Wendy'S",
#   'restaurant_id': '30112340'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'grades': [{'score': 2}, {'score': 11}, {'score': 12}, {'score': 12}],
#   'name': 'Dj Reynolds Pub And Restaurant',
#   'restaurant_id': '30191841'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 5}, {'score': 7}, {'score': 12}, {'score': 12}],
#   'name': 'Riviera Caterer',
#   'restaurant_id': '40356018'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 38}, {'score': 10}, {'score': 7}, {'score': 13}],
#   'name': 'Brunos On The Boulevard',
#   'restaurant_id': '40356151'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'score': 9}, {'score': 12}, {'score': 12}, {'score': 9}],
#   'name': 'Kosher Island',
#   'restaurant_id': '40356442'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'grades': [{'score': 10},
#    {'score': 10},
#    {'score': 8},
#    {'score': 10},
#    {'score': 13},
#    {'score': 9}],
#   'name': "Wilken'S Fine Food",
#   'restaurant_id': '40356483'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 12},
#    {'score': 12},
#    {'score': 11},
#    {'score': 2},
#    {'score': 11}],
#   'name': 'Regina Caterers',
#   'restaurant_id': '40356649'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'score': 12}, {'score': 8}, {'score': 5}, {'score': 8}],
#   'name': 'Taste The Tropics Ice Cream',
#   'restaurant_id': '40356731'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'score': 11}, {'score': 4}, {'score': 3}],
#   'name': 'Wild Asia',
#   'restaurant_id': '40357217'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 5}, {'score': 2}, {'score': 5}, {'score': 2}],
#   'name': 'C & C Catering Service',
#   'restaurant_id': '40357437'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'grades': [{'score': 21},
#    {'score': 7},
#    {'score': 56},
#    {'score': 27},
#    {'score': 27}],
#   'name': 'May May Kitchen',
#   'restaurant_id': '40358429'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 3}, {'score': 4}, {'score': 6}, {'score': 0}],
#   'name': '1 East 66Th Street Kitchen',
#   'restaurant_id': '40359480'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'score': 11},
#    {'score': 13},
#    {'score': 7},
#    {'score': 9},
#    {'score': 19}],
#   'name': 'Seuda Foods',
#   'restaurant_id': '40360045'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'score': 2},
#    {'score': 13},
#    {'score': 3},
#    {'score': 12},
#    {'score': 13}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40360076'},
#  {'borough': 'Queens',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'score': 9}, {'score': 10}, {'score': 13}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40361322'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Delicatessen',
#   'grades': [{'score': 4}, {'score': 3}, {'score': 10}],
#   'name': 'Nordic Delicacies',
#   'restaurant_id': '40361390'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 12},
#    {'score': 16},
#    {'score': 9},
#    {'score': 13},
#    {'score': 11}],
#   'name': 'Glorious Food',
#   'restaurant_id': '40361521'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 11}, {'score': 2}, {'score': 13}, {'score': 11}],
#   'name': 'The Movable Feast',
#   'restaurant_id': '40361606'},
#  {'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'grades': [{'score': 12}, {'score': 9}, {'score': 7}, {'score': 10}],
#   'name': "Sal'S Deli",
#   'restaurant_id': '40361618'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Delicatessen',
#   'grades': [{'score': 12}, {'score': 11}, {'score': 6}, {'score': 8}],
#   'name': "Bully'S Deli",
#   'restaurant_id': '40361708'},
#  {'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'grades': [{'score': 3}, {'score': 12}, {'score': 8}, {'score': 7}],
#   'name': "Steve Chu'S Deli & Grocery",
#   'restaurant_id': '40361998'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Chicken',
#   'grades': [{'score': 10},
#    {'score': 13},
#    {'score': 13},
#    {'score': 11},
#    {'score': 10},
#    {'score': 7}],
#   'name': "Harriet'S Kitchen",
#   'restaurant_id': '40362098'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 26}, {'score': 9}, {'score': 20}, {'score': 12}],
#   'name': 'P & S Deli Grocery',
#   'restaurant_id': '40362264'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 9}, {'score': 4}, {'score': 13}, {'score': 5}],
#   'name': 'Angelika Film Center',
#   'restaurant_id': '40362274'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'grades': [{'score': 8}, {'score': 8}, {'score': 7}, {'score': 2}],
#   'name': 'White Castle',
#   'restaurant_id': '40362344'},
#  {'borough': 'Queens',
#   'cuisine': 'Chinese',
#   'grades': [{'score': 10},
#    {'score': 5},
#    {'score': 12},
#    {'score': 10},
#    {'score': 0},
#    {'score': 13},
#    {'score': 12},
#    {'score': 11}],
#   'name': 'Ho Mei Restaurant',
#   'restaurant_id': '40362432'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'score': 9}, {'score': 13}, {'score': 9}, {'score': 11}],
#   'name': 'The Country Cafe',
#   'restaurant_id': '40362715'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Caribbean',
#   'grades': [{'score': 2}, {'score': 7}, {'score': 11}, {'score': 12}],
#   'name': "Shashemene Int'L Restaura",
#   'restaurant_id': '40362869'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 12},
#    {'score': 9},
#    {'score': 9},
#    {'score': 12},
#    {'score': 13},
#    {'score': 11}],
#   'name': 'Downtown Deli',
#   'restaurant_id': '40363021'},
#  {'borough': 'Bronx',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'score': 10},
#    {'score': 10},
#    {'score': 9},
#    {'score': 11},
#    {'score': 5}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363093'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Donuts',
#   'grades': [{'score': 8}, {'score': 9}, {'score': 11}, {'score': 10}],
#   'name': "Dunkin' Donuts",
#   'restaurant_id': '40363098'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 10}, {'score': 11}, {'score': 5}, {'score': 13}],
#   'name': 'Mejlander & Mulgannon',
#   'restaurant_id': '40363117'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Bakery',
#   'grades': [{'score': 11},
#    {'score': 13},
#    {'score': 7},
#    {'score': 7},
#    {'score': 3}],
#   'name': "Olive'S",
#   'restaurant_id': '40363151'},
#  {'borough': 'Bronx',
#   'cuisine': 'Chinese',
#   'grades': [{'score': 8}, {'score': 10}, {'score': 15}],
#   'name': 'Happy Garden',
#   'restaurant_id': '40363289'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 12},
#    {'score': 9},
#    {'score': 4},
#    {'score': 9},
#    {'score': 13}],
#   'name': 'Cafe Metro',
#   'restaurant_id': '40363298'},
#  {'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'grades': [{'score': 11},
#    {'score': 8},
#    {'score': 12},
#    {'score': 25},
#    {'score': 11},
#    {'score': 10}],
#   'name': "Tony'S Deli",
#   'restaurant_id': '40363333'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Sandwiches/Salads/Mixed Buffet',
#   'grades': [{'score': 3},
#    {'score': 3},
#    {'score': 0},
#    {'score': 12},
#    {'score': 5}],
#   'name': 'Lexler Deli',
#   'restaurant_id': '40363426'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'grades': [{'score': 3}, {'score': 10}, {'score': 10}, {'score': 11}],
#   'name': 'Bagels N Buns',
#   'restaurant_id': '40363427'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 7},
#    {'score': 11},
#    {'score': 7},
#    {'score': 10},
#    {'score': 0},
#    {'score': 4}],
#   'name': 'Snack Time Grill',
#   'restaurant_id': '40363590'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Continental',
#   'grades': [{'score': 9},
#    {'score': 8},
#    {'score': 26},
#    {'score': 7},
#    {'score': 25}],
#   'name': "Lorenzo & Maria'S",
#   'restaurant_id': '40363630'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 3},
#    {'score': 11},
#    {'score': 12},
#    {'score': 4},
#    {'score': 2},
#    {'score': 0}],
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40363644'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 9},
#    {'score': 5},
#    {'score': 12},
#    {'score': 11},
#    {'score': 13}],
#   'name': 'Berkely',
#   'restaurant_id': '40363685'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 0}, {'score': 3}, {'score': 10}],
#   'name': "Sonny'S Heros",
#   'restaurant_id': '40363744'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Ice Cream, Gelato, Yogurt, Ices',
#   'grades': [{'score': 12}, {'score': 5}, {'score': 2}],
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363834'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'grades': [{'score': 13}, {'score': 10}, {'score': 4}, {'score': 13}],
#   'name': 'Golden Pavillion',
#   'restaurant_id': '40363920'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 13}, {'score': 18}, {'score': 13}, {'score': 9}],
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40363945'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 20}, {'score': 23}, {'score': 12}, {'score': 8}],
#   'name': 'Spoon Bread Catering',
#   'restaurant_id': '40364179'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'score': 10}, {'score': 11}, {'score': 9}],
#   'name': 'Kosher Bagel Hole',
#   'restaurant_id': '40364220'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 9}, {'score': 10}, {'score': 9}, {'score': 32}],
#   'name': 'Terminal Cafe/Yankee Clipper',
#   'restaurant_id': '40364262'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'grades': [{'score': 12}, {'score': 12}, {'score': 7}, {'score': 5}],
#   'name': 'Plaza Bagels & Deli',
#   'restaurant_id': '40364286'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Delicatessen',
#   'grades': [{'score': 4},
#    {'score': 39},
#    {'score': 12},
#    {'score': 13},
#    {'score': 10}],
#   'name': 'B & M Hot Bagel & Grocery',
#   'restaurant_id': '40364299'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Chicken',
#   'grades': [{'score': 12},
#    {'score': 48},
#    {'score': 13},
#    {'score': 8},
#    {'score': 7}],
#   'name': 'Texas Rotisserie',
#   'restaurant_id': '40364304'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'grades': [{'score': 12}, {'score': 7}, {'score': 10}, {'score': 12}],
#   'name': 'Philadelhia Grille Express',
#   'restaurant_id': '40364305'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Steak',
#   'grades': [{'score': 12},
#    {'score': 10},
#    {'score': 3},
#    {'score': 12},
#    {'score': 13}],
#   'name': 'Peter Luger Steakhouse',
#   'restaurant_id': '40364335'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 24},
#    {'score': 4},
#    {'score': 13},
#    {'score': 12},
#    {'score': 17},
#    {'score': 11}],
#   'name': 'Metropolitan Club',
#   'restaurant_id': '40364347'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 19},
#    {'score': 12},
#    {'score': 11},
#    {'score': 8},
#    {'score': 12}],
#   'name': 'Palm Restaurant',
#   'restaurant_id': '40364355'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'score': 5}, {'score': 10}],
#   'name': 'Manhem Club',
#   'restaurant_id': '40364363'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 13},
#    {'score': 10},
#    {'score': 10},
#    {'score': 7},
#    {'score': 9}],
#   'name': 'Isle Of Capri Resturant',
#   'restaurant_id': '40364373'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 10}, {'score': 9}, {'score': 36}, {'score': 9}],
#   'name': 'Old Town Bar & Restaurant',
#   'restaurant_id': '40364389'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Polish',
#   'grades': [{'score': 2}, {'score': 3}, {'score': 6}, {'score': 54}],
#   'name': 'Polish National Home',
#   'restaurant_id': '40364404'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'grades': [{'score': 11},
#    {'score': 11},
#    {'score': 7},
#    {'score': 13},
#    {'score': 10}],
#   'name': 'Seville Restaurant',
#   'restaurant_id': '40364439'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 8}, {'score': 12}, {'score': 13}, {'score': 12}],
#   'name': 'Criminal Court Bldg Cafeteria',
#   'restaurant_id': '40364443'},
#  {'borough': 'Queens',
#   'cuisine': 'German',
#   'grades': [{'score': 11},
#    {'score': 2},
#    {'score': 27},
#    {'score': 24},
#    {'score': 20}],
#   'name': 'Gottscheer Hall',
#   'restaurant_id': '40364449'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 12},
#    {'score': 40},
#    {'score': 2},
#    {'score': 11},
#    {'score': 4},
#    {'score': 2}],
#   'name': 'Nyac Main Dining Room',
#   'restaurant_id': '40364467'},
#  {'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'score': 11},
#    {'score': 9},
#    {'score': 8},
#    {'score': 24},
#    {'score': 10},
#    {'score': 12}],
#   'name': 'Ben-Best Deli & Restaurant',
#   'restaurant_id': '40364529'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 12},
#    {'score': 12},
#    {'score': 2},
#    {'score': 20},
#    {'score': 8}],
#   'name': 'Cafe Atelier (Art Students League)',
#   'restaurant_id': '40364531'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'score': 12},
#    {'score': 8},
#    {'score': 9},
#    {'score': 3},
#    {'score': 5}],
#   'name': "Donohue'S Steak House",
#   'restaurant_id': '40364572'},
#  {'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'score': 15},
#    {'score': 13},
#    {'score': 36},
#    {'score': 22},
#    {'score': 36},
#    {'score': 7}],
#   'name': 'Tout Va Bien',
#   'restaurant_id': '40364576'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 11}, {'score': 7}, {'score': 3}, {'score': 7}],
#   'name': "Junior'S",
#   'restaurant_id': '40364581'},
#  {'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'grades': [{'score': 10}, {'score': 4}, {'score': 8}],
#   'name': 'Great Kills Yacht Club',
#   'restaurant_id': '40364610'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 11},
#    {'score': 9},
#    {'score': 27},
#    {'score': 17},
#    {'score': 21}],
#   'name': 'Towne Cafe',
#   'restaurant_id': '40364681'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Continental',
#   'grades': [{'score': 13},
#    {'score': 13},
#    {'score': 18},
#    {'score': 9},
#    {'score': 8}],
#   'name': 'Dining Room',
#   'restaurant_id': '40364691'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 9},
#    {'score': 12},
#    {'score': 24},
#    {'score': 12},
#    {'score': 2}],
#   'name': 'Old Homestead',
#   'restaurant_id': '40364715'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'score': 11}, {'score': 9}, {'score': 12}, {'score': 9}],
#   'name': 'New Park Pizzeria & Restaurant',
#   'restaurant_id': '40364744'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 13},
#    {'score': 13},
#    {'score': 9},
#    {'score': 2},
#    {'score': 23}],
#   'name': 'Douglaston Club',
#   'restaurant_id': '40364858'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 10}, {'score': 3}, {'score': 10}, {'score': 9}],
#   'name': 'Serendipity 3',
#   'restaurant_id': '40364863'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 2},
#    {'score': 12},
#    {'score': 10},
#    {'score': 12},
#    {'score': 10}],
#   'name': "Rizzo'S Fine Pizza",
#   'restaurant_id': '40364920'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'score': 7},
#    {'score': 17},
#    {'score': 12},
#    {'score': 9},
#    {'score': 19}],
#   'name': 'The New Starling Athletic Club Of The Bronx',
#   'restaurant_id': '40364956'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 2},
#    {'score': 7},
#    {'score': 2},
#    {'score': 6},
#    {'score': 5}],
#   'name': 'White Horse Tavern',
#   'restaurant_id': '40364958'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'grades': [{'score': 13}, {'score': 2}, {'score': 5}, {'score': 11}],
#   'name': 'Crystal Room',
#   'restaurant_id': '40365013'},
#  {'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'grades': [{'score': 9}, {'score': 13}, {'score': 10}, {'score': 20}],
#   'name': "Labetti'S Post # 2159",
#   'restaurant_id': '40365022'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 2},
#    {'score': 9},
#    {'score': 28},
#    {'score': 29},
#    {'score': 10}],
#   'name': 'Shell Lanes',
#   'restaurant_id': '40365043'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'grades': [{'score': 8},
#    {'score': 10},
#    {'score': 8},
#    {'score': 13},
#    {'score': 9},
#    {'score': 16}],
#   'name': "Mcsorley'S Old Ale House",
#   'restaurant_id': '40365075'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 9},
#    {'score': 10},
#    {'score': 12},
#    {'score': 11},
#    {'score': 13}],
#   'name': 'Forlinis Restaurant',
#   'restaurant_id': '40365098'},
#  {'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'grades': [{'score': 3}, {'score': 19}, {'score': 6}],
#   'name': 'South Shore Swimming Club',
#   'restaurant_id': '40365120'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 12}, {'score': 5}, {'score': 4}, {'score': 12}],
#   'name': 'Corner Bistro',
#   'restaurant_id': '40365166'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Donuts',
#   'grades': [{'score': 16},
#    {'score': 5},
#    {'score': 10},
#    {'score': 9},
#    {'score': 16},
#    {'score': 13}],
#   'name': 'Nostrand Donut Shop',
#   'restaurant_id': '40365226'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'grades': [{'score': 2}, {'score': 7}, {'score': 7}, {'score': 9}],
#   'name': "Dorrian'S Red Hand Restaurant",
#   'restaurant_id': '40365239'},
#  {'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'score': 10}, {'score': 9}, {'score': 13}],
#   'name': 'La Grenouille',
#   'restaurant_id': '40365264'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 10}, {'score': 10}, {'score': 6}, {'score': 60}],
#   'name': 'Como Pizza',
#   'restaurant_id': '40365280'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 6},
#    {'score': 2},
#    {'score': 8},
#    {'score': 9},
#    {'score': 24}],
#   'name': 'Keats Restaurant',
#   'restaurant_id': '40365288'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 11},
#    {'score': 13},
#    {'score': 9},
#    {'score': 13},
#    {'score': 11}],
#   'name': 'Angelo Of Mulberry St.',
#   'restaurant_id': '40365293'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Mexican',
#   'grades': [{'score': 10}, {'score': 9}, {'score': 13}, {'score': 20}],
#   'name': "Panchito'S",
#   'restaurant_id': '40365348'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'grades': [{'score': 11},
#    {'score': 10},
#    {'score': 9},
#    {'score': 10},
#    {'score': 12}],
#   'name': 'New Corner',
#   'restaurant_id': '40365355'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 7},
#    {'score': 9},
#    {'score': 13},
#    {'score': 29},
#    {'score': 12}],
#   'name': 'The Princeton Club',
#   'restaurant_id': '40365361'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 13},
#    {'score': 12},
#    {'score': 12},
#    {'score': 7},
#    {'score': 12}],
#   'name': "Arturo'S",
#   'restaurant_id': '40365387'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 20},
#    {'score': 10},
#    {'score': 15},
#    {'score': 23},
#    {'score': 3},
#    {'score': 23},
#    {'score': 48}],
#   'name': "Reynold'S Bar",
#   'restaurant_id': '40365423'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'score': 5},
#    {'score': 14},
#    {'score': 10},
#    {'score': 4},
#    {'score': 22}],
#   'name': "Joe & Pat'S Pizzeria",
#   'restaurant_id': '40365454'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'score': 12},
#    {'score': 13},
#    {'score': 9},
#    {'score': 10},
#    {'score': 13}],
#   'name': 'Spain Restaurant & Bar',
#   'restaurant_id': '40365472'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 5}, {'score': 19}, {'score': 11}, {'score': 13}],
#   'name': 'Palace Cafe',
#   'restaurant_id': '40365473'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'score': 9},
#    {'score': 4},
#    {'score': 10},
#    {'score': 15},
#    {'score': 13},
#    {'score': 10},
#    {'score': 37}],
#   'name': 'Yankee Tavern',
#   'restaurant_id': '40365499'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Donuts',
#   'grades': [{'score': 12},
#    {'score': 2},
#    {'score': 18},
#    {'score': 16},
#    {'score': 9},
#    {'score': 12}],
#   'name': 'Donut Pub',
#   'restaurant_id': '40365525'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 8},
#    {'score': 10},
#    {'score': 21},
#    {'score': 13},
#    {'score': 11}],
#   'name': 'Reben Luncheonette',
#   'restaurant_id': '40365546'},
#  {'borough': 'Queens',
#   'cuisine': 'Chinese',
#   'grades': [{'score': 14},
#    {'score': 13},
#    {'score': 10},
#    {'score': 13},
#    {'score': 2},
#    {'score': 36}],
#   'name': 'King Yum Restaurant',
#   'restaurant_id': '40365592'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 10},
#    {'score': 13},
#    {'score': 9},
#    {'score': 10},
#    {'score': 11},
#    {'score': 10}],
#   'name': "Jahn'S Restaurant",
#   'restaurant_id': '40365627'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 12},
#    {'score': 13},
#    {'score': 11},
#    {'score': 9},
#    {'score': 13}],
#   'name': 'J&V Famous Pizza',
#   'restaurant_id': '40365632'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 35},
#    {'score': 19},
#    {'score': 12},
#    {'score': 9},
#    {'score': 24},
#    {'score': 12},
#    {'score': 21}],
#   'name': 'La Parisienne Diner',
#   'restaurant_id': '40365633'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 7},
#    {'score': 6},
#    {'score': 5},
#    {'score': 8},
#    {'score': 13}],
#   'name': 'Joe Allen Restaurant',
#   'restaurant_id': '40365644'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 12}, {'score': 12}, {'score': 9}, {'score': 7}],
#   'name': 'Barbetta Restaurant',
#   'restaurant_id': '40365726'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'grades': [{'score': 13}, {'score': 12}, {'score': 9}, {'score': 9}],
#   'name': "Gargiulo'S Restaurant",
#   'restaurant_id': '40365784'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 10}, {'score': 6}, {'score': 12}, {'score': 13}],
#   'name': "Patsy'S Italian Restaurant",
#   'restaurant_id': '40365789'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 9},
#    {'score': 8},
#    {'score': 11},
#    {'score': 9},
#    {'score': 7}],
#   'name': "Lavelle'S Admiral'S Club",
#   'restaurant_id': '40365844'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 13},
#    {'score': 9},
#    {'score': 12},
#    {'score': 11},
#    {'score': 10},
#    {'score': 11}],
#   'name': "Neary'S Pub",
#   'restaurant_id': '40365871'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 11},
#    {'score': 5},
#    {'score': 11},
#    {'score': 9},
#    {'score': 8},
#    {'score': 12}],
#   'name': 'New York Pizza Suprema',
#   'restaurant_id': '40365882'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'grades': [{'score': 10},
#    {'score': 10},
#    {'score': 9},
#    {'score': 4},
#    {'score': 12},
#    {'score': 11},
#    {'score': 24}],
#   'name': 'Mee Sum Coffee Shop',
#   'restaurant_id': '40365904'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 4},
#    {'score': 11},
#    {'score': 13},
#    {'score': 20},
#    {'score': 21}],
#   'name': "Nancy'S Fire Side",
#   'restaurant_id': '40365938'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 18},
#    {'score': 8},
#    {'score': 23},
#    {'score': 12},
#    {'score': 12},
#    {'score': 13}],
#   'name': 'Nancy Whiskey Pub',
#   'restaurant_id': '40365968'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 10},
#    {'score': 10},
#    {'score': 13},
#    {'score': 10},
#    {'score': 9}],
#   'name': 'Blarney Bar',
#   'restaurant_id': '40365972'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 11},
#    {'score': 12},
#    {'score': 7},
#    {'score': 13},
#    {'score': 8}],
#   'name': "Healy'S Pub",
#   'restaurant_id': '40366054'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 22}, {'score': 3}, {'score': 13}, {'score': 9}],
#   'name': 'Fifth Avenue Bingo',
#   'restaurant_id': '40366109'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'score': 12}, {'score': 9}, {'score': 20}, {'score': 8}],
#   'name': "Denino'S Pizzeria Tavern",
#   'restaurant_id': '40366132'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'grades': [{'score': 9},
#    {'score': 12},
#    {'score': 12},
#    {'score': 8},
#    {'score': 20},
#    {'score': 9}],
#   'name': "Michael'S Restaurant",
#   'restaurant_id': '40366154'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 9},
#    {'score': 13},
#    {'score': 16},
#    {'score': 20},
#    {'score': 19}],
#   'name': "Lenihan'S Saloon",
#   'restaurant_id': '40366162'},
#  {'borough': 'Queens',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'grades': [{'score': 9}, {'score': 11}, {'score': 11}, {'score': 30}],
#   'name': 'Emilio Iii Bar',
#   'restaurant_id': '40366214'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'grades': [{'score': 11}, {'score': 7}, {'score': 2}, {'score': 12}],
#   'name': 'Killarney Rose',
#   'restaurant_id': '40366222'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 18},
#    {'score': 21},
#    {'score': 7},
#    {'score': 11},
#    {'score': 8}],
#   'name': 'Blarney Castle',
#   'restaurant_id': '40366356'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 12},
#    {'score': 11},
#    {'score': 7},
#    {'score': 12},
#    {'score': 24}],
#   'name': 'Three Star Restaurant',
#   'restaurant_id': '40366361'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'grades': [{'score': 12},
#    {'score': 5},
#    {'score': 9},
#    {'score': 8},
#    {'score': 13},
#    {'score': 5}],
#   'name': 'Blarney Rock',
#   'restaurant_id': '40366379'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 4}, {'score': 6}, {'score': 36}, {'score': 11}],
#   'name': "Dangerfield'S Night Club",
#   'restaurant_id': '40366381'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 12}, {'score': 13}, {'score': 11}, {'score': 9}],
#   'name': "Desmond'S Tavern",
#   'restaurant_id': '40366396'},
#  {'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'score': 9},
#    {'score': 9},
#    {'score': 26},
#    {'score': 9},
#    {'score': 11}],
#   'name': 'Naomi Kosher Pizza',
#   'restaurant_id': '40366425'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 5},
#    {'score': 10},
#    {'score': 7},
#    {'score': 13},
#    {'score': 19}],
#   'name': 'Roll-N-Roaster',
#   'restaurant_id': '40366471'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'score': 15}, {'score': 12}, {'score': 7}, {'score': 9}],
#   'name': 'Tio Pepe',
#   'restaurant_id': '40366473'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 7},
#    {'score': 11},
#    {'score': 11},
#    {'score': 12},
#    {'score': 5}],
#   'name': 'Brennan & Carr',
#   'restaurant_id': '40366487'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'score': 5},
#    {'score': 19},
#    {'score': 9},
#    {'score': 18},
#    {'score': 10},
#    {'score': 35}],
#   'name': 'The Punch Bowl',
#   'restaurant_id': '40366497'},
#  {'borough': 'Queens',
#   'cuisine': 'Chinese',
#   'grades': [{'score': 25},
#    {'score': 19},
#    {'score': 7},
#    {'score': 20},
#    {'score': 12},
#    {'score': 13},
#    {'score': 26}],
#   'name': 'Jardin De China Rest',
#   'restaurant_id': '40366543'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'grades': [{'score': 10},
#    {'score': 10},
#    {'score': 10},
#    {'score': 10},
#    {'score': 43},
#    {'score': 10},
#    {'score': 7}],
#   'name': 'Blarney Stone',
#   'restaurant_id': '40366574'},
#  {'borough': 'Queens',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'score': 9},
#    {'score': 15},
#    {'score': 11},
#    {'score': 12},
#    {'score': 11}],
#   'name': 'Shimons Kosher Pizza',
#   'restaurant_id': '40366586'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 12}, {'score': 9}, {'score': 5}, {'score': 12}],
#   'name': 'The Riviera Cafe',
#   'restaurant_id': '40366643'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'score': 12}, {'score': 13}, {'score': 11}, {'score': 8}],
#   'name': "Fascati'S Pizzeria",
#   'restaurant_id': '40366652'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Tex-Mex',
#   'grades': [{'score': 12}, {'score': 13}, {'score': 7}],
#   'name': "Baby Bo'S Burritos",
#   'restaurant_id': '40366661'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Chinese',
#   'grades': [{'score': 11}, {'score': 7}, {'score': 8}, {'score': 9}],
#   'name': 'Shun Lee Palace Restaurant',
#   'restaurant_id': '40366716'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 7}, {'score': 13}, {'score': 12}, {'score': 9}],
#   'name': 'Tamaqua',
#   'restaurant_id': '40366742'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'score': 22},
#    {'score': 7},
#    {'score': 22},
#    {'score': 12},
#    {'score': 10},
#    {'score': 16}],
#   'name': 'Munchtime',
#   'restaurant_id': '40366748'},
#  {'borough': 'Queens',
#   'cuisine': 'Italian',
#   'grades': [{'score': 13},
#    {'score': 15},
#    {'score': 10},
#    {'score': 7},
#    {'score': 11}],
#   'name': 'Cara Mia',
#   'restaurant_id': '40366812'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pancakes/Waffles',
#   'grades': [{'score': 11},
#    {'score': 9},
#    {'score': 3},
#    {'score': 24},
#    {'score': 13},
#    {'score': 7}],
#   'name': 'Ihop',
#   'restaurant_id': '40366833'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 11}, {'score': 13}, {'score': 11}, {'score': 9}],
#   'name': "Maloney'S Bar",
#   'restaurant_id': '40366857'},
#  {'borough': 'Queens',
#   'cuisine': 'Spanish',
#   'grades': [{'score': 11},
#    {'score': 12},
#    {'score': 2},
#    {'score': 12},
#    {'score': 12},
#    {'score': 10},
#    {'score': 22}],
#   'name': 'La Fusta Restaurant',
#   'restaurant_id': '40366879'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 12},
#    {'score': 2},
#    {'score': 11},
#    {'score': 13},
#    {'score': 6},
#    {'score': 11}],
#   'name': 'Little Brown Jug',
#   'restaurant_id': '40366929'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'grades': [{'score': 12},
#    {'score': 9},
#    {'score': 11},
#    {'score': 14},
#    {'score': 12}],
#   'name': "Lulu'S Coffee Shop",
#   'restaurant_id': '40366938'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Soul Food',
#   'grades': [{'score': 9},
#    {'score': 2},
#    {'score': 25},
#    {'score': 13},
#    {'score': 8}],
#   'name': "Mitchell'S Restaurant",
#   'restaurant_id': '40366961'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'score': 12},
#    {'score': 12},
#    {'score': 2},
#    {'score': 5},
#    {'score': 2},
#    {'score': 7}],
#   'name': 'El Charro Espanol',
#   'restaurant_id': '40366987'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 9}, {'score': 10}, {'score': 11}, {'score': 7}],
#   'name': "Finnegan'S Wake",
#   'restaurant_id': '40366993'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Mexican',
#   'grades': [{'score': 5}, {'score': 2}, {'score': 10}, {'score': 10}],
#   'name': 'Mexico Lindo Restaurant',
#   'restaurant_id': '40367038'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'score': 18}, {'score': 4}, {'score': 12}, {'score': 2}],
#   'name': 'Marina Delray',
#   'restaurant_id': '40367161'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 10},
#    {'score': 15},
#    {'score': 15},
#    {'score': 11},
#    {'score': 7},
#    {'score': 34},
#    {'score': 16}],
#   'name': 'New Floridian Diner',
#   'restaurant_id': '40367164'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Irish',
#   'grades': [{'score': 10},
#    {'score': 8},
#    {'score': 12},
#    {'score': 12},
#    {'score': 12}],
#   'name': 'Twins Pub',
#   'restaurant_id': '40367179'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 7}, {'score': 11}, {'score': 4}, {'score': 9}],
#   'name': 'Narrows Coffee Shop',
#   'restaurant_id': '40367183'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 13}, {'score': 7}, {'score': 7}, {'score': 14}],
#   'name': 'Broome Street Bar',
#   'restaurant_id': '40367189'},
#  {'borough': 'Queens',
#   'cuisine': 'Irish',
#   'grades': [{'score': 8},
#    {'score': 10},
#    {'score': 5},
#    {'score': 12},
#    {'score': 12}],
#   'name': "O'Hanlon'S Pub",
#   'restaurant_id': '40367232'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 4}, {'score': 11}, {'score': 10}, {'score': 2}],
#   'name': 'Charlies Sports Bar',
#   'restaurant_id': '40367240'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 12}, {'score': 24}, {'score': 9}, {'score': 10}],
#   'name': 'Jg Melon Restaurant',
#   'restaurant_id': '40367241'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 5},
#    {'score': 13},
#    {'score': 12},
#    {'score': 10},
#    {'score': 10},
#    {'score': 32}],
#   'name': 'Emerald Pub',
#   'restaurant_id': '40367329'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 2}, {'score': 12}, {'score': 8}],
#   'name': 'Tap Room',
#   'restaurant_id': '40367338'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 10},
#    {'score': 3},
#    {'score': 22},
#    {'score': 10},
#    {'score': 17}],
#   'name': 'Cocktail Room (Nyac)',
#   'restaurant_id': '40367339'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 3},
#    {'score': 7},
#    {'score': 10},
#    {'score': 8},
#    {'score': 13}],
#   'name': 'Flame Restaurant Coffee House',
#   'restaurant_id': '40367365'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 2}, {'score': 11}, {'score': 13}, {'score': 11}],
#   'name': 'Jackson Hole',
#   'restaurant_id': '40367373'},
#  {'borough': 'Queens',
#   'cuisine': 'German',
#   'grades': [{'score': 11},
#    {'score': 7},
#    {'score': 13},
#    {'score': 9},
#    {'score': 13},
#    {'score': 24}],
#   'name': 'Zum Stammtisch',
#   'restaurant_id': '40367377'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 3}, {'score': 12}, {'score': 6}, {'score': 7}],
#   'name': "John'S Restaurant",
#   'restaurant_id': '40367407'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 13},
#    {'score': 13},
#    {'score': 9},
#    {'score': 17},
#    {'score': 13}],
#   'name': 'Grassroot Tavern',
#   'restaurant_id': '40367420'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 4},
#    {'score': 12},
#    {'score': 12},
#    {'score': 7},
#    {'score': 6}],
#   'name': 'The Assembly Bar',
#   'restaurant_id': '40367481'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'score': 12},
#    {'score': 10},
#    {'score': 13},
#    {'score': 40},
#    {'score': 12},
#    {'score': 5}],
#   'name': 'Mr Broadway Kosher Restaurant',
#   'restaurant_id': '40367534'},
#  {'borough': 'Queens',
#   'cuisine': 'Italian',
#   'grades': [{'score': 26},
#    {'score': 11},
#    {'score': 28},
#    {'score': 8},
#    {'score': 13},
#    {'score': 12}],
#   'name': 'Piccola Venezia',
#   'restaurant_id': '40367540'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'score': 6},
#    {'score': 12},
#    {'score': 7},
#    {'score': 9},
#    {'score': 22},
#    {'score': 24}],
#   'name': 'Malaga Restaurant',
#   'restaurant_id': '40367544'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'grades': [{'score': 11},
#    {'score': 8},
#    {'score': 10},
#    {'score': 12},
#    {'score': 4}],
#   'name': "Ni-Ni'S Cafe",
#   'restaurant_id': '40367570'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 13},
#    {'score': 12},
#    {'score': 6},
#    {'score': 11},
#    {'score': 9},
#    {'score': 12}],
#   'name': 'Capitol Restaurant',
#   'restaurant_id': '40367677'},
#  {'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'score': 9},
#    {'score': 12},
#    {'score': 9},
#    {'score': 12},
#    {'score': 11},
#    {'score': 5}],
#   'name': 'La Bonne Soupe Bistro',
#   'restaurant_id': '40367715'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 13}, {'score': 2}, {'score': 12}],
#   'name': 'Mimis Restaurant & Bar',
#   'restaurant_id': '40367728'},
#  {'borough': 'Queens',
#   'cuisine': 'Seafood',
#   'grades': [{'score': 16},
#    {'score': 12},
#    {'score': 11},
#    {'score': 7},
#    {'score': 12}],
#   'name': "Lenny'S Clam Bar",
#   'restaurant_id': '40367749'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 12}, {'score': 2}, {'score': 7}, {'score': 9}],
#   'name': 'Griffis Faculty Club',
#   'restaurant_id': '40367752'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Hotdogs',
#   'grades': [{'score': 7},
#    {'score': 8},
#    {'score': 20},
#    {'score': 13},
#    {'score': 13},
#    {'score': 7}],
#   'name': "Gray'S Papaya",
#   'restaurant_id': '40367766'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 11},
#    {'score': 4},
#    {'score': 7},
#    {'score': 8},
#    {'score': 12}],
#   'name': 'Dani Pizza And Restaurant',
#   'restaurant_id': '40367789'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'grades': [{'score': 11},
#    {'score': 12},
#    {'score': 7},
#    {'score': 10},
#    {'score': 7}],
#   'name': "Mcdonald'S",
#   'restaurant_id': '40367790'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Greek',
#   'grades': [{'score': 9},
#    {'score': 10},
#    {'score': 10},
#    {'score': 2},
#    {'score': 7}],
#   'name': 'El Greco Diner',
#   'restaurant_id': '40367795'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Seafood',
#   'grades': [{'score': 23},
#    {'score': 11},
#    {'score': 10},
#    {'score': 13},
#    {'score': 0}],
#   'name': 'One If By Land Two If By Sea',
#   'restaurant_id': '40367797'},
#  {'borough': 'Queens',
#   'cuisine': 'Hamburgers',
#   'grades': [{'score': 2},
#    {'score': 7},
#    {'score': 9},
#    {'score': 13},
#    {'score': 11}],
#   'name': "Mcdonald'S",
#   'restaurant_id': '40367829'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 6},
#    {'score': 2},
#    {'score': 7},
#    {'score': 12},
#    {'score': 7}],
#   'name': 'Fiorellos',
#   'restaurant_id': '40367841'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'score': 7},
#    {'score': 17},
#    {'score': 27},
#    {'score': 13},
#    {'score': 11}],
#   'name': 'Lb Spumoni Gardens',
#   'restaurant_id': '40367860'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'score': 11},
#    {'score': 10},
#    {'score': 10},
#    {'score': 13},
#    {'score': 9},
#    {'score': 11}],
#   'name': 'Amore Pizzeria & Restaurant',
#   'restaurant_id': '40367870'},
#  {'borough': 'Bronx',
#   'cuisine': 'Not Listed/Not Applicable',
#   'grades': [{'score': 5}, {'score': 2}, {'score': 2}, {'score': 10}],
#   'name': "The Lark'S Nest",
#   'restaurant_id': '40367946'},
#  {'borough': 'Bronx',
#   'cuisine': 'Café/Coffee/Tea',
#   'grades': [{'score': 8}, {'score': 9}, {'score': 8}],
#   'name': 'Terrace Cafe',
#   'restaurant_id': '40368018'},
#  {'borough': 'Bronx',
#   'cuisine': 'African',
#   'grades': [{'score': 8}, {'score': 6}, {'score': 0}, {'score': 0}],
#   'name': 'African Terrace',
#   'restaurant_id': '40368021'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'score': 2}, {'score': 11}, {'score': 12}, {'score': 5}],
#   'name': 'Cool Zone',
#   'restaurant_id': '40368022'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'score': 11}, {'score': 10}, {'score': 2}, {'score': 0}],
#   'name': 'Beaver Pond',
#   'restaurant_id': '40368025'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'score': 5}, {'score': 3}, {'score': 4}, {'score': 9}],
#   'name': 'African Market (Baboon Cafe)',
#   'restaurant_id': '40368026'},
#  {'borough': 'Staten Island',
#   'cuisine': 'Italian',
#   'grades': [{'score': 10}, {'score': 3}, {'score': 6}, {'score': 10}],
#   'name': 'Roadhouse Restaurant',
#   'restaurant_id': '40368034'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 9},
#    {'score': 11},
#    {'score': 11},
#    {'score': 11},
#    {'score': 13}],
#   'name': 'Ford Foundation Cafeteria',
#   'restaurant_id': '40368065'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 9},
#    {'score': 11},
#    {'score': 13},
#    {'score': 18},
#    {'score': 9}],
#   'name': 'Elephant & Castle',
#   'restaurant_id': '40368157'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'score': 11}, {'score': 9}, {'score': 7}, {'score': 0}],
#   'name': 'Mill Basin Kosher Deli',
#   'restaurant_id': '40368207'},
#  {'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'grades': [{'score': 12},
#    {'score': 8},
#    {'score': 10},
#    {'score': 13},
#    {'score': 9}],
#   'name': 'Colonnade Diner',
#   'restaurant_id': '40368291'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 10}, {'score': 6}, {'score': 12}, {'score': 13}],
#   'name': 'Red Flame Diner',
#   'restaurant_id': '40368313'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 8}, {'score': 12}, {'score': 13}, {'score': 13}],
#   'name': 'Maggies Place',
#   'restaurant_id': '40368318'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 13},
#    {'score': 12},
#    {'score': 5},
#    {'score': 11},
#    {'score': 15}],
#   'name': 'Da Silvano Restaurant',
#   'restaurant_id': '40368346'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 12},
#    {'score': 12},
#    {'score': 8},
#    {'score': 17},
#    {'score': 12},
#    {'score': 16}],
#   'name': 'Benjamin',
#   'restaurant_id': '40368370'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 27}, {'score': 5}, {'score': 12}, {'score': 12}],
#   'name': "Jimmy'S Corner",
#   'restaurant_id': '40368374'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'grades': [{'score': 10},
#    {'score': 6},
#    {'score': 18},
#    {'score': 11},
#    {'score': 9}],
#   'name': 'Frost Restaurant',
#   'restaurant_id': '40368526'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Steak',
#   'grades': [{'score': 12},
#    {'score': 7},
#    {'score': 26},
#    {'score': 5},
#    {'score': 2}],
#   'name': "Sammy'S Steakhouse",
#   'restaurant_id': '40368552'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 9},
#    {'score': 10},
#    {'score': 10},
#    {'score': 9},
#    {'score': 13}],
#   'name': 'Il Cortile Restaurant',
#   'restaurant_id': '40368555'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 12}, {'score': 8}, {'score': 9}, {'score': 12}],
#   'name': "Denny'S Pub",
#   'restaurant_id': '40368577'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 13},
#    {'score': 9},
#    {'score': 23},
#    {'score': 29},
#    {'score': 12}],
#   'name': 'Maries Crisis Cafe',
#   'restaurant_id': '40368581'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 2},
#    {'score': 10},
#    {'score': 10},
#    {'score': 13},
#    {'score': 9}],
#   'name': 'Boots & Saddle Bar',
#   'restaurant_id': '40368617'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 7},
#    {'score': 12},
#    {'score': 10},
#    {'score': 10},
#    {'score': 12},
#    {'score': 11}],
#   'name': 'New Parkway Restaurant',
#   'restaurant_id': '40368632'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Spanish',
#   'grades': [{'score': 12},
#    {'score': 23},
#    {'score': 12},
#    {'score': 5},
#    {'score': 13}],
#   'name': 'Cafe Riazor',
#   'restaurant_id': '40368725'},
#  {'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'score': 6},
#    {'score': 3},
#    {'score': 18},
#    {'score': 12},
#    {'score': 9}],
#   'name': 'Raouls',
#   'restaurant_id': '40368752'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 2},
#    {'score': 10},
#    {'score': 15},
#    {'score': 5},
#    {'score': 24}],
#   'name': 'The Brook',
#   'restaurant_id': '40368763'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 7},
#    {'score': 11},
#    {'score': 4},
#    {'score': 2},
#    {'score': 12}],
#   'name': "P.J.' S",
#   'restaurant_id': '40368809'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Japanese',
#   'grades': [{'score': 12},
#    {'score': 10},
#    {'score': 7},
#    {'score': 7},
#    {'score': 16}],
#   'name': 'Hatsuhana Restaurant',
#   'restaurant_id': '40368897'},
#  {'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'score': 11},
#    {'score': 7},
#    {'score': 10},
#    {'score': 4},
#    {'score': 9},
#    {'score': 39}],
#   'name': 'La Mangeoire',
#   'restaurant_id': '40368971'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza/Italian',
#   'grades': [{'score': 7},
#    {'score': 19},
#    {'score': 7},
#    {'score': 15},
#    {'score': 11},
#    {'score': 6}],
#   'name': "Valentino'S Pizza",
#   'restaurant_id': '40369012'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Greek',
#   'grades': [{'score': 7},
#    {'score': 24},
#    {'score': 11},
#    {'score': 12},
#    {'score': 4},
#    {'score': 7},
#    {'score': 18}],
#   'name': 'Viand Coffee Shop',
#   'restaurant_id': '40369016'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 11}, {'score': 5}, {'score': 3}, {'score': 12}],
#   'name': 'Palm Too',
#   'restaurant_id': '40369017'},
#  {'borough': 'Bronx',
#   'cuisine': 'American ',
#   'grades': [{'score': 12},
#    {'score': 12},
#    {'score': 5},
#    {'score': 2},
#    {'score': 9},
#    {'score': 11},
#    {'score': 13},
#    {'score': 13}],
#   'name': 'Blue Bay Restaurant',
#   'restaurant_id': '40369087'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Japanese',
#   'grades': [{'score': 11},
#    {'score': 12},
#    {'score': 11},
#    {'score': 4},
#    {'score': 9}],
#   'name': 'Nada-Sushi',
#   'restaurant_id': '40369097'},
#  {'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'score': 9}, {'score': 2}, {'score': 8}],
#   'name': 'Pergola Des Artistes',
#   'restaurant_id': '40369139'},
#  {'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'grades': [{'score': 10},
#    {'score': 2},
#    {'score': 11},
#    {'score': 13},
#    {'score': 13},
#    {'score': 9}],
#   'name': "Jody'S Club",
#   'restaurant_id': '40369158'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 13},
#    {'score': 17},
#    {'score': 12},
#    {'score': 9},
#    {'score': 14}],
#   'name': "Reif'S Tavern",
#   'restaurant_id': '40369165'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 7}, {'score': 13}, {'score': 9}],
#   'name': "John'S Pizzeria",
#   'restaurant_id': '40369262'},
#  {'borough': 'Bronx',
#   'cuisine': 'Seafood',
#   'grades': [{'score': 13},
#    {'score': 12},
#    {'score': 12},
#    {'score': 22},
#    {'score': 9}],
#   'name': 'Seashore Restaurant',
#   'restaurant_id': '40369299'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 12},
#    {'score': 12},
#    {'score': 9},
#    {'score': 15},
#    {'score': 8},
#    {'score': 13},
#    {'score': 12}],
#   'name': 'White Horse Tavern',
#   'restaurant_id': '40369400'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'grades': [{'score': 7},
#    {'score': 12},
#    {'score': 12},
#    {'score': 13},
#    {'score': 9}],
#   'name': 'Caffe Reggio',
#   'restaurant_id': '40369418'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 2},
#    {'score': 25},
#    {'score': 18},
#    {'score': 11},
#    {'score': 19}],
#   'name': "Armando'S Pizza",
#   'restaurant_id': '40369482'},
#  {'borough': 'Manhattan',
# ...
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'score': 19},
#    {'score': 4},
#    {'score': 11},
#    {'score': 23},
#    {'score': 14},
#    {'score': 19}],
#   'name': 'Pavillion Caterers',
#   'restaurant_id': '40398532'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 9},
#    {'score': 9},
#    {'score': 11},
#    {'score': 12},
#    {'score': 11}],
#   'name': "Perry'S Restaurant",
#   'restaurant_id': '40398549'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 12}, {'score': 10}, {'score': 7}, {'score': 12}],
#   'name': 'San Martin',
#   'restaurant_id': '40398554'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 7}, {'score': 13}, {'score': 13}, {'score': 11}],
#   'name': 'Tom And Jerry Bar',
#   'restaurant_id': '40398561'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'grades': [{'score': 7},
#    {'score': 5},
#    {'score': 5},
#    {'score': 5},
#    {'score': 10}],
#   'name': 'Starbucks Coffee',
#   'restaurant_id': '40398571'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Chinese',
#   'grades': [{'score': 31},
#    {'score': 11},
#    {'score': 25},
#    {'score': 12},
#    {'score': 5},
#    {'score': 12}],
#   'name': 'Dinastia China',
#   'restaurant_id': '40398572'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 12},
#    {'score': 13},
#    {'score': 18},
#    {'score': 7},
#    {'score': 17}],
#   'name': 'Dyckman Bar',
#   'restaurant_id': '40398578'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 20},
#    {'score': 20},
#    {'score': 14},
#    {'score': 25},
#    {'score': 3},
#    {'score': 13}],
#   'name': "Joseph'S Ristorante",
#   'restaurant_id': '40398586'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'grades': [{'score': 16},
#    {'score': 56},
#    {'score': 27},
#    {'score': 5},
#    {'score': 0},
#    {'score': 14},
#    {'score': 10},
#    {'score': 11}],
#   'name': 'World Cup Cafe',
#   'restaurant_id': '40398588'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Mexican',
#   'grades': [{'score': 12},
#    {'score': 12},
#    {'score': 2},
#    {'score': 0},
#    {'score': 10}],
#   'name': "Blockhead'S Burritos",
#   'restaurant_id': '40398600'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'grades': [{'score': 7}, {'score': 10}, {'score': 15}, {'score': 10}],
#   'name': 'La Lechonera Criolla',
#   'restaurant_id': '40398642'},
#  {'borough': 'Queens',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'grades': [{'score': 7},
#    {'score': 2},
#    {'score': 12},
#    {'score': 33},
#    {'score': 11},
#    {'score': 5}],
#   'name': 'Cafe 75 Bar',
#   'restaurant_id': '40398658'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'grades': [{'score': 9},
#    {'score': 13},
#    {'score': 17},
#    {'score': 13},
#    {'score': 22}],
#   'name': 'Master Wok',
#   'restaurant_id': '40398688'},
#  {'borough': 'Queens',
#   'cuisine': 'Café/Coffee/Tea',
#   'grades': [{'score': 7}, {'score': 9}, {'score': 10}, {'score': 13}],
#   'name': 'Caffee Express',
#   'restaurant_id': '40398689'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 12}, {'score': 2}, {'score': 13}, {'score': 11}],
#   'name': 'Doc Holidays',
#   'restaurant_id': '40398690'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 12},
#    {'score': 5},
#    {'score': 11},
#    {'score': 7},
#    {'score': 8}],
#   'name': 'Famous Pizza',
#   'restaurant_id': '40398700'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 10},
#    {'score': 10},
#    {'score': 14},
#    {'score': 9},
#    {'score': 10},
#    {'score': 10}],
#   'name': 'Hanson Restaurant And Pizzeria',
#   'restaurant_id': '40398767'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 12},
#    {'score': 12},
#    {'score': 33},
#    {'score': 4},
#    {'score': 8}],
#   'name': 'Vixens',
#   'restaurant_id': '40398795'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'grades': [{'score': 12}, {'score': 8}, {'score': 12}, {'score': 9}],
#   'name': 'Starbucks Coffee',
#   'restaurant_id': '40398796'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 10},
#    {'score': 11},
#    {'score': 5},
#    {'score': 12},
#    {'score': 9},
#    {'score': 8}],
#   'name': 'Knapp St Pizza Ii',
#   'restaurant_id': '40398899'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Chinese',
#   'grades': [{'score': 12}, {'score': 9}, {'score': 8}, {'score': 11}],
#   'name': 'Choy Le Chinese Restaurant',
#   'restaurant_id': '40398904'},
#  {'borough': 'Bronx',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 12},
#    {'score': 12},
#    {'score': 0},
#    {'score': 30},
#    {'score': 8},
#    {'score': 9}],
#   'name': "Joe'S Pizza",
#   'restaurant_id': '40398910'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 10},
#    {'score': 12},
#    {'score': 11},
#    {'score': 12},
#    {'score': 8},
#    {'score': 12}],
#   'name': 'Mumbles',
#   'restaurant_id': '40398913'},
#  {'borough': 'Staten Island',
#   'cuisine': 'American ',
#   'grades': [{'score': 9},
#    {'score': 8},
#    {'score': 12},
#    {'score': 13},
#    {'score': 9}],
#   'name': "Henny'S Restaurant",
#   'restaurant_id': '40398948'},
#  {'borough': 'Bronx',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'grades': [{'score': 17},
#    {'score': 17},
#    {'score': 5},
#    {'score': 27},
#    {'score': 11}],
#   'name': "Lolita'S Restaurant",
#   'restaurant_id': '40398958'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Vegetarian',
#   'grades': [{'score': 9}, {'score': 22}, {'score': 12}, {'score': 12}],
#   'name': 'Candle Cafe',
#   'restaurant_id': '40399007'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 7}, {'score': 13}, {'score': 5}, {'score': 27}],
#   'name': '9Th Ave Saloon',
#   'restaurant_id': '40399057'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'grades': [{'score': 7},
#    {'score': 10},
#    {'score': 3},
#    {'score': 13},
#    {'score': 12},
#    {'score': 11}],
#   'name': 'Europa Cafe',
#   'restaurant_id': '40399090'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 8},
#    {'score': 2},
#    {'score': 7},
#    {'score': 6},
#    {'score': 2},
#    {'score': 8}],
#   'name': 'Sale & Pepe',
#   'restaurant_id': '40399095'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'grades': [{'score': 11}, {'score': 5}, {'score': 8}, {'score': 5}],
#   'name': 'Starbucks Coffee',
#   'restaurant_id': '40399099'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 5},
#    {'score': 13},
#    {'score': 13},
#    {'score': 7},
#    {'score': 4}],
#   'name': 'Rockefeller U/Abby Bldg',
#   'restaurant_id': '40399136'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 21},
#    {'score': 12},
#    {'score': 11},
#    {'score': 8},
#    {'score': 49}],
#   'name': 'Mugs Ale House Bar',
#   'restaurant_id': '40399165'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 7},
#    {'score': 12},
#    {'score': 13},
#    {'score': 24},
#    {'score': 13}],
#   'name': 'Gigino Trattoria',
#   'restaurant_id': '40399174'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 8}, {'score': 11}],
#   'name': 'Sony Music Employee Cafeteria',
#   'restaurant_id': '40399176'},
#  {'borough': 'Queens',
#   'cuisine': 'Mexican',
#   'grades': [{'score': 13}, {'score': 9}, {'score': 11}],
#   'name': 'El Rey Mexican Restaurant',
#   'restaurant_id': '40399217'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 9},
#    {'score': 7},
#    {'score': 7},
#    {'score': 6},
#    {'score': 5}],
#   'name': 'Singas Famous Pizza',
#   'restaurant_id': '40399256'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 12},
#    {'score': 9},
#    {'score': 9},
#    {'score': 25},
#    {'score': 2},
#    {'score': 13}],
#   'name': 'Pomodoro Ristorante',
#   'restaurant_id': '40399279'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Thai',
#   'grades': [{'score': 12},
#    {'score': 5},
#    {'score': 12},
#    {'score': 12},
#    {'score': 24}],
#   'name': 'Bangkok Grand Palace',
#   'restaurant_id': '40399285'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 9},
#    {'score': 19},
#    {'score': 64},
#    {'score': 12},
#    {'score': 18},
#    {'score': 5}],
#   'name': 'Acappella Restaurant',
#   'restaurant_id': '40399334'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 2},
#    {'score': 12},
#    {'score': 9},
#    {'score': 10},
#    {'score': 13},
#    {'score': 2},
#    {'score': 10}],
#   'name': 'Coffee Shop',
#   'restaurant_id': '40399340'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 11}, {'score': 9}, {'score': 11}, {'score': 10}],
#   'name': "O'Hanlon'S",
#   'restaurant_id': '40399356'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Turkish',
#   'grades': [{'score': 9}, {'score': 9}, {'score': 5}],
#   'name': 'Turkish Kitchen',
#   'restaurant_id': '40399372'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'grades': [{'score': 11},
#    {'score': 9},
#    {'score': 12},
#    {'score': 10},
#    {'score': 8},
#    {'score': 4}],
#   'name': 'La Barca Restaurant',
#   'restaurant_id': '40399373'},
#  {'borough': 'Queens',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 5},
#    {'score': 9},
#    {'score': 2},
#    {'score': 12},
#    {'score': 13},
#    {'score': 11}],
#   'name': 'Pizza Chef',
#   'restaurant_id': '40399422'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Italian',
#   'grades': [{'score': 10},
#    {'score': 25},
#    {'score': 2},
#    {'score': 5},
#    {'score': 12}],
#   'name': 'Olive Garden Italian Restaurant',
#   'restaurant_id': '40399472'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 9},
#    {'score': 12},
#    {'score': 11},
#    {'score': 12},
#    {'score': 12}],
#   'name': 'Sardis Restaurant',
#   'restaurant_id': '40399560'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Bagels/Pretzels',
#   'grades': [{'score': 10},
#    {'score': 7},
#    {'score': 9},
#    {'score': 4},
#    {'score': 10}],
#   'name': 'Pick-A-Bagel',
#   'restaurant_id': '40399561'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 9}, {'score': 2}, {'score': 17}, {'score': 11}],
#   'name': 'Judge Roy Bean',
#   'restaurant_id': '40399569'},
#  {'borough': 'Queens',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'grades': [{'score': 2},
#    {'score': 64},
#    {'score': 9},
#    {'score': 12},
#    {'score': 8},
#    {'score': 3}],
#   'name': 'Pio Pio',
#   'restaurant_id': '40399581'},
#  {'borough': 'Queens',
#   'cuisine': 'American ',
#   'grades': [{'score': 10},
#    {'score': 11},
#    {'score': 11},
#    {'score': 13},
#    {'score': 27},
#    {'score': 9},
#    {'score': 26}],
#   'name': 'Flagship Diner',
#   'restaurant_id': '40399613'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 5},
#    {'score': 13},
#    {'score': 5},
#    {'score': 12},
#    {'score': 2},
#    {'score': 2}],
#   'name': 'La Linea Lounge',
#   'restaurant_id': '40399620'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 11},
#    {'score': 9},
#    {'score': 12},
#    {'score': 11},
#    {'score': 16}],
#   'name': 'Green Trees',
#   'restaurant_id': '40399652'},
#  {'borough': 'Queens',
#   'cuisine': 'Bakery',
#   'grades': [{'score': 13},
#    {'score': 13},
#    {'score': 8},
#    {'score': 14},
#    {'score': 10},
#    {'score': 12},
#    {'score': 12}],
#   'name': 'Bagels & Cream Deli',
#   'restaurant_id': '40399672'},
#  {'borough': 'Queens',
#   'cuisine': 'Delicatessen',
#   'grades': [{'score': 16},
#    {'score': 7},
#    {'score': 12},
#    {'score': 8},
#    {'score': 23},
#    {'score': 9},
#    {'score': 12}],
#   'name': 'Glory Deli',
#   'restaurant_id': '40399729'},
#  {'borough': 'Queens',
#   'cuisine': 'Donuts',
#   'grades': [{'score': 17},
#    {'score': 10},
#    {'score': 9},
#    {'score': 8},
#    {'score': 7},
#    {'score': 7}],
#   'name': "Dunkin' Donuts, Baskin Robbins",
#   'restaurant_id': '40399739'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Italian',
#   'grades': [{'score': 13},
#    {'score': 13},
#    {'score': 11},
#    {'score': 7},
#    {'score': 16}],
#   'name': 'Noodle Pudding',
#   'restaurant_id': '40399751'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Bakery',
#   'grades': [{'score': 8},
#    {'score': 10},
#    {'score': 2},
#    {'score': 7},
#    {'score': 7}],
#   'name': "Michael'S Pastry Shop",
#   'restaurant_id': '40399770'},
#  {'borough': 'Bronx',
#   'cuisine': 'Hamburgers',
#   'grades': [{'score': 7},
#    {'score': 2},
#    {'score': 5},
#    {'score': 2},
#    {'score': 12},
#    {'score': 9},
#    {'score': 7}],
#   'name': "Mcdonald'S",
#   'restaurant_id': '40399778'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Mediterranean',
#   'grades': [{'score': 26}, {'score': 5}, {'score': 13}, {'score': 10}],
#   'name': 'Uncle Nicks',
#   'restaurant_id': '40399784'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Café/Coffee/Tea',
#   'grades': [{'score': 8},
#    {'score': 2},
#    {'score': 3},
#    {'score': 10},
#    {'score': 3}],
#   'name': 'Starbucks Coffee',
#   'restaurant_id': '40399787'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#   'grades': [{'score': 6},
#    {'score': 10},
#    {'score': 7},
#    {'score': 13},
#    {'score': 12},
#    {'score': 4}],
#   'name': 'International Restaurant',
#   'restaurant_id': '40399810'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 11},
#    {'score': 5},
#    {'score': 9},
#    {'score': 14},
#    {'score': 26}],
#   'name': 'Hangar Bar',
#   'restaurant_id': '40399852'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 5}, {'score': 9}, {'score': 4}, {'score': 12}],
#   'name': "Domino'S Pizza",
#   'restaurant_id': '40399867'},
#  {'borough': 'Queens',
#   'cuisine': 'Donuts',
#   'grades': [{'score': 7},
#    {'score': 4},
#    {'score': 5},
#    {'score': 12},
#    {'score': 7},
#    {'score': 5}],
#   'name': "Dunkin' Donuts",
#   'restaurant_id': '40399886'},
#  {'borough': 'Manhattan',
#   'cuisine': 'American ',
#   'grades': [{'score': 7}, {'score': 9}, {'score': 7}, {'score': 4}],
#   'name': 'Pieces',
#   'restaurant_id': '40399910'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Pizza',
#   'grades': [{'score': 4},
#    {'score': 8},
#    {'score': 2},
#    {'score': 27},
#    {'score': 20}],
#   'name': "Lenny'S Pizza",
#   'restaurant_id': '40399911'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Hamburgers',
#   'grades': [{'score': 3}, {'score': 9}, {'score': 11}, {'score': 5}],
#   'name': 'White Castle',
#   'restaurant_id': '40399922'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'Jewish/Kosher',
#   'grades': [{'score': 9},
#    {'score': 12},
#    {'score': 31},
#    {'score': 13},
#    {'score': 31}],
#   'name': "Schick'S Manor",
#   'restaurant_id': '40399955'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Bakery',
#   'grades': [{'score': 21},
#    {'score': 11},
#    {'score': 12},
#    {'score': 21},
#    {'score': 12},
#    {'score': 13},
#    {'score': 2}],
#   'name': 'Tai Pan Bakery',
#   'restaurant_id': '40399970'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 10},
#    {'score': 12},
#    {'score': 9},
#    {'score': 9},
#    {'score': 11},
#    {'score': 9},
#    {'score': 11},
#    {'score': 11}],
#   'name': 'Fifth Ave Cafe /Diner',
#   'restaurant_id': '40399986'},
#  {'borough': 'Bronx',
#   'cuisine': 'Bagels/Pretzels',
#   'grades': [{'score': 12},
#    {'score': 7},
#    {'score': 7},
#    {'score': 23},
#    {'score': 7},
#    {'score': 13}],
#   'name': 'Rolen Bagels',
#   'restaurant_id': '40399988'},
#  {'borough': 'Manhattan',
#   'cuisine': 'French',
#   'grades': [{'score': 33}, {'score': 9}, {'score': 9}, {'score': 7}],
#   'name': 'Cafe Gitane',
#   'restaurant_id': '40400039'},
#  {'borough': 'Manhattan',
#   'cuisine': 'Japanese',
#   'grades': [{'score': 10},
#    {'score': 10},
#    {'score': 2},
#    {'score': 10},
#    {'score': 20}],
#   'name': 'Panya/The Barrel',
#   'restaurant_id': '40400049'},
#  {'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'score': 9}, {'score': 12}, {'score': 10}],
#   'name': "Circle'S Grill",
#   'restaurant_id': '40400096'},
#  ...]

# %% [markdown]
# 11. Devolver ID del restaurante, el nombre y las calificaciones del restaurante para aquellos restaurantes que obtuvieron una calificación de "A" y obtuvieron un puntaje de 11 en una fecha ISO "2014-08-11T00: 00: 00Z" entre muchas fechas de encuesta

# %% [markdown]
# 12. Devolver ID del restaurante, nombre, dirección y ubicación geográfica del restaurante de aquellos donde el segundo elemento de la matriz coord contiene un valor que es más de 42 y hasta 52

# %%
filtro = {
    "address.coord.1": {"$gt":42, "$lt": 52}
}


proyeccion = {"restaurant_id": 1, "name": 1, "address": 1, "_id": 0}
list(restaurantes.find(filtro, proyeccion))
# Out:
# [{'address': {'building': '47',
#    'coord': [-78.877224, 42.89546199999999],
#    'street': 'Broadway @ Trinity Pl',
#    'zipcode': '10006'},
#   'name': "T.G.I. Friday'S",
#   'restaurant_id': '40387990'},
#  {'address': {'building': '1',
#    'coord': [-0.7119979, 51.6514664],
#    'street': 'Pennplaza E, Penn Sta',
#    'zipcode': '10001'},
#   'name': 'T.G.I. Fridays',
#   'restaurant_id': '40388936'},
#  {'address': {'building': '3000',
#    'coord': [-87.86567699999999, 42.61150920000001],
#    'street': '47 Avenue',
#    'zipcode': '11101'},
#   'name': "Di Luvio'S Deli",
#   'restaurant_id': '40402284'},
#  {'address': {'building': '21972199',
#    'coord': [-78.589606, 42.8912372],
#    'street': 'Broadway',
#    'zipcode': '10024'},
#   'name': 'La Caridad 78',
#   'restaurant_id': '40568285'},
#  {'address': {'building': '7981',
#    'coord': [-84.9751215, 45.4713351],
#    'street': 'Hoyt Street',
#    'zipcode': '11201'},
#   'name': "Bijan'S",
#   'restaurant_id': '40876618'},
#  {'address': {'building': '0',
#    'coord': [-88.0778799, 42.4154769],
#    'street': '& Grand Central',
#    'zipcode': '10017'},
#   'name': 'Hyatt, Ny Central/Room Service',
#   'restaurant_id': '40879243'},
#  {'address': {'building': '60',
#    'coord': [-111.9975205, 42.0970258],
#    'street': 'West Side Highway',
#    'zipcode': '10006'},
#   'name': 'Sports Center At Chelsea Piers (Sushi Bar)',
#   'restaurant_id': '40882356'},
#  {'address': {'building': '47',
#    'coord': [-78.877224, 42.89546199999999],
#    'street': 'Broadway @ Trinity Pl',
#    'zipcode': '10006'},
#   'name': "T.G.I. Friday'S",
#   'restaurant_id': '40387990'},
#  {'address': {'building': '1',
#    'coord': [-0.7119979, 51.6514664],
#    'street': 'Pennplaza E, Penn Sta',
#    'zipcode': '10001'},
#   'name': 'T.G.I. Fridays',
#   'restaurant_id': '40388936'},
#  {'address': {'building': '3000',
#    'coord': [-87.86567699999999, 42.61150920000001],
#    'street': '47 Avenue',
#    'zipcode': '11101'},
#   'name': "Di Luvio'S Deli",
#   'restaurant_id': '40402284'},
#  {'address': {'building': '21972199',
#    'coord': [-78.589606, 42.8912372],
#    'street': 'Broadway',
#    'zipcode': '10024'},
#   'name': 'La Caridad 78',
#   'restaurant_id': '40568285'},
#  {'address': {'building': '7981',
#    'coord': [-84.9751215, 45.4713351],
#    'street': 'Hoyt Street',
#    'zipcode': '11201'},
#   'name': "Bijan'S",
#   'restaurant_id': '40876618'},
#  {'address': {'building': '0',
#    'coord': [-88.0778799, 42.4154769],
#    'street': '& Grand Central',
#    'zipcode': '10017'},
#   'name': 'Hyatt, Ny Central/Room Service',
#   'restaurant_id': '40879243'},
#  {'address': {'building': '60',
#    'coord': [-111.9975205, 42.0970258],
#    'street': 'West Side Highway',
#    'zipcode': '10006'},
#   'name': 'Sports Center At Chelsea Piers (Sushi Bar)',
#   'restaurant_id': '40882356'},
#  {'address': {'building': '47',
#    'coord': [-78.877224, 42.89546199999999],
#    'street': 'Broadway @ Trinity Pl',
#    'zipcode': '10006'},
#   'name': "T.G.I. Friday'S",
#   'restaurant_id': '40387990'},
#  {'address': {'building': '1',
#    'coord': [-0.7119979, 51.6514664],
#    'street': 'Pennplaza E, Penn Sta',
#    'zipcode': '10001'},
#   'name': 'T.G.I. Fridays',
#   'restaurant_id': '40388936'},
#  {'address': {'building': '3000',
#    'coord': [-87.86567699999999, 42.61150920000001],
#    'street': '47 Avenue',
#    'zipcode': '11101'},
#   'name': "Di Luvio'S Deli",
#   'restaurant_id': '40402284'},
#  {'address': {'building': '21972199',
#    'coord': [-78.589606, 42.8912372],
#    'street': 'Broadway',
#    'zipcode': '10024'},
#   'name': 'La Caridad 78',
#   'restaurant_id': '40568285'},
#  {'address': {'building': '7981',
#    'coord': [-84.9751215, 45.4713351],
#    'street': 'Hoyt Street',
#    'zipcode': '11201'},
#   'name': "Bijan'S",
#   'restaurant_id': '40876618'},
#  {'address': {'building': '0',
#    'coord': [-88.0778799, 42.4154769],
#    'street': '& Grand Central',
#    'zipcode': '10017'},
#   'name': 'Hyatt, Ny Central/Room Service',
#   'restaurant_id': '40879243'},
#  {'address': {'building': '60',
#    'coord': [-111.9975205, 42.0970258],
#    'street': 'West Side Highway',
#    'zipcode': '10006'},
#   'name': 'Sports Center At Chelsea Piers (Sushi Bar)',
#   'restaurant_id': '40882356'}]

# %% [markdown]
# 17. Busca los restaurantes cuyo nombre empiece por 'C'

# %%
filtro = {
    "name": {"$regex": "^c", "$options": "i"}
}


proyeccion = {"restaurant_id": 1, "name": 1, "address": 1, "_id": 0}
list(restaurantes.find(filtro, proyeccion))
# Out:
# [{'address': {'building': '7715',
#    'coord': [-73.9973325, 40.61174889999999],
#    'street': '18 Avenue',
#    'zipcode': '11214'},
#   'name': 'C & C Catering Service',
#   'restaurant_id': '40357437'},
#  {'address': {'building': '203',
#    'coord': [-73.97822040000001, 40.6435254],
#    'street': 'Church Avenue',
#    'zipcode': '11218'},
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40360076'},
#  {'address': {'building': '265-15',
#    'coord': [-73.7032601, 40.7386417],
#    'street': 'Hillside Avenue',
#    'zipcode': '11004'},
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40361322'},
#  {'address': {'building': '1006',
#    'coord': [-73.84856870000002, 40.8903781],
#    'street': 'East 233 Street',
#    'zipcode': '10466'},
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363093'},
#  {'address': {'building': '625',
#    'coord': [-73.990494, 40.7569545],
#    'street': '8 Avenue',
#    'zipcode': '10018'},
#   'name': 'Cafe Metro',
#   'restaurant_id': '40363298'},
#  {'address': {'building': '1111',
#    'coord': [-74.0796436, 40.59878339999999],
#    'street': 'Hylan Boulevard',
#    'zipcode': '10305'},
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40363834'},
#  {'address': {'building': '100',
#    'coord': [-74.0010484, 40.71599000000001],
#    'street': 'Centre Street',
#    'zipcode': '10013'},
#   'name': 'Criminal Court Bldg Cafeteria',
#   'restaurant_id': '40364443'},
#  {'address': {'building': '215',
#    'coord': [-73.9805679, 40.7659436],
#    'street': 'West 57 Street',
#    'zipcode': '10019'},
#   'name': 'Cafe Atelier (Art Students League)',
#   'restaurant_id': '40364531'},
#  {'address': {'building': '67',
#    'coord': [-74.0707363, 40.59321569999999],
#    'street': 'Olympia Boulevard',
#    'zipcode': '10305'},
#   'name': 'Crystal Room',
#   'restaurant_id': '40365013'},
#  {'address': {'building': '331',
#    'coord': [-74.0037823, 40.7380122],
#    'street': 'West    4 Street',
#    'zipcode': '10014'},
#   'name': 'Corner Bistro',
#   'restaurant_id': '40365166'},
#  {'address': {'building': '4035',
#    'coord': [-73.9395182, 40.8422945],
#    'street': 'Broadway',
#    'zipcode': '10032'},
#   'name': 'Como Pizza',
#   'restaurant_id': '40365280'},
#  {'address': {'building': '220-20',
#    'coord': [-73.74292179999999, 40.7305714],
#    'street': 'Hillside Avenue',
#    'zipcode': '11427'},
#   'name': 'Cara Mia',
#   'restaurant_id': '40366812'},
#  {'address': {'building': '4408',
#    'coord': [-73.90364869999999, 40.74133339999999],
#    'street': '60Th St. - Store',
#    'zipcode': '11377'},
#   'name': 'Charlies Sports Bar',
#   'restaurant_id': '40367240'},
#  {'address': {'building': '180',
#    'coord': [-73.9788694, 40.7665961],
#    'street': 'Central Park South',
#    'zipcode': '10019'},
#   'name': 'Cocktail Room (Nyac)',
#   'restaurant_id': '40367339'},
#  {'address': {'building': '4933',
#    'coord': [-73.9215284, 40.8678204],
#    'street': 'Broadway',
#    'zipcode': '10034'},
#   'name': 'Capitol Restaurant',
#   'restaurant_id': '40367677'},
#  {'address': {'building': '2300',
#    'coord': [-73.8786113, 40.8502883],
#    'street': 'Southern Boulevard',
#    'zipcode': '10460'},
#   'name': 'Cool Zone',
#   'restaurant_id': '40368022'},
#  {'address': {'building': '441',
#    'coord': [-73.98431219999999, 40.7258174],
#    'street': 'East    6 Street',
#    'zipcode': '10009'},
#   'name': 'Cherry Tavern',
#   'restaurant_id': '40368271'},
#  {'address': {'building': '2001',
#    'coord': [-74.099018, 40.58116500000001],
#    'street': 'Hylan Boulevard',
#    'zipcode': '10306'},
#   'name': 'Colonnade Diner',
#   'restaurant_id': '40368291'},
#  {'address': {'building': '245',
#    'coord': [-74.000399, 40.740848],
#    'street': 'West   16 Street',
#    'zipcode': '10011'},
#   'name': 'Cafe Riazor',
#   'restaurant_id': '40368725'},
#  {'address': {'building': '119',
#    'coord': [-74.00041689999999, 40.7302678],
#    'street': 'Mac Dougal Street',
#    'zipcode': '10012'},
#   'name': 'Caffe Reggio',
#   'restaurant_id': '40369418'},
#  {'address': {'building': '123',
#    'coord': [-73.984126, 40.7567949],
#    'street': 'West   44 Street',
#    'zipcode': '10036'},
#   'name': 'Cafe Un Deux Trois',
#   'restaurant_id': '40369461'},
#  {'address': {'building': '427',
#    'coord': [-73.94523509999999, 40.7177182],
#    'street': 'Graham Avenue',
#    'zipcode': '11211'},
#   'name': 'Cafe Capri',
#   'restaurant_id': '40369597'},
#  {'address': {'building': '138140',
#    'coord': [-73.9574128, 40.7701235],
#    'street': 'East   74 Street',
#    'zipcode': '10021'},
#   'name': 'Cucina Vivolo',
#   'restaurant_id': '40370497'},
#  {'address': {'building': '172',
#    'coord': [-74.0007509, 40.7287609],
#    'street': 'Bleecker Street',
#    'zipcode': '10012'},
#   'name': 'Cafe Espanol',
#   'restaurant_id': '40370759'},
#  {'address': {'building': '312',
#    'coord': [-73.9832993, 40.76754440000001],
#    'street': 'West   58 Street',
#    'zipcode': '10019'},
#   'name': 'Coliseum Bar Restaurant',
#   'restaurant_id': '40371281'},
#  {'address': {'building': '1',
#    'coord': [-73.990556, 40.749722],
#    'street': 'Penn Plaza',
#    'zipcode': '10001'},
#   'name': 'Caruso Pizza #2',
#   'restaurant_id': '40372523'},
#  {'address': {'building': '917',
#    'coord': [-73.8128627, 40.7931101],
#    'street': 'Clintonville Street',
#    'zipcode': '11357'},
#   'name': 'Clinton Restaurant',
#   'restaurant_id': '40372694'},
#  {'address': {'building': '1434',
#    'coord': [-74.0986428, 40.5942955],
#    'street': 'Richmond Road',
#    'zipcode': '10304'},
#   'name': "Chen'S Chinese",
#   'restaurant_id': '40372831'},
#  {'address': {'building': '114',
#    'coord': [-74.031688, 40.6374532],
#    'street': 'Bayridge Avenue',
#    'zipcode': '11220'},
#   'name': 'Casa Pepe',
#   'restaurant_id': '40372999'},
#  {'address': {'building': '79',
#    'coord': [-74.0018619, 40.7288849],
#    'street': 'Mac Dougal Street',
#    'zipcode': '10012'},
#   'name': 'Caffe Dante',
#   'restaurant_id': '40373149'},
#  {'address': {'building': '127',
#    'coord': [-73.9982079, 40.7180815],
#    'street': 'Mulberry Street',
#    'zipcode': '10013'},
#   'name': 'Casa Bella',
#   'restaurant_id': '40374834'},
#  {'address': {'building': '365',
#    'coord': [-73.9883256, 40.76344890000001],
#    'street': 'West 50 Street',
#    'zipcode': '10019'},
#   'name': 'Chez Napolean',
#   'restaurant_id': '40374974'},
#  {'address': {'building': '739',
#    'coord': [-73.993406, 40.730003],
#    'street': 'Broadway',
#    'zipcode': '10003'},
#   'name': 'Cozy Soup & Burger',
#   'restaurant_id': '40375839'},
#  {'address': {'building': '309',
#    'coord': [-73.9801846, 40.7801316],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10023'},
#   'name': 'Candle Bar',
#   'restaurant_id': '40376031'},
#  {'address': {'building': '464',
#    'coord': [-92.73084399999999, 41.7461462],
#    'street': '6 Avenue',
#    'zipcode': '10011'},
#   'name': "Charlie'S Mom Chinese Restaurant",
#   'restaurant_id': '40376121'},
#  {'address': {'building': '72',
#    'coord': [-74.001763, 40.7282465],
#    'street': 'Mac Dougal Street',
#    'zipcode': '10012'},
#   'name': 'Chez Jaqueline',
#   'restaurant_id': '40376687'},
#  {'address': {'building': '200',
#    'coord': [-73.983169, 40.7774031],
#    'street': 'West   70 Street',
#    'zipcode': '10023'},
#   'name': 'Cafe Luxembourg',
#   'restaurant_id': '40377789'},
#  {'address': {'building': '168',
#    'coord': [-73.94100100000001, 40.798046],
#    'street': 'East  116 Street',
#    'zipcode': '10029'},
#   'name': 'Cuchifrito',
#   'restaurant_id': '40378212'},
#  {'address': {'building': '493',
#    'coord': [-73.97579000000002, 40.786074],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10024'},
#   'name': "Caesar'S Palace",
#   'restaurant_id': '40378970'},
#  {'address': {'building': '339',
#    'coord': [-73.980274, 40.73489379999999],
#    'street': '1 Avenue',
#    'zipcode': '10003'},
#   'name': 'Cooper Town Diner',
#   'restaurant_id': '40379580'},
#  {'address': {'building': '158',
#    'coord': [-73.8982405, 40.8616283],
#    'street': 'E. 188 Th St',
#    'zipcode': '10468'},
#   'name': 'Cuchifritos',
#   'restaurant_id': '40380164'},
#  {'address': {'building': '101',
#    'coord': [-73.97775159999999, 40.7510553],
#    'street': 'Park Avenue',
#    'zipcode': '10017'},
#   'name': 'Club 101',
#   'restaurant_id': '40380182'},
#  {'address': {'building': '7402',
#    'coord': [-73.87812749999999, 40.7126376],
#    'street': 'Metropolitan Avenue',
#    'zipcode': '11379'},
#   'name': 'Carlos Pizza',
#   'restaurant_id': '40380422'},
#  {'address': {'building': '80',
#    'coord': [-73.9932232, 40.6974104],
#    'street': 'Clark Street',
#    'zipcode': '11201'},
#   'name': "Clark'S Restaurant",
#   'restaurant_id': '40381551'},
#  {'address': {'building': '4015',
#    'coord': [-73.939728, 40.841687],
#    'street': 'Broadway',
#    'zipcode': '10032'},
#   'name': "Coogan'S",
#   'restaurant_id': '40382395'},
#  {'address': {'building': '32',
#    'coord': [-74.00298049999999, 40.7317316],
#    'street': 'Jones Street',
#    'zipcode': '10014'},
#   'name': 'Caffe Vivaldi',
#   'restaurant_id': '40382455'},
#  {'address': {'building': '1506',
#    'coord': [-73.8537226, 40.8427071],
#    'street': 'Bronxdale Avenue',
#    'zipcode': '10462'},
#   'name': 'Castlehill Diner',
#   'restaurant_id': '40382517'},
#  {'address': {'building': '117-18',
#    'coord': [-73.832745, 40.7149694],
#    'street': 'Queens Boulevard',
#    'zipcode': '11375'},
#   'name': 'Cobblestone Pub',
#   'restaurant_id': '40383003'},
#  {'address': {'building': '113',
#    'coord': [-73.99849569999999, 40.7176369],
#    'street': 'Mulberry Street',
#    'zipcode': '10013'},
#   'name': "Cha Cha'S Backyard Garden Bar & Cafe",
#   'restaurant_id': '40383009'},
#  {'address': {'building': '29',
#    'coord': [-74.0024972, 40.7314926],
#    'street': 'Cornelia Street',
#    'zipcode': '10014'},
#   'name': 'Cornelia Street Cafe',
#   'restaurant_id': '40383354'},
#  {'address': {'building': '1825',
#    'coord': [-74.1268188, 40.5651822],
#    'street': 'North Railroad Avenue',
#    'zipcode': '10306'},
#   'name': "Canlon'S Restaurant",
#   'restaurant_id': '40383737'},
#  {'address': {'building': '70',
#    'coord': [-73.975144, 40.675441],
#    'street': '7 Avenue',
#    'zipcode': '11217'},
#   'name': "Cousin John'S Cafe And Bakery",
#   'restaurant_id': '40383763'},
#  {'address': {'building': '414',
#    'coord': [-73.9935579, 40.7585089],
#    'street': 'West   42 Street',
#    'zipcode': '10036'},
#   'name': 'Chez Josephine',
#   'restaurant_id': '40384671'},
#  {'address': {'building': '228',
#    'coord': [-73.98635039999999, 40.7596825],
#    'street': 'West   47 Street',
#    'zipcode': '10036'},
#   'name': 'Cafe Edison',
#   'restaurant_id': '40385000'},
#  {'address': {'building': '7721',
#    'coord': [-74.0283135, 40.6294318],
#    'street': '3 Avenue',
#    'zipcode': '11209'},
#   'name': 'Cappuccino Cafe',
#   'restaurant_id': '40385057'},
#  {'address': {'building': '1571',
#    'coord': [-74.1013145, 40.5912425],
#    'street': 'Richmond Road',
#    'zipcode': '10304'},
#   'name': "Carol'S Cafe",
#   'restaurant_id': '40385065'},
#  {'address': {'building': '238',
#    'coord': [-73.98789909999999, 40.7292983],
#    'street': 'East    9 Street',
#    'zipcode': '10003'},
#   'name': 'Cloister Cafe',
#   'restaurant_id': '40385461'},
#  {'address': {'building': '4357',
#    'coord': [-74.1603346, 40.5454655],
#    'street': 'Amboy Road',
#    'zipcode': '10312'},
#   'name': 'Country Donuts',
#   'restaurant_id': '40386067'},
#  {'address': {'building': '51',
#    'coord': [-73.9787406, 40.7611474],
#    'street': 'West 52 Street',
#    'zipcode': '10019'},
#   'name': 'China Grill',
#   'restaurant_id': '40386481'},
#  {'address': {'building': '146',
#    'coord': [-73.9792691, 40.7649292],
#    'street': 'West   57 Street',
#    'zipcode': '10019'},
#   'name': 'Club Metropolitan',
#   'restaurant_id': '40386646'},
#  {'address': {'building': '5024',
#    'coord': [-73.9135648, 40.7458604],
#    'street': 'Skillman Avenue',
#    'zipcode': '11377'},
#   'name': 'Copper Kettle',
#   'restaurant_id': '40386675'},
#  {'address': {'building': '201',
#    'coord': [-73.97672659999999, 40.78598119999999],
#    'street': 'West   83 Street',
#    'zipcode': '10024'},
#   'name': 'Cafe Lalo',
#   'restaurant_id': '40387357'},
#  {'address': {'building': '519',
#    'coord': [-74.00660599999999, 40.733932],
#    'street': 'Hudson Street',
#    'zipcode': '10014'},
#   'name': 'Cowgirl Hall Of Fame',
#   'restaurant_id': '40388321'},
#  {'address': {'building': '71',
#    'coord': [-74.01229450000001, 40.7074764],
#    'street': 'Broadway',
#    'zipcode': '10006'},
#   'name': "Champ'S Deli",
#   'restaurant_id': '40388457'},
#  {'address': {'building': '8822',
#    'coord': [-74.03208579999999, 40.6215814],
#    'street': '3 Avenue',
#    'zipcode': '11209'},
#   'name': "Chadwick'S",
#   'restaurant_id': '40388823'},
#  {'address': {'building': '9',
#    'coord': [-73.991669, 40.737153],
#    'street': 'East   16 Street',
#    'zipcode': '10003'},
#   'name': 'Campeon',
#   'restaurant_id': '40389357'},
#  {'address': {'building': '30',
#    'coord': [-74.01153459999999, 40.7061121],
#    'street': 'Broad Street',
#    'zipcode': '10004'},
#   'name': 'Champ Gourmet',
#   'restaurant_id': '40389807'},
#  {'address': {'building': '56',
#    'coord': [-73.9907994, 40.7156752],
#    'street': 'Hester Street',
#    'zipcode': '10002'},
#   'name': 'Classic Coffee Shop',
#   'restaurant_id': '40389900'},
#  {'address': {'building': '2483',
#    'coord': [-73.9732585, 40.79229249999999],
#    'street': 'Broadway',
#    'zipcode': '10025'},
#   'name': "Cleopatra'S Needle",
#   'restaurant_id': '40390186'},
#  {'address': {'building': '6443',
#    'coord': [-73.8487037, 40.7319571],
#    'street': '108 Street',
#    'zipcode': '11375'},
#   'name': 'Cho-Sen Garden',
#   'restaurant_id': '40390232'},
#  {'address': {'building': '110-11',
#    'coord': [-73.833378, 40.688097],
#    'street': '101 Avenue',
#    'zipcode': '11419'},
#   'name': "Caterina'S Pizza",
#   'restaurant_id': '40390698'},
#  {'address': {'building': '1300',
#    'coord': [-74.085013, 40.5966165],
#    'street': 'Hylan Boulevard',
#    'zipcode': '10305'},
#   'name': 'Cafe Luna',
#   'restaurant_id': '40390850'},
#  {'address': {'building': '1310',
#    'coord': [-73.92396529999999, 40.6903438],
#    'street': 'Broadway',
#    'zipcode': '11221'},
#   'name': 'Collado Restaurant',
#   'restaurant_id': '40391562'},
#  {'address': {'building': '205',
#    'coord': [-73.9890601, 40.7538643],
#    'street': 'West   38 Street',
#    'zipcode': '10018'},
#   'name': 'Cambridge Caterers',
#   'restaurant_id': '40392244'},
#  {'address': {'building': '537',
#    'coord': [-73.9549067, 40.6971322],
#    'street': 'Park Avenue',
#    'zipcode': '11205'},
#   'name': "Charle'S Corner Restaurant & Deli",
#   'restaurant_id': '40392285'},
#  {'address': {'building': '1919',
#    'coord': [-74.0969897, 40.5830445],
#    'street': 'Hylan Boulevard',
#    'zipcode': '10305'},
#   'name': 'Cafe Bella Vita',
#   'restaurant_id': '40392313'},
#  {'address': {'building': '4530',
#    'coord': [-73.945866, 40.746087],
#    'street': '23 Street',
#    'zipcode': '11101'},
#   'name': 'Court Square Diner',
#   'restaurant_id': '40393395'},
#  {'address': {'building': '154',
#    'coord': [-73.9931261, 40.6887559],
#    'street': 'Court Street',
#    'zipcode': '11201'},
#   'name': "Cody'S Ale House Grill",
#   'restaurant_id': '40393496'},
#  {'address': {'building': '983',
#    'coord': [-73.9049922, 40.6962313],
#    'street': 'Wyckoff Avenue',
#    'zipcode': '11385'},
#   'name': 'C & B Luncheonette',
#   'restaurant_id': '40393753'},
#  {'address': {'building': '38-14',
#    'coord': [-73.9193791, 40.75896760000001],
#    'street': 'Broadway',
#    'zipcode': '11103'},
#   'name': 'Cronin & Phelan Pub & Restaurant',
#   'restaurant_id': '40394110'},
#  {'address': {'building': '750',
#    'coord': [-73.9837606, 40.7608268],
#    'street': '7 Avenue',
#    'zipcode': '10019'},
#   'name': "Caroline'S On Broadway",
#   'restaurant_id': '40394762'},
#  {'address': {'building': '4340',
#    'coord': [-73.85553, 40.89668349999999],
#    'street': 'White Plains Road',
#    'zipcode': '10466'},
#   'name': "Cullen'S Tavern",
#   'restaurant_id': '40394838'},
#  {'address': {'building': '1382',
#    'coord': [-73.954818, 40.768811],
#    'street': '1 Avenue',
#    'zipcode': '10021'},
#   'name': 'Campagnola Restaurant',
#   'restaurant_id': '40394954'},
#  {'address': {'building': '153',
#    'coord': [-73.9848956, 40.72855],
#    'street': 'First Avenue',
#    'zipcode': '10003'},
#   'name': 'Coyote Ugly',
#   'restaurant_id': '40395093'},
#  {'address': {'building': '27120',
#    'coord': [-73.70225359999999, 40.751891],
#    'street': 'Union Turnpike',
#    'zipcode': '11040'},
#   'name': 'Cafe Cardini',
#   'restaurant_id': '40395239'},
#  {'address': {'building': '286',
#    'coord': [-73.9798842, 40.6049957],
#    'street': 'Kings Highway',
#    'zipcode': '11223'},
#   'name': 'Chicken Delicious',
#   'restaurant_id': '40395333'},
#  {'address': {'building': '3235',
#    'coord': [-74.1688867, 40.5604033],
#    'street': 'Richmond Avenue',
#    'zipcode': '10312'},
#   'name': 'Country Donuts',
#   'restaurant_id': '40395554'},
#  {'address': {'building': '113335',
#    'coord': [-73.96712, 40.798503],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10025'},
#   'name': 'Camilles',
#   'restaurant_id': '40395691'},
#  {'address': {'building': '150',
#    'coord': [-73.9908184, 40.686652],
#    'street': 'Smith Street',
#    'zipcode': '11201'},
#   'name': 'Caruso Pizzeria & Restaurant',
#   'restaurant_id': '40395774'},
#  {'address': {'building': '3533',
#    'coord': [-73.9509786, 40.8264242],
#    'street': 'Broadway',
#    'zipcode': '10031'},
#   'name': 'Caridad Restaurant',
#   'restaurant_id': '40395872'},
#  {'address': {'building': '780',
#    'coord': [-73.8630529, 40.8456372],
#    'street': 'Morris Park Ave',
#    'zipcode': '10462'},
#   'name': 'Chick-N-Ribs',
#   'restaurant_id': '40396053'},
#  {'address': {'building': '200',
#    'coord': [-73.986654, 40.757498],
#    'street': 'West 44 Street',
#    'zipcode': '10036'},
#   'name': "Carmine'S",
#   'restaurant_id': '40396159'},
#  {'address': {'building': '105',
#    'coord': [-73.9977256, 40.7368279],
#    'street': 'West   13 Street',
#    'zipcode': '10011'},
#   'name': 'Cafe Loup',
#   'restaurant_id': '40396395'},
#  {'address': {'building': '385',
#    'coord': [-73.9967999, 40.720231],
#    'street': 'Broome Street',
#    'zipcode': '10013'},
#   'name': 'Caffe Roma',
#   'restaurant_id': '40396421'},
#  {'address': {'building': '853',
#    'coord': [-73.954054, 40.729085],
#    'street': 'Manhattan Avenue',
#    'zipcode': '11222'},
#   'name': "Christina'S Restaurant",
#   'restaurant_id': '40396433'},
#  {'address': {'building': '1645',
#    'coord': [-73.9508638, 40.7826745],
#    'street': 'Third Avenue',
#    'zipcode': '10128'},
#   'name': 'Corner Cafe And Bakery',
#   'restaurant_id': '40396494'},
#  {'address': {'building': '26',
#    'coord': [-73.960095, 40.779471],
#    'street': 'East   84 Street',
#    'zipcode': '10028'},
#   'name': 'Caffe Grazie',
#   'restaurant_id': '40397243'},
#  {'address': {'building': '1301',
#    'coord': [-73.9801263, 40.7616971],
#    'street': 'Avenue Of The Americas',
#    'zipcode': '10019'},
#   'name': 'Credit Agricole-Cbi Executive Room',
#   'restaurant_id': '40397486'},
#  {'address': {'building': '907',
#    'coord': [-73.88343, 40.6665185],
#    'street': 'Livonia Avenue',
#    'zipcode': '11207'},
#   'name': "Caterina'S Pizzeria",
#   'restaurant_id': '40397916'},
#  {'address': {'building': '213-10',
#    'coord': [-73.771394, 40.76331],
#    'street': '41 Avenue',
#    'zipcode': '11361'},
#   'name': "Cj Sullivan'S",
#   'restaurant_id': '40398150'},
#  {'address': {'building': '119',
#    'coord': [-73.982139, 40.742638],
#    'street': 'Lexington Avenue',
#    'zipcode': '10016'},
#   'name': 'Curry In A Hurry',
#   'restaurant_id': '40398434'},
#  {'address': {'building': '7518',
#    'coord': [-73.879909, 40.7480778],
#    'street': 'Roosevelt Avenue',
#    'zipcode': '11372'},
#   'name': 'Cafe 75 Bar',
#   'restaurant_id': '40398658'},
#  {'address': {'building': '25-51',
#    'coord': [-73.9124892, 40.76656990000001],
#    'street': 'Steinway Street',
#    'zipcode': '11103'},
#   'name': 'Caffee Express',
#   'restaurant_id': '40398689'},
#  {'address': {'building': '425',
#    'coord': [-73.96837599999999, 40.59775399999999],
#    'street': 'Avenue U',
#    'zipcode': '11223'},
#   'name': 'Choy Le Chinese Restaurant',
#   'restaurant_id': '40398904'},
#  {'address': {'building': '1307',
#    'coord': [-73.9589834, 40.77141839999999],
#    'street': '3 Avenue',
#    'zipcode': '10021'},
#   'name': 'Candle Cafe',
#   'restaurant_id': '40399007'},
#  {'address': {'building': '150',
#    'coord': [-74.0215371, 40.6467581],
#    'street': '55 Street',
#    'zipcode': '11220'},
#   'name': 'Coffee Shop',
#   'restaurant_id': '40399340'},
#  {'address': {'building': '242',
#    'coord': [-73.9946873, 40.7232006],
#    'street': 'Mott Street',
#    'zipcode': '10012'},
#   'name': 'Cafe Gitane',
#   'restaurant_id': '40400039'},
#  {'address': {'building': '9023',
#    'coord': [-74.0320876, 40.6203769],
#    'street': '3 Avenue',
#    'zipcode': '11209'},
#   'name': "Circle'S Grill",
#   'restaurant_id': '40400096'},
#  {'address': {'building': '4413',
#    'coord': [-73.98924699999999, 40.637366],
#    'street': '13 Avenue',
#    'zipcode': '11219'},
#   'name': 'China Glatt',
#   'restaurant_id': '40400149'},
#  {'address': {'building': '620',
#    'coord': [-73.9945999, 40.7400153],
#    'street': '6 Avenue',
#    'zipcode': '10011'},
#   'name': 'Cafe Beyond',
#   'restaurant_id': '40400185'},
#  {'address': {'building': '107-12',
#    'coord': [-73.8454939, 40.7208543],
#    'street': '70 Road',
#    'zipcode': '11375'},
#   'name': 'Cabana',
#   'restaurant_id': '40400198'},
#  {'address': {'building': '111',
#    'coord': [-73.97099589999999, 40.7601877],
#    'street': 'East   55 Street',
#    'zipcode': '10022'},
#   'name': 'Create & Go',
#   'restaurant_id': '40400270'},
#  {'address': {'building': '31',
#    'coord': [-73.9956014, 40.7291935],
#    'street': 'West    4 Street',
#    'zipcode': '10012'},
#   'name': 'Campus Eatery',
#   'restaurant_id': '40400315'},
#  {'address': {'building': '2282',
#    'coord': [-73.9780885, 40.7857695],
#    'street': 'Broadway',
#    'zipcode': '10024'},
#   'name': 'Cafe Eighty Two',
#   'restaurant_id': '40400453'},
#  {'address': {'building': '3178',
#    'coord': [-73.9600397, 40.5785117],
#    'street': 'Coney Island Ave',
#    'zipcode': '11235'},
#   'name': 'Cafe Paris',
#   'restaurant_id': '40400638'},
#  {'address': {'building': '3145',
#    'coord': [-73.962751, 40.5754141],
#    'street': 'Brighton    4 Street',
#    'zipcode': '11235'},
#   'name': 'Cafe Volna',
#   'restaurant_id': '40400811'},
#  {'address': {'building': '235',
#    'coord': [-73.9877408, 40.7377223],
#    'street': 'Park Avenue South',
#    'zipcode': '10003'},
#   'name': 'City Crab',
#   'restaurant_id': '40401217'},
#  {'address': {'building': '2028',
#    'coord': [-73.867474, 40.851044],
#    'street': 'White Plains Road',
#    'zipcode': '10462'},
#   'name': "Celeste'S Snack Bar",
#   'restaurant_id': '40401250'},
#  {'address': {'building': '166',
#    'coord': [-73.9812479, 40.778125],
#    'street': 'West   72 Street',
#    'zipcode': '10023'},
#   'name': 'City Pie',
#   'restaurant_id': '40401251'},
#  {'address': {'building': '261',
#    'coord': [-78.0810058, 36.9083866],
#    'street': 'Columbus Ave Store #2',
#    'zipcode': '10023'},
#   'name': 'Columbus Gourmet Food',
#   'restaurant_id': '40401834'},
#  {'address': {'building': '530',
#    'coord': [-73.9887584, 40.7539308],
#    'street': '7 Avenue',
#    'zipcode': '10018'},
#   'name': 'Cafe Metro',
#   'restaurant_id': '40401998'},
#  {'address': {'building': '767',
#    'coord': [-73.9729466, 40.7494832],
#    'street': '2 Avenue',
#    'zipcode': '10017'},
#   'name': 'Cibo',
#   'restaurant_id': '40402151'},
#  {'address': {'building': '564',
#    'coord': [-73.9686411, 40.76513449999999],
#    'street': 'Park Avenue',
#    'zipcode': '10065'},
#   'name': 'Colony Club',
#   'restaurant_id': '40402369'},
#  {'address': {'building': '524',
#    'coord': [-73.989637, 40.769262],
#    'street': 'West   57 Street',
#    'zipcode': '10019'},
#   'name': 'Cbs Employee Cafeteria',
#   'restaurant_id': '40402788'},
#  {'address': {'building': '8',
#    'coord': [-73.96784099999999, 40.76997100000001],
#    'street': 'East   69 Street',
#    'zipcode': '10021'},
#   'name': 'Columbus Citizens Foundation',
#   'restaurant_id': '40402893'},
#  {'address': {'building': '9302',
#    'coord': [-73.8077193, 40.7005139],
#    'street': 'Sutphin Boulevard',
#    'zipcode': '11435'},
#   'name': 'Cafeteria- Lirr Employees',
#   'restaurant_id': '40403110'},
#  {'address': {'building': '1',
#    'coord': [-74.0109533, 40.7096139],
#    'street': 'Liberty Plaza',
#    'zipcode': '10006'},
#   'name': 'Cleary Gottlieb',
#   'restaurant_id': '40403768'},
#  {'address': {'building': '101',
#    'coord': [-74.01231039999999, 40.7143002],
#    'street': 'Barclay Street',
#    'zipcode': '10007'},
#   'name': 'Cafe 101 16Th Floor Cafeteria',
#   'restaurant_id': '40403880'},
#  {'address': {'building': '1301',
#    'coord': [-73.9801263, 40.7616971],
#    'street': 'Avenue Of The Americas',
#    'zipcode': '10019'},
#   'name': 'Credit Agricole',
#   'restaurant_id': '40403988'},
#  {'address': {'building': '138',
#    'coord': [-90.1910491, 38.6144575],
#    'street': 'St Convent Ave',
#    'zipcode': '10031'},
#   'name': 'City College Cafeteria',
#   'restaurant_id': '40403999'},
#  {'address': {'building': '825',
#    'coord': [-73.9866514, 40.7620624],
#    'street': '8 Avenue',
#    'zipcode': '10019'},
#   'name': 'Cravath Cafe',
#   'restaurant_id': '40404017'},
#  {'address': {'building': '30',
#    'coord': [-73.9793564, 40.7589426],
#    'street': 'Rockefeller Plaza',
#    'zipcode': '10112'},
#   'name': 'Culinart Cafe',
#   'restaurant_id': '40404071'},
#  {'address': {'building': '252',
#    'coord': [-73.9149362, 40.8333583],
#    'street': 'East  167 Street',
#    'zipcode': '10456'},
#   'name': 'Concourse Jamaican Bakery',
#   'restaurant_id': '40423547'},
#  {'address': {'building': '312',
#    'coord': [-73.9234069, 40.7014034],
#    'street': 'Knickerbocker Avenue',
#    'zipcode': '11237'},
#   'name': 'Circo Pastry Shop',
#   'restaurant_id': '40423563'},
#  {'address': {'building': '3978',
#    'coord': [-73.86009279999999, 40.8879078],
#    'street': 'White Plains Road',
#    'zipcode': '10466'},
#   'name': 'Champion Bakery',
#   'restaurant_id': '40423830'},
#  {'address': {'building': '186',
#    'coord': [-73.9403713, 40.7980917],
#    'street': 'East  116 Street',
#    'zipcode': '10029'},
#   'name': 'Capri Bakery',
#   'restaurant_id': '40424437'},
#  {'address': {'building': '400',
#    'coord': [-73.9546917, 40.7688396],
#    'street': 'East 74 Street',
#    'zipcode': '10021'},
#   'name': 'Creative Cakes',
#   'restaurant_id': '40424933'},
#  {'address': {'building': '51',
#    'coord': [-73.9860597, 40.7431194],
#    'street': 'Madison Avenue',
#    'zipcode': '10010'},
#   'name': 'Cafe Madison',
#   'restaurant_id': '40483729'},
#  {'address': {'building': '2459',
#    'coord': [-73.8929629, 40.8601605],
#    'street': 'Webster Avenue',
#    'zipcode': '10458'},
#   'name': 'China Wok Ii',
#   'restaurant_id': '40510328'},
#  {'address': {'building': '117',
#    'coord': [-73.999501, 40.7348987],
#    'street': 'West   10 Street',
#    'zipcode': '10011'},
#   'name': 'Cafe Asean',
#   'restaurant_id': '40510969'},
#  {'address': {'building': '56',
#    'coord': [-73.9869973, 40.7359131],
#    'street': 'Irving Place',
#    'zipcode': '10003'},
#   'name': "Cibar - Lady Mendl'S Tea Salon",
#   'restaurant_id': '40511479'},
#  {'address': {'building': '453',
#    'coord': [-73.9895227, 40.7671312],
#    'street': '_West   54 Street',
#    'zipcode': '10019'},
#   'name': 'Cafe Ole Usa',
#   'restaurant_id': '40512186'},
#  {'address': {'building': '47',
#    'coord': [-74.01303759999999, 40.70661],
#    'street': 'Broadway',
#    'zipcode': '10006'},
#   'name': 'China Chalet',
#   'restaurant_id': '40512403'},
#  {'address': {'building': '108',
#    'coord': [-74.0015999, 40.740631],
#    'street': '8 Avenue',
#    'zipcode': '10011'},
#   'name': 'Chelsea Trattoria',
#   'restaurant_id': '40512520'},
#  {'address': {'building': '79',
#    'coord': [-73.924914, 40.827846],
#    'street': 'East  161 Street',
#    'zipcode': '10451'},
#   'name': 'Crown Diner',
#   'restaurant_id': '40512746'},
#  {'address': {'building': '14',
#    'coord': [-73.9778118, 40.7561728],
#    'street': 'East   47 Street',
#    'zipcode': '10017'},
#   'name': "Connolly'S Pub",
#   'restaurant_id': '40512865'},
#  {'address': {'building': '110',
#    'coord': [-74.008558, 40.732037],
#    'street': 'Barrow Street',
#    'zipcode': '10014'},
#   'name': 'Creative Edge Caterers',
#   'restaurant_id': '40514147'},
#  {'address': {'building': '2880',
#    'coord': [-73.8285999, 40.8324789],
#    'street': 'Bruckner Boulevard',
#    'zipcode': '10465'},
#   'name': 'Crosstown Diner',
#   'restaurant_id': '40515675'},
#  {'address': {'building': '2800',
#    'coord': [-74.15198199999999, 40.6009948],
#    'street': 'Victory Boulevard',
#    'zipcode': '10314'},
#   'name': 'Campus Center Cafeteria',
#   'restaurant_id': '40516509'},
#  {'address': {'building': '2303',
#    'coord': [-73.8893286, 40.8535484],
#    'street': 'Arthur Avenue',
#    'zipcode': '10458'},
#   'name': "Catania'S Pizza Cafe",
#   'restaurant_id': '40521624'},
#  {'address': {'building': '149',
#    'coord': [-73.8280734, 40.8775869],
#    'street': 'Dreiser Loop',
#    'zipcode': '10475'},
#   'name': 'Capri Ii Pizza',
#   'restaurant_id': '40525767'},
#  {'address': {'building': '26',
#    'coord': [-73.96936149999999, 40.7658603],
#    'street': 'East   63 Street',
#    'zipcode': '10065'},
#   'name': 'Club Macanudo (Cigar Bar)',
#   'restaurant_id': '40526406'},
#  {'address': {'building': '11',
#    'coord': [-74.00947049999999, 40.7045563],
#    'street': 'Hanover Square',
#    'zipcode': '10004'},
#   'name': 'Cafe Bravo',
#   'restaurant_id': '40529655'},
#  {'address': {'building': '66',
#    'coord': [-74.010069, 40.7147337],
#    'street': 'West Broadway',
#    'zipcode': '10007'},
#   'name': 'Corner Gourmet Ii',
#   'restaurant_id': '40530583'},
#  {'address': {'building': '1460',
#    'coord': [-73.8460571, 40.78431080000001],
#    'street': 'College Point Boulevard',
#    'zipcode': '11356'},
#   'name': "Cascarino'S Pizza",
#   'restaurant_id': '40534044'},
#  {'address': {'building': '120',
#    'coord': [-73.9793577, 40.7630705],
#    'street': 'West   55 Street',
#    'zipcode': '10019'},
#   'name': 'Circo Restaurant',
#   'restaurant_id': '40534379'},
#  {'address': {'building': '1674',
#    'coord': [-73.982872, 40.76280939999999],
#    'street': 'Broadway',
#    'zipcode': '10019'},
#   'name': 'Crown Gourmet Deli',
#   'restaurant_id': '40534810'},
#  {'address': {'building': '200',
#    'coord': [-73.9966194, 40.7433635],
#    'street': '7 Avenue',
#    'zipcode': '10011'},
#   'name': 'Cafe Champignon',
#   'restaurant_id': '40535391'},
#  {'address': {'building': '161',
#    'coord': [-73.9965239, 40.719646],
#    'street': 'Mott Street',
#    'zipcode': '10013'},
#   'name': 'Chiu Hong Bakery',
#   'restaurant_id': '40535467'},
#  {'address': {'building': '75-02',
#    'coord': [-73.8923707, 40.7583122],
#    'street': '31 Avenue',
#    'zipcode': '11370'},
#   'name': "Cassidy'S Ale House",
#   'restaurant_id': '40536534'},
#  {'address': {'building': '171',
#    'coord': [-73.9772878, 40.671776],
#    'street': '7 Avenue',
#    'zipcode': '11215'},
#   'name': 'Connecticut Muffin',
#   'restaurant_id': '40536785'},
#  {'address': {'building': '726',
#    'coord': [-73.8903473, 40.8447875],
#    'street': 'East Tremont Avenue',
#    'zipcode': '10457'},
#   'name': 'Cosmos Restaurant',
#   'restaurant_id': '40538061'},
#  {'address': {'building': '320',
#    'coord': [-73.971248, 40.5901629],
#    'street': 'Avenue X',
#    'zipcode': '11223'},
#   'name': 'Cuccios Bakery',
#   'restaurant_id': '40542546'},
#  {'address': {'building': '6091',
#    'coord': [-73.8950873, 40.7009461],
#    'street': 'Myrtle Avenue',
#    'zipcode': '11385'},
#   'name': 'Corato Pizza Ii',
#   'restaurant_id': '40544529'},
#  {'address': {'building': '2342',
#    'coord': [-73.92533499999999, 40.7685025],
#    'street': '30 Avenue',
#    'zipcode': '11102'},
#   'name': 'Crescent Corner',
#   'restaurant_id': '40544613'},
#  {'address': {'building': '61',
#    'coord': [-74.00358059999999, 40.7317983],
#    'street': '7 Avenue South',
#    'zipcode': '10014'},
#   'name': 'Caliente Cab Co',
#   'restaurant_id': '40544958'},
#  {'address': {'building': '178',
#    'coord': [-73.9901958, 40.7412679],
#    'street': '5 Avenue',
#    'zipcode': '10010'},
#   'name': 'City Market Cafe',
#   'restaurant_id': '40545071'},
#  {'address': {'building': '220',
#    'coord': [-73.9933039, 40.7493998],
#    'street': 'West 31 Street',
#    'zipcode': '10001'},
#   'name': 'Cafe 31',
#   'restaurant_id': '40545546'},
#  {'address': {'building': '316',
#    'coord': [-73.9877321, 40.7619602],
#    'street': 'West   49 Street',
#    'zipcode': '10019'},
#   'name': 'Churrascaria Plataforma',
#   'restaurant_id': '40546098'},
#  {'address': {'building': '1250',
#    'coord': [-73.8511316, 40.8335033],
#    'street': 'Castle Hill Ave',
#    'zipcode': '10462'},
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40550801'},
#  {'address': {'building': '171',
#    'coord': [-73.8370236, 40.579157],
#    'street': 'Beach  116 Street',
#    'zipcode': '11694'},
#   'name': "Ciro'S Pizza Restaurant",
#   'restaurant_id': '40557434'},
#  {'address': {'building': '3250',
#    'coord': [-73.9376807, 40.7674632],
#    'street': 'Vernon Boulevard',
#    'zipcode': '11106'},
#   'name': 'Costco Wholesale',
#   'restaurant_id': '40559243'},
#  {'address': {'building': '481',
#    'coord': [-73.9934785, 40.7527038],
#    'street': '8 Avenue',
#    'zipcode': '10001'},
#   'name': 'Coopers Tavern',
#   'restaurant_id': '40559636'},
#  {'address': {'building': '410',
#    'coord': [-73.900514, 40.847339],
#    'street': 'East Tremont Avenue',
#    'zipcode': '10457'},
#   'name': 'Caridad Restaurant',
#   'restaurant_id': '40560308'},
#  {'address': {'building': '138',
#    'coord': [-73.98306800000002, 40.7591309],
#    'street': 'West   48 Street',
#    'zipcode': '10036'},
#   'name': 'Cort Theatre',
#   'restaurant_id': '40560949'},
#  {'address': {'building': '3290',
#    'coord': [-73.92430569999999, 40.7565317],
#    'street': '36 Street',
#    'zipcode': '11106'},
#   'name': 'Cafe Bar',
#   'restaurant_id': '40561796'},
#  {'address': {'building': '500',
#    'coord': [-73.960049, 40.8094253],
#    'street': 'West 120 Street',
#    'zipcode': '10027'},
#   'name': 'Carleton Lounge - Mudd Building',
#   'restaurant_id': '40563829'},
#  {'address': {'building': '3501',
#    'coord': [-73.921888, 40.76061199999999],
#    'street': 'Broadway',
#    'zipcode': '11106'},
#   'name': 'Caravan Chicken',
#   'restaurant_id': '40565141'},
#  {'address': {'building': '110',
#    'coord': [-74.0021229, 40.7382669],
#    'street': 'Greenwich Avenue',
#    'zipcode': '10011'},
#   'name': 'Carry On Tea & Sympathy',
#   'restaurant_id': '40566335'},
#  {'address': {'building': '158',
#    'coord': [-73.948014, 40.7264539],
#    'street': 'Norman Avenue',
#    'zipcode': '11222'},
#   'name': "Connie O'S",
#   'restaurant_id': '40566431'},
#  {'address': {'building': '191',
#    'coord': [-73.9977311, 40.7182328],
#    'street': 'Hester St',
#    'zipcode': '10013'},
#   'name': 'Caffe Napoli',
#   'restaurant_id': '40567158'},
#  {'address': {'building': '1460',
#    'coord': [-73.9503667, 40.6349956],
#    'street': 'Flatbush Avenue',
#    'zipcode': '11210'},
#   'name': 'Crystal Manor',
#   'restaurant_id': '40570254'},
#  {'address': {'building': '854',
#    'coord': [-73.9814742, 40.7642335],
#    'street': '7 Avenue',
#    'zipcode': '10019'},
#   'name': 'Carnegie Delicatessen & Restaurant',
#   'restaurant_id': '40571198'},
#  {'address': {'building': '27',
#    'coord': [-73.95622589999999, 40.7848855],
#    'street': 'East   92 Street',
#    'zipcode': '10128'},
#   'name': 'Ciao Bella',
#   'restaurant_id': '40572957'},
#  {'address': {'building': '1470',
#    'coord': [-73.9536119, 40.7705841],
#    'street': '1 Avenue',
#    'zipcode': '10075'},
#   'name': 'Canyon Road Grill',
#   'restaurant_id': '40573131'},
#  {'address': {'building': '361',
#    'coord': [-73.78737300000002, 40.84861],
#    'street': 'City Island Ave',
#    'zipcode': '10464'},
#   'name': 'Crab Shanty',
#   'restaurant_id': '40573338'},
#  {'address': {'building': '3060',
#    'coord': [-73.8562166, 40.87044789999999],
#    'street': 'Boston Road',
#    'zipcode': '10469'},
#   'name': "Cafe Lou'S",
#   'restaurant_id': '40575255'},
#  {'address': {'building': '376',
#    'coord': [-74.0030019, 40.7235659],
#    'street': 'West Broadway',
#    'zipcode': '10012'},
#   'name': 'Cipriani Downtown Restaurant',
#   'restaurant_id': '40576044'},
#  {'address': {'building': '3042',
#    'coord': [-73.944092, 40.610156],
#    'street': 'Nostrand Avenue',
#    'zipcode': '11229'},
#   'name': 'Claddagh Inn',
#   'restaurant_id': '40578092'},
#  {'address': {'building': '3785',
#    'coord': [-74.18227569999999, 40.5975538],
#    'street': 'Victory Boulevard',
#    'zipcode': '10314'},
#   'name': 'Chicken Holiday Express',
#   'restaurant_id': '40579745'},
#  {'address': {'building': '704',
#    'coord': [-73.9639194, 40.597882],
#    'street': 'Avenue U',
#    'zipcode': '11223'},
#   'name': 'Caffe Venezia',
#   'restaurant_id': '40580405'},
#  {'address': {'building': '3801',
#    'coord': [-73.94463139999999, 40.8349956],
#    'street': 'Broadway',
#    'zipcode': '10032'},
#   'name': 'Coral Diner',
#   'restaurant_id': '40580969'},
#  {'address': {'building': '1',
#    'coord': [-73.94447079999999, 40.7473237],
#    'street': 'Court Square',
#    'zipcode': '11101'},
#   'name': 'Citibank Employee Cafeteria',
#   'restaurant_id': '40583239'},
#  {'address': {'building': '55',
#    'coord': [-73.986193, 40.750245],
#    'street': 'West   35 Street',
#    'zipcode': '10001'},
#   'name': 'Cho Dang Gol',
#   'restaurant_id': '40584086'},
#  {'address': {'building': '81',
#    'coord': [-73.9854578, 40.727888],
#    'street': 'St Marks Place',
#    'zipcode': '10003'},
#   'name': 'Cafe Rakka',
#   'restaurant_id': '40585040'},
#  {'address': {'building': '338',
#    'coord': [-73.9519253, 40.7341312],
#    'street': 'Mc Guiness Boulevard',
#    'zipcode': '11222'},
#   'name': 'Casanova Restaurant',
#   'restaurant_id': '40585479'},
#  {'address': {'building': '11319',
#    'coord': [-73.8094089, 40.5905154],
#    'street': 'Beach Channel Drive',
#    'zipcode': '11694'},
#   'name': 'Ciro Pizza',
#   'restaurant_id': '40588072'},
#  {'address': {'building': '30',
#    'coord': [-73.9847939, 40.744186],
#    'street': 'East   29 Street',
#    'zipcode': '10016'},
#   'name': 'Campanile',
#   'restaurant_id': '40589044'},
#  {'address': {'building': '206',
#    'coord': [-73.98051989999999, 40.6607441],
#    'street': 'Prospect Park West',
#    'zipcode': '11215'},
#   'name': 'Connecticut Muffin',
#   'restaurant_id': '40589507'},
#  {'address': {'building': '48',
#    'coord': [-73.99222379999999, 40.6995965],
#    'street': 'Henry Street',
#    'zipcode': '11201'},
#   'name': "Cranberry'S",
#   'restaurant_id': '40590237'},
#  {'address': {'building': '320',
#    'coord': [-73.980368, 40.780879],
#    'street': 'Amsterdam Avenue',
#    'zipcode': '10023'},
#   'name': 'Citrus Bar & Grill',
#   'restaurant_id': '40593202'},
#  {'address': {'building': '161',
#    'coord': [-74.00121299999999, 40.726163],
#    'street': 'Prince Street',
#    'zipcode': '10012'},
#   'name': 'Cafe Borgia Ii',
#   'restaurant_id': '40593646'},
#  {'address': {'building': '7111',
#    'coord': [-73.989425, 40.612718],
#    'street': '20 Avenue',
#    'zipcode': '11204'},
#   'name': "Caffe' Romeo",
#   'restaurant_id': '40597074'},
#  {'address': {'building': '115',
#    'coord': [-73.994787, 40.695161],
#    'street': 'Montague Street',
#    'zipcode': '11201'},
#   'name': 'Connecticut Muffin',
#   'restaurant_id': '40597410'},
#  {'address': {'building': '148',
#    'coord': [-73.9972901, 40.7189915],
#    'street': 'Mulberry Street',
#    'zipcode': '10013'},
#   'name': 'Caffe Palermo',
#   'restaurant_id': '40600516'},
#  {'address': {'building': '304',
#    'coord': [-73.78629219999999, 40.8471662],
#    'street': 'City Island Ave',
#    'zipcode': '10464'},
#   'name': 'City Island Diner /Snug Bar',
#   'restaurant_id': '40604207'},
#  {'address': {'building': '1215',
#    'coord': [-73.9591141, 40.8089857],
#    'street': 'Amnsterdam Avenue',
#    'zipcode': '10027'},
#   'name': 'Che Bella Pizza',
#   'restaurant_id': '40604400'},
#  {'address': {'building': '225',
#    'coord': [-73.97926749999999, 40.77620940000001],
#    'street': 'Columbus Avenue',
#    'zipcode': '10023'},
#   'name': 'Cassis Bistro/Brasserie',
#   'restaurant_id': '40605282'},
#  {'address': {'building': '153',
#    'coord': [-73.970443, 40.75844],
#    'street': 'East   53 Street',
#    'zipcode': '10022'},
#   'name': 'Citibank Executive Conference Center',
#   'restaurant_id': '40610155'},
#  {'address': {'building': '31-08',
#    'coord': [-73.9178935, 40.769715],
#    'street': 'Astoria Boulevard',
#    'zipcode': '11102'},
#   'name': 'Caprice',
#   'restaurant_id': '40611134'},
#  {'address': {'building': '131',
#    'coord': [-74.007454, 40.71637800000001],
#    'street': 'Duane Street',
#    'zipcode': '10013'},
#   'name': 'City Hall Restaurant',
#   'restaurant_id': '40612524'},
#  {'address': {'building': '7611',
#    'coord': [-73.99657499999999, 40.61236299999999],
#    'street': '18 Avenue',
#    'zipcode': '11214'},
#   'name': 'C & C Catering',
#   'restaurant_id': '40617224'},
#  {'address': {'building': '2401',
#    'coord': [-73.84662039999999, 40.8372031],
#    'street': 'Westchester Avenue',
#    'zipcode': '10461'},
#   'name': 'Capri Pizza Restaurant',
#   'restaurant_id': '40617679'},
#  {'address': {'building': '101',
#    'coord': [-73.98431699999999, 40.727441],
#    'street': 'St Marks Place',
#    'zipcode': '10009'},
#   'name': 'Cafe Mogador',
#   'restaurant_id': '40618557'},
#  {'address': {'building': '',
#    'coord': [-73.9988889, 40.7477778],
#    'street': 'Penn Station',
#    'zipcode': '10001'},
#   'name': 'Chickpea',
#   'restaurant_id': '40619303'},
#  {'address': {'building': '119',
#    'coord': [-73.99788459999999, 40.740528],
#    'street': '7 Avenue',
#    'zipcode': '10011'},
#   'name': 'Cafeteria',
#   'restaurant_id': '40619544'},
#  {'address': {'building': '622',
#    'coord': [-73.886871, 40.854888],
#    'street': 'East 187 Street',
#    'zipcode': '10458'},
#   'name': 'Caffe Egidio',
#   'restaurant_id': '40621241'},
#  {'address': {'building': '151',
#    'coord': [-73.99324299999999, 40.694735],
#    'street': 'Montague Street',
#    'zipcode': '11201'},
#   'name': 'Caffe Buon Gusto',
#   'restaurant_id': '40624802'},
#  {'address': {'building': '1712',
#    'coord': [-73.9478306, 40.778485],
#    'street': 'First Avenue',
#    'zipcode': '10128'},
#   'name': 'Cavatappo Grill',
#   'restaurant_id': '40624951'},
#  {'address': {'building': '511',
#    'coord': [-73.9935848, 40.7330038],
#    'street': 'University Place',
#    'zipcode': '10003'},
#   'name': "Chic-Fil-A, Quiznos Subs, Jw'S, Tossed",
#   'restaurant_id': '40634715'},
#  {'address': {'building': '405',
#    'coord': [-73.98565239999999, 40.7263767],
#    'street': 'East    6 Street',
#    'zipcode': '10009'},
#   'name': 'Caravan Of Dreams',
#   'restaurant_id': '40635781'},
#  {'address': {'building': '28030',
#    'coord': [-74.1629372, 40.5806591],
#    'street': 'Marsh Avenue',
#    'zipcode': '10314'},
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40639953'},
#  {'address': {'building': '976',
#    'coord': [-74.0090742, 40.6554813],
#    'street': '3 Avenue',
#    'zipcode': '11232'},
#   'name': 'Costco Wholesale',
#   'restaurant_id': '40645986'},
#  {'address': {'building': '208',
#    'coord': [-73.965688, 40.761744],
#    'street': 'East   60 Street',
#    'zipcode': '10022'},
#   'name': 'Canaletto Ristorante',
#   'restaurant_id': '40649377'},
#  {'address': {'building': '2331',
#    'coord': [-73.8877756, 40.8541437],
#    'street': 'Hughes Avenue',
#    'zipcode': '10458'},
#   'name': 'Cafe Al Mercato',
#   'restaurant_id': '40654328'},
#  {'address': {'building': '1712',
#    'coord': [-73.950141, 40.77950999999999],
#    'street': '2 Avenue',
#    'zipcode': '10128'},
#   'name': 'Cilantro',
#   'restaurant_id': '40654675'},
#  {'address': {'building': '72',
#    'coord': [-74.0047385, 40.731475],
#    'street': 'Bedford Street',
#    'zipcode': '10014'},
#   'name': 'Casa',
#   'restaurant_id': '40655520'},
#  {'address': {'building': '13208',
#    'coord': [-73.8441198, 40.6764737],
#    'street': 'Crossbay Boulevard',
#    'zipcode': '11417'},
#   'name': "Cookie'S Lounge",
#   'restaurant_id': '40660193'},
#  {'address': {'building': '32',
#    'coord': [-74.0043525, 40.7236469],
#    'street': 'Watts Street',
#    'zipcode': '10013'},
#   'name': 'Circa Tabac',
#   'restaurant_id': '40664052'},
#  {'address': {'building': '378',
#    'coord': [-73.98153599999999, 40.741651],
#    'street': '3 Avenue',
#    'zipcode': '10016'},
#   'name': "Coppola'S",
#   'restaurant_id': '40667358'},
#  {'address': {'building': '15259',
#    'coord': [-119.6368672, 36.2504996],
#    'street': '10 Avenue',
#    'zipcode': '11357'},
#   'name': "Cascarino'S",
#   'restaurant_id': '40668681'},
#  {'address': {'building': '397',
#    'coord': [-74.01589299999999, 40.7115385],
#    'street': 'South End Avenue',
#    'zipcode': '10280'},
#   'name': 'Cafe Express',
#   'restaurant_id': '40674598'},
#  {'address': {'building': '505',
#    'coord': [-73.9779696, 40.7454765],
#    'street': '3 Avenue',
#    'zipcode': '10016'},
#   'name': 'Cinema Cafe & Bar',
#   'restaurant_id': '40678550'},
#  {'address': {'building': '42-18',
#    'coord': [-73.9152214, 40.7601975],
#    'street': '31 Avenue',
#    'zipcode': '11103'},
#   'name': 'Cavo',
#   'restaurant_id': '40680038'},
#  {'address': {'building': '20',
#    'coord': [-73.9799726, 40.7586467],
#    'street': 'Rockefeller Plaza',
#    'zipcode': '10020'},
#   'name': "Christie'S",
#   'restaurant_id': '40686696'},
#  {'address': {'building': '344',
#    'coord': [-73.830641, 40.867177],
#    'street': 'Baychester Avenue',
#    'zipcode': '10475'},
#   'name': 'Checkers',
#   'restaurant_id': '40690910'},
#  {'address': {'building': '1251',
#    'coord': [-73.9817238, 40.7599885],
#    'street': 'Avenue Of The Americas',
#    'zipcode': '10020'},
#   'name': 'City Lobster & Steak',
#   'restaurant_id': '40699514'},
#  {'address': {'building': '16',
#    'coord': [-73.97807010000001, 40.7530362],
#    'street': 'Vanderbilt Avenue',
#    'zipcode': '10017'},
#   'name': 'Central Cafe',
#   'restaurant_id': '40704232'},
#  {'address': {'building': '365',
#    'coord': [-73.98400699999999, 40.7486485],
#    'street': 'Fifth Avenue',
#    'zipcode': '10016'},
#   'name': 'C.U.N.Y Cafe',
#   'restaurant_id': '40710515'},
#  {'address': {'building': '2920',
#    'coord': [-73.9640299, 40.807001],
#    'street': 'Broadway',
#    'zipcode': '10027'},
#   'name': 'Cafe 212/Columbia Catering Kitchen - Alfred Lerner Hall',
#   'restaurant_id': '40710953'},
#  {'address': {'building': '2919',
#    'coord': [-73.9109154, 40.7766011],
#    'street': 'Ditmars Boulevard',
#    'zipcode': '11105'},
#   'name': 'Chicken Festival',
#   'restaurant_id': '40711301'},
#  {'address': {'building': '394',
#    'coord': [-73.9463447, 40.6542651],
#    'street': 'Lenox Road',
#    'zipcode': '11203'},
#   'name': 'Cafe 101',
#   'restaurant_id': '40711788'},
#  {'address': {'building': '1775',
#    'coord': [-74.1928099, 40.6000765],
#    'street': 'South Avenue',
#    'zipcode': '10314'},
#   'name': "Chuck E Cheese'S",
#   'restaurant_id': '40716299'},
#  {'address': {'building': '104-03',
#    'coord': [-73.848705, 40.710323],
#    'street': 'Metropolitan Avenue',
#    'zipcode': '11375'},
#   'name': 'Continental Luncheonette & Deli',
#   'restaurant_id': '40721162'},
#  {'address': {'building': '153',
#    'coord': [-73.970443, 40.75844],
#    'street': 'East   53 Street',
#    'zipcode': '10022'},
#   'name': 'Cucina Gourmet',
#   'restaurant_id': '40721693'},
#  {'address': {'building': '48-18',
#    'coord': [-73.9136305, 40.7533158],
#    'street': 'Northern Boulevard',
#    'zipcode': '11101'},
#   'name': "Chuck E Cheese'S",
#   'restaurant_id': '40724462'},
#  {'address': {'building': '2',
#    'coord': [-73.9791142, 40.754993],
#    'street': 'East   45 Street',
#    'zipcode': '10017'},
#   'name': 'Cinema The Brasserie',
#   'restaurant_id': '40725075'},
#  {'address': {'building': '87',
#    'coord': [-73.989747, 40.726523],
#    'street': 'East    4 Street',
#    'zipcode': '10003'},
#   'name': 'Cucina Di Pesce',
#   'restaurant_id': '40726044'},
#  {'address': {'building': '657',
#    'coord': [-73.9574976, 40.6945948],
#    'street': 'Myrtle Avenue',
#    'zipcode': '11205'},
#   'name': 'Chinantla',
#   'restaurant_id': '40727214'},
#  {'address': {'building': '79-19',
#    'coord': [-73.88595699999999, 40.74762399999999],
#    'street': 'Roosevelt Avenue',
#    'zipcode': '11372'},
#   'name': 'Cositas Ricas',
#   'restaurant_id': '40729439'},
#  {'address': {'building': '1056',
#    'coord': [-73.8542141, 40.84864580000001],
#    'street': 'Morris Park Ave',
#    'zipcode': '10461'},
#   'name': "Captain'S Pizzeria And Restaurant",
#   'restaurant_id': '40731746'},
#  {'address': {'building': '1070',
#    'coord': [-73.9620217, 40.7590592],
#    'street': '1 Avenue',
#    'zipcode': '10022'},
#   'name': 'Cafe Joul',
# ...
#    'street': 'Hughes Avenue',
#    'zipcode': '10458'},
#   'name': 'Cafe Al Mercato',
#   'restaurant_id': '40654328'},
#  {'address': {'building': '1712',
#    'coord': [-73.950141, 40.77950999999999],
#    'street': '2 Avenue',
#    'zipcode': '10128'},
#   'name': 'Cilantro',
#   'restaurant_id': '40654675'},
#  {'address': {'building': '72',
#    'coord': [-74.0047385, 40.731475],
#    'street': 'Bedford Street',
#    'zipcode': '10014'},
#   'name': 'Casa',
#   'restaurant_id': '40655520'},
#  {'address': {'building': '13208',
#    'coord': [-73.8441198, 40.6764737],
#    'street': 'Crossbay Boulevard',
#    'zipcode': '11417'},
#   'name': "Cookie'S Lounge",
#   'restaurant_id': '40660193'},
#  {'address': {'building': '32',
#    'coord': [-74.0043525, 40.7236469],
#    'street': 'Watts Street',
#    'zipcode': '10013'},
#   'name': 'Circa Tabac',
#   'restaurant_id': '40664052'},
#  {'address': {'building': '378',
#    'coord': [-73.98153599999999, 40.741651],
#    'street': '3 Avenue',
#    'zipcode': '10016'},
#   'name': "Coppola'S",
#   'restaurant_id': '40667358'},
#  {'address': {'building': '15259',
#    'coord': [-119.6368672, 36.2504996],
#    'street': '10 Avenue',
#    'zipcode': '11357'},
#   'name': "Cascarino'S",
#   'restaurant_id': '40668681'},
#  {'address': {'building': '397',
#    'coord': [-74.01589299999999, 40.7115385],
#    'street': 'South End Avenue',
#    'zipcode': '10280'},
#   'name': 'Cafe Express',
#   'restaurant_id': '40674598'},
#  {'address': {'building': '505',
#    'coord': [-73.9779696, 40.7454765],
#    'street': '3 Avenue',
#    'zipcode': '10016'},
#   'name': 'Cinema Cafe & Bar',
#   'restaurant_id': '40678550'},
#  {'address': {'building': '42-18',
#    'coord': [-73.9152214, 40.7601975],
#    'street': '31 Avenue',
#    'zipcode': '11103'},
#   'name': 'Cavo',
#   'restaurant_id': '40680038'},
#  {'address': {'building': '20',
#    'coord': [-73.9799726, 40.7586467],
#    'street': 'Rockefeller Plaza',
#    'zipcode': '10020'},
#   'name': "Christie'S",
#   'restaurant_id': '40686696'},
#  {'address': {'building': '344',
#    'coord': [-73.830641, 40.867177],
#    'street': 'Baychester Avenue',
#    'zipcode': '10475'},
#   'name': 'Checkers',
#   'restaurant_id': '40690910'},
#  {'address': {'building': '1251',
#    'coord': [-73.9817238, 40.7599885],
#    'street': 'Avenue Of The Americas',
#    'zipcode': '10020'},
#   'name': 'City Lobster & Steak',
#   'restaurant_id': '40699514'},
#  {'address': {'building': '16',
#    'coord': [-73.97807010000001, 40.7530362],
#    'street': 'Vanderbilt Avenue',
#    'zipcode': '10017'},
#   'name': 'Central Cafe',
#   'restaurant_id': '40704232'},
#  {'address': {'building': '365',
#    'coord': [-73.98400699999999, 40.7486485],
#    'street': 'Fifth Avenue',
#    'zipcode': '10016'},
#   'name': 'C.U.N.Y Cafe',
#   'restaurant_id': '40710515'},
#  {'address': {'building': '2920',
#    'coord': [-73.9640299, 40.807001],
#    'street': 'Broadway',
#    'zipcode': '10027'},
#   'name': 'Cafe 212/Columbia Catering Kitchen - Alfred Lerner Hall',
#   'restaurant_id': '40710953'},
#  {'address': {'building': '2919',
#    'coord': [-73.9109154, 40.7766011],
#    'street': 'Ditmars Boulevard',
#    'zipcode': '11105'},
#   'name': 'Chicken Festival',
#   'restaurant_id': '40711301'},
#  {'address': {'building': '394',
#    'coord': [-73.9463447, 40.6542651],
#    'street': 'Lenox Road',
#    'zipcode': '11203'},
#   'name': 'Cafe 101',
#   'restaurant_id': '40711788'},
#  {'address': {'building': '1775',
#    'coord': [-74.1928099, 40.6000765],
#    'street': 'South Avenue',
#    'zipcode': '10314'},
#   'name': "Chuck E Cheese'S",
#   'restaurant_id': '40716299'},
#  {'address': {'building': '104-03',
#    'coord': [-73.848705, 40.710323],
#    'street': 'Metropolitan Avenue',
#    'zipcode': '11375'},
#   'name': 'Continental Luncheonette & Deli',
#   'restaurant_id': '40721162'},
#  {'address': {'building': '153',
#    'coord': [-73.970443, 40.75844],
#    'street': 'East   53 Street',
#    'zipcode': '10022'},
#   'name': 'Cucina Gourmet',
#   'restaurant_id': '40721693'},
#  {'address': {'building': '48-18',
#    'coord': [-73.9136305, 40.7533158],
#    'street': 'Northern Boulevard',
#    'zipcode': '11101'},
#   'name': "Chuck E Cheese'S",
#   'restaurant_id': '40724462'},
#  {'address': {'building': '2',
#    'coord': [-73.9791142, 40.754993],
#    'street': 'East   45 Street',
#    'zipcode': '10017'},
#   'name': 'Cinema The Brasserie',
#   'restaurant_id': '40725075'},
#  {'address': {'building': '87',
#    'coord': [-73.989747, 40.726523],
#    'street': 'East    4 Street',
#    'zipcode': '10003'},
#   'name': 'Cucina Di Pesce',
#   'restaurant_id': '40726044'},
#  {'address': {'building': '657',
#    'coord': [-73.9574976, 40.6945948],
#    'street': 'Myrtle Avenue',
#    'zipcode': '11205'},
#   'name': 'Chinantla',
#   'restaurant_id': '40727214'},
#  {'address': {'building': '79-19',
#    'coord': [-73.88595699999999, 40.74762399999999],
#    'street': 'Roosevelt Avenue',
#    'zipcode': '11372'},
#   'name': 'Cositas Ricas',
#   'restaurant_id': '40729439'},
#  {'address': {'building': '1056',
#    'coord': [-73.8542141, 40.84864580000001],
#    'street': 'Morris Park Ave',
#    'zipcode': '10461'},
#   'name': "Captain'S Pizzeria And Restaurant",
#   'restaurant_id': '40731746'},
#  {'address': {'building': '1070',
#    'coord': [-73.9620217, 40.7590592],
#    'street': '1 Avenue',
#    'zipcode': '10022'},
#   'name': 'Cafe Joul',
#   'restaurant_id': '40734557'},
#  {'address': {'building': '89',
#    'coord': [-73.9934645, 40.71554649999999],
#    'street': 'Canal Street',
#    'zipcode': '10002'},
#   'name': 'Cup & Saucer',
#   'restaurant_id': '40735180'},
#  {'address': {'building': '244',
#    'coord': [-73.95903109999999, 40.71347129999999],
#    'street': 'Grand Street',
#    'zipcode': '11211'},
#   'name': 'Caribbean Sports',
#   'restaurant_id': '40738973'},
#  {'address': {'building': '48',
#    'coord': [-73.9812776, 40.7568337],
#    'street': 'West   46 Street',
#    'zipcode': '10036'},
#   'name': 'Cafe Cello Deli',
#   'restaurant_id': '40739883'},
#  {'address': {'building': '1111',
#    'coord': [-73.96439029999999, 40.6225488],
#    'street': 'Avenue K',
#    'zipcode': '11230'},
#   'name': 'Cafe K',
#   'restaurant_id': '40740251'},
#  {'address': {'building': '41',
#    'coord': [-73.9870615, 40.7285042],
#    'street': 'St Marks Place',
#    'zipcode': '10003'},
#   'name': 'Cafe Orlin',
#   'restaurant_id': '40744833'},
#  {'address': {'building': '415',
#    'coord': [-73.84947930000001, 40.5782181],
#    'street': 'Beach  129 Street',
#    'zipcode': '11694'},
#   'name': 'Ciros Pastry Shop',
#   'restaurant_id': '40746162'},
#  {'address': {'building': '1535',
#    'coord': [-73.9862536, 40.7585799],
#    'street': 'Broadway',
#    'zipcode': '10036'},
#   'name': 'Crossroads (Marriott Marquis)',
#   'restaurant_id': '40750285'},
#  {'address': {'building': '14751',
#    'coord': [-74.01136939999999, 40.7164914],
#    'street': 'Chambers Street',
#    'zipcode': '10013'},
#   'name': "Cafe Amore'S Restaurant",
#   'restaurant_id': '40752011'},
#  {'address': {'building': '112',
#    'coord': [-73.8610744, 40.8324594],
#    'street': 'Hugh Grant Circle',
#    'zipcode': '10472'},
#   'name': 'Circle Pizzeria',
#   'restaurant_id': '40755548'},
#  {'address': {'building': '1319',
#    'coord': [-73.95688799999999, 40.767069],
#    'street': '1 Avenue',
#    'zipcode': '10021'},
#   'name': 'Cafe Luka',
#   'restaurant_id': '40757539'},
#  {'address': {'building': '368',
#    'coord': [-73.97644199999999, 40.7810076],
#    'street': 'Columbus Avenue',
#    'zipcode': '10024'},
#   'name': 'Cafe Frida',
#   'restaurant_id': '40758427'},
#  {'address': {'building': '236',
#    'coord': [-73.9571457, 40.7722763],
#    'street': 'East   77 Street',
#    'zipcode': '10075'},
#   'name': 'Cafe Buon Gusto',
#   'restaurant_id': '40759586'},
#  {'address': {'building': '1633',
#    'coord': [-73.9845362, 40.7620434],
#    'street': 'Broadway',
#    'zipcode': '10019'},
#   'name': 'Circle In The Square Theatre',
#   'restaurant_id': '40761262'},
#  {'address': {'building': '466',
#    'coord': [-73.9747277, 40.7536114],
#    'street': 'Lexington Avenue',
#    'zipcode': '10017'},
#   'name': 'Cafe Metro',
#   'restaurant_id': '40761780'},
#  {'address': {'building': '1720',
#    'coord': [-73.9498632, 40.7799512],
#    'street': '2 Avenue',
#    'zipcode': '10128'},
#   'name': "Chef Ho'S",
#   'restaurant_id': '40763888'},
#  {'address': {'building': '1919',
#    'coord': [-73.95546499999999, 40.6187332],
#    'street': 'Avenue M',
#    'zipcode': '11230'},
#   'name': 'Chadash Falafel & Pizza',
#   'restaurant_id': '40764279'},
#  {'address': {'building': '545',
#    'coord': [-73.9988, 40.723726],
#    'street': 'Broadway',
#    'zipcode': '10012'},
#   'name': 'Cafe Duke',
#   'restaurant_id': '40765318'},
#  {'address': {'building': '1436',
#    'coord': [-73.84471610000001, 40.84312430000001],
#    'street': 'Williamsbridge Road',
#    'zipcode': '10461'},
#   'name': 'Caridad',
#   'restaurant_id': '40781213'},
#  {'address': {'building': '4910',
#    'coord': [-74.0099658, 40.6454685],
#    'street': '5 Avenue',
#    'zipcode': '11220'},
#   'name': 'Charles Pizzeria',
#   'restaurant_id': '40782328'},
#  {'address': {'building': '68',
#    'coord': [-73.9775629, 40.6810713],
#    'street': '5 Avenue',
#    'zipcode': '11217'},
#   'name': 'Convivium Osteria',
#   'restaurant_id': '40783014'},
#  {'address': {'building': '1806',
#    'coord': [-73.9732461, 40.6086286],
#    'street': 'Mc Donald Avenue',
#    'zipcode': '11223'},
#   'name': 'Cindy Restaurant Luncheonette',
#   'restaurant_id': '40783591'},
#  {'address': {'building': '9015',
#    'coord': [-73.8706606, 40.7342757],
#    'street': 'Queens Boulevard',
#    'zipcode': '11373'},
#   'name': 'Cinnabon World Famous Cinnamon Rolls',
#   'restaurant_id': '40784405'},
#  {'address': {'building': '25',
#    'coord': [-73.9854099, 40.749687],
#    'street': 'West   35 Street',
#    'zipcode': '10018'},
#   'name': 'Cafe Rustico Ii',
#   'restaurant_id': '40785103'},
#  {'address': {'building': '897',
#    'coord': [-73.9900893, 40.7390882],
#    'street': 'Broadway',
#    'zipcode': '10003'},
#   'name': 'City Chow Cafe',
#   'restaurant_id': '40789374'},
#  {'address': {'building': '1611',
#    'coord': [-73.95876799999999, 40.6183915],
#    'street': 'Avenue M',
#    'zipcode': '11230'},
#   'name': "Chock Full O' Nuts",
#   'restaurant_id': '40792980'},
#  {'address': {'building': '1221',
#    'coord': [-73.962367, 40.7637492],
#    'street': '2 Avenue',
#    'zipcode': '10065'},
#   'name': 'China Fun',
#   'restaurant_id': '40793323'},
#  {'address': {'building': '',
#    'coord': [-73.97705599999999, 40.752998],
#    'street': 'Grand Central Terminal',
#    'zipcode': '10017'},
#   'name': 'Cafe Spice',
#   'restaurant_id': '40793607'},
#  {'address': {'building': '2166',
#    'coord': [-73.99783219999999, 40.5985843],
#    'street': 'Bath Avenue',
#    'zipcode': '11214'},
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40794321'},
#  {'address': {'building': '138-31',
#    'coord': [-73.8177883, 40.7081113],
#    'street': 'Queens Boulevard',
#    'zipcode': '11435'},
#   'name': 'Crystal Palace',
#   'restaurant_id': '40798514'},
#  {'address': {'building': '249',
#    'coord': [-73.9788067, 40.7769826],
#    'street': 'Columbus Avenue',
#    'zipcode': '10023'},
#   'name': 'Cafe Ronda',
#   'restaurant_id': '40799203'},
#  {'address': {'building': '2945',
#    'coord': [-74.2295052, 40.5469324],
#    'street': 'Arthur Kill Road',
#    'zipcode': '10309'},
#   'name': "Curves Gentleman'S Club",
#   'restaurant_id': '40800121'},
#  {'address': {'building': '8024',
#    'coord': [-73.9614481, 40.6044156],
#    'street': 'Kings Highway',
#    'zipcode': '11223'},
#   'name': 'Cafe Renaissance',
#   'restaurant_id': '40806615'},
#  {'address': {'building': '34-02',
#    'coord': [-73.8317112, 40.7661163],
#    'street': 'Linden Place',
#    'zipcode': '11354'},
#   'name': 'Carom Cafe Billiards',
#   'restaurant_id': '40808640'},
#  {'address': {'building': '2450',
#    'coord': [-73.9739714, 40.791121],
#    'street': 'Broadway',
#    'zipcode': '10024'},
#   'name': "Carmine'S",
#   'restaurant_id': '40811162'},
#  {'address': {'building': '0',
#    'coord': [-90.9745883, 38.3516219],
#    'street': 'E 72St Central Pk Drive North',
#    'zipcode': '10022'},
#   'name': 'Central Park Boathouse',
#   'restaurant_id': '40812630'},
#  {'address': {'building': '560',
#    'coord': [-73.92227869999999, 40.8177664],
#    'street': 'Morris Avenue',
#    'zipcode': '10451'},
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40814300'},
#  {'address': {'building': '98-09',
#    'coord': [-73.8687364, 40.75229300000001],
#    'street': '37 Avenue',
#    'zipcode': '11368'},
#   'name': 'Charo Restaurant',
#   'restaurant_id': '40814991'},
#  {'address': {'building': '20510',
#    'coord': [-73.7749235, 40.7532457],
#    'street': '48 Avenue',
#    'zipcode': '11364'},
#   'name': 'Constantines Deli',
#   'restaurant_id': '40815185'},
#  {'address': {'building': '24',
#    'coord': [-73.99097309999999, 40.7372758],
#    'street': 'East   17 Street',
#    'zipcode': '10003'},
#   'name': "Chop'T",
#   'restaurant_id': '40815605'},
#  {'address': {'building': '420',
#    'coord': [-73.9752701, 40.7527506],
#    'street': 'Lexington Avenue',
#    'zipcode': '10017'},
#   'name': 'City Chow Cafe V (Equinox)',
#   'restaurant_id': '40816772'},
#  {'address': {'building': '145',
#    'coord': [-73.97216999999999, 40.755584],
#    'street': 'East   49 Street',
#    'zipcode': '10017'},
#   'name': 'Caffe Linda',
#   'restaurant_id': '40819474'},
#  {'address': {'building': '100',
#    'coord': [-74.239806, 40.535467],
#    'street': 'Kreischer St',
#    'zipcode': '10309'},
#   'name': 'Columbus House',
#   'restaurant_id': '40821141'},
#  {'address': {'building': '503',
#    'coord': [-73.988849, 40.769475],
#    'street': 'West   57 Street',
#    'zipcode': '10019'},
#   'name': 'Casabianca Pizzeria',
#   'restaurant_id': '40823196'},
#  {'address': {'building': '1568',
#    'coord': [-73.953558, 40.774806],
#    'street': '2 Avenue',
#    'zipcode': '10028'},
#   'name': 'Comic Strip',
#   'restaurant_id': '40823209'},
#  {'address': {'building': '2893',
#    'coord': [-73.96576259999999, 40.80596329999999],
#    'street': 'Broadway',
#    'zipcode': '10025'},
#   'name': 'Community Food And Juice',
#   'restaurant_id': '40824179'},
#  {'address': {'building': '14511',
#    'coord': [-73.7942022, 40.6672795],
#    'street': 'North Conduit Avenue',
#    'zipcode': '11436'},
#   'name': 'Courtyard By Marriott',
#   'restaurant_id': '40824512'},
#  {'address': {'building': '4332',
#    'coord': [-74.15969900000002, 40.5451213],
#    'street': 'Amboy Road',
#    'zipcode': '10312'},
#   'name': 'Carvel Ice Cream',
#   'restaurant_id': '40827606'},
#  {'address': {'building': '4',
#    'coord': [-73.98385669999999, 40.7211434],
#    'street': 'Clinton Street',
#    'zipcode': '10002'},
#   'name': 'Clinton Street Baking Company',
#   'restaurant_id': '40829514'},
#  {'address': {'building': '121',
#    'coord': [-73.9835994, 40.7573439],
#    'street': 'West   45 Street',
#    'zipcode': '10036'},
#   'name': "Connolly'S",
#   'restaurant_id': '40836801'},
#  {'address': {'building': '1904',
#    'coord': [-73.9844943, 40.5748057],
#    'street': 'Surf Avenue',
#    'zipcode': '11224'},
#   'name': 'Concession # 110',
#   'restaurant_id': '40839232'},
#  {'address': {'building': '1904',
#    'coord': [-73.9844943, 40.5748057],
#    'street': 'Surf Avenue',
#    'zipcode': '11224'},
#   'name': 'Concession # 120/ The Bullpen',
#   'restaurant_id': '40839236'},
#  {'address': {'building': '1904',
#    'coord': [-73.9844943, 40.5748057],
#    'street': 'Surf Avenue',
#    'zipcode': '11224'},
#   'name': 'Concession Stand  330',
#   'restaurant_id': '40839260'},
#  {'address': {'building': '520',
#    'coord': [-73.78913399999999, 40.852584],
#    'street': 'City Island Avenue',
#    'zipcode': '10464'},
#   'name': 'City Island Deli',
#   'restaurant_id': '40839264'},
#  {'address': {'building': '71-15',
#    'coord': [-73.89188399999999, 40.7282749],
#    'street': 'Grand Avenue',
#    'zipcode': '11378'},
#   'name': "Connolly'S Corner",
#   'restaurant_id': '40840921'},
#  {'address': {'building': '1321',
#    'coord': [-73.95679249999999, 40.7671155],
#    'street': '1 Avenue',
#    'zipcode': '10021'},
#   'name': 'Cilantro',
#   'restaurant_id': '40845245'},
#  {'address': {'building': '422',
#    'coord': [-73.9842317, 40.6640914],
#    'street': '7 Avenue',
#    'zipcode': '11215'},
#   'name': 'Cafe Steinhof',
#   'restaurant_id': '40845757'},
#  ...]
